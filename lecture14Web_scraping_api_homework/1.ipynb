# %%
Оглавление
Задание 1
1.1 Итоговый датафрейм
Задание 2
In [1]:
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd
Задание 1
Обязательная часть
Будем парсить страницу со свежеми новостям на habr.com/ru/all/.

Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:

KEYWORDS = ['python', 'парсинг']

Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).

В итоге должен формироваться датафрейм вида: - -

Дополнительная часть (необязательная)
Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.

Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.

Итоговый датафрейм формировать со столбцами: - - -

In [2]:
URL = 'https://habr.com/ru/all/'
words = ['python', 'парсинг']
In [3]:
res_main = requests.get(URL)
soup_main = BeautifulSoup(res_main.text, 'html.parser')
In [4]:
# добираемя до параметра который нам подскажет сколько страниц всего 

result = soup_main.find('a', class_='toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_bordered').get('href')
result
Out[4]:
'/ru/all/page50/'
In [5]:
# выводить число страниц со всеми страницами, то есть получаем что всего 50 страниц с постами

number_page = soup_main.find('a', class_='toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_bordered').get('href')
int(number_page[-3:-1])
Out[5]:
50
In [6]:
# через метод range формируем цикл в рамках итераций которого будут формироваться url с постами

list(range(1,int(number_page[-3:-1])+1))

for x in range(1,int(number_page[-3:-1])+1):
    url_links = f'https://habr.com/ru/all/page{x}'
    print(url_links)
https://habr.com/ru/all/page1
https://habr.com/ru/all/page2
https://habr.com/ru/all/page3
https://habr.com/ru/all/page4
https://habr.com/ru/all/page5
https://habr.com/ru/all/page6
https://habr.com/ru/all/page7
https://habr.com/ru/all/page8
https://habr.com/ru/all/page9
https://habr.com/ru/all/page10
https://habr.com/ru/all/page11
https://habr.com/ru/all/page12
https://habr.com/ru/all/page13
https://habr.com/ru/all/page14
https://habr.com/ru/all/page15
https://habr.com/ru/all/page16
https://habr.com/ru/all/page17
https://habr.com/ru/all/page18
https://habr.com/ru/all/page19
https://habr.com/ru/all/page20
https://habr.com/ru/all/page21
https://habr.com/ru/all/page22
https://habr.com/ru/all/page23
https://habr.com/ru/all/page24
https://habr.com/ru/all/page25
https://habr.com/ru/all/page26
https://habr.com/ru/all/page27
https://habr.com/ru/all/page28
https://habr.com/ru/all/page29
https://habr.com/ru/all/page30
https://habr.com/ru/all/page31
https://habr.com/ru/all/page32
https://habr.com/ru/all/page33
https://habr.com/ru/all/page34
https://habr.com/ru/all/page35
https://habr.com/ru/all/page36
https://habr.com/ru/all/page37
https://habr.com/ru/all/page38
https://habr.com/ru/all/page39
https://habr.com/ru/all/page40
https://habr.com/ru/all/page41
https://habr.com/ru/all/page42
https://habr.com/ru/all/page43
https://habr.com/ru/all/page44
https://habr.com/ru/all/page45
https://habr.com/ru/all/page46
https://habr.com/ru/all/page47
https://habr.com/ru/all/page48
https://habr.com/ru/all/page49
https://habr.com/ru/all/page50
In [7]:
# выводим текст с нужной страницы с постами

result_2 = requests.get(url_links)
result_2.text
Out[7]:
'<!DOCTYPE html>\n<html lang="ru" class="no-js">\n  <head>\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<meta content=\'width=1024\' name=\'viewport\'>\n<title>Все публикации подряд / Хабр</title>\n\n\n\n  <meta property="fb:app_id" content="444736788986613" />\n<meta property="og:type" content="website"/>\n<meta property="fb:pages" content="472597926099084"/>\n<meta property="og:site_name" content="Хабр" />\n<link rel="image_src" href="https://habrastorage.org/storage/stuff/habr/habr_ru.png" />\n<meta property="og:image" content="https://habrastorage.org/storage/stuff/habr/habr_ru.png" />\n<meta property="og:image:width" content="1200" />\n<meta property="og:image:height" content="628" />\n<meta property="og:title" content="Все публикации подряд / Хабр"/>\n<meta property="og:description" content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом."/>\n\n\n\n<meta name=\'yandex-verification\' content=\'71593b225aeafc4e\' />\n<meta name=\'referrer\' content=\'unsafe-url\' />\n<meta name="pocket-site-verification" content="ed24b2b9721edf0a282c5b4a3232c4" />\n<meta name="biu" content="https://dr.habracdn.net/habr/oldassets/60a75345/images/">\n\n<style type="text/css">\n  @font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.woff2) format("woff2"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.woff) format("woff"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.ttf) format("truetype")}\n</style>\n\n<link href="https://dr.habracdn.net/habr/oldassets/60a75345/styles/main.bundle.css" rel="stylesheet" media="all" />\n\n\n\n\n\n<meta name=\'yandex-verification\' content=\'67d46b975fa41645\' />\n\n<link rel="apple-touch-icon" sizes="180x180" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/apple-touch-icon.png">\n<link rel="icon" type="image/png" sizes="32x32" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/favicon-32x32.png">\n<link rel="icon" type="image/png" sizes="16x16" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/favicon-16x16.png">\n<link rel="manifest" href="https://dr.habracdn.net/habr/oldassets/60a75345/site.webmanifest">\n<link rel="mask-icon" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/safari-pinned-tab.svg" color="#77a2b6">\n<meta name="application-name" content="Хабр"/>\n<meta name="msapplication-TileColor" content="#77a2b6">\n<meta name="theme-color" content="#77a2b6">\n\n\n  <link title="Все публикации подряд" type="application/rss+xml" rel="alternate" href="https://habr.com/ru/rss/all/all/?fl=ru"/>\n\n<script>/* Font Face Observer v2.0.13 - © Bram Stein. License: BSD-3-Clause */(function(){\'use strict\';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}\nfunction r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};\nfunction w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());\n\n(function(){function l(a,b){document.addEventListener?a.addEventListener("scroll",b,!1):a.attachEvent("scroll",b)}function m(a){document.body?a():document.addEventListener?document.addEventListener("DOMContentLoaded",function c(){document.removeEventListener("DOMContentLoaded",c);a()}):document.attachEvent("onreadystatechange",function k(){if("interactive"==document.readyState||"complete"==document.readyState)document.detachEvent("onreadystatechange",k),a()})};function r(a){this.a=document.createElement("div");this.a.setAttribute("aria-hidden","true");this.a.appendChild(document.createTextNode(a));this.b=document.createElement("span");this.c=document.createElement("span");this.h=document.createElement("span");this.f=document.createElement("span");this.g=-1;this.b.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.c.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";\nthis.f.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.h.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;";this.b.appendChild(this.h);this.c.appendChild(this.f);this.a.appendChild(this.b);this.a.appendChild(this.c)}\nfunction t(a,b){a.a.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;white-space:nowrap;font-synthesis:none;font:"+b+";"}function y(a){var b=a.a.offsetWidth,c=b+100;a.f.style.width=c+"px";a.c.scrollLeft=c;a.b.scrollLeft=a.b.scrollWidth+100;return a.g!==b?(a.g=b,!0):!1}function z(a,b){function c(){var a=k;y(a)&&a.a.parentNode&&b(a.g)}var k=a;l(a.b,c);l(a.c,c);y(a)};function A(a,b){var c=b||{};this.family=a;this.style=c.style||"normal";this.weight=c.weight||"normal";this.stretch=c.stretch||"normal"}var B=null,C=null,E=null,F=null;function G(){if(null===C)if(J()&&/Apple/.test(window.navigator.vendor)){var a=/AppleWebKit\\/([0-9]+)(?:\\.([0-9]+))(?:\\.([0-9]+))/.exec(window.navigator.userAgent);C=!!a&&603>parseInt(a[1],10)}else C=!1;return C}function J(){null===F&&(F=!!document.fonts);return F}\nfunction K(){if(null===E){var a=document.createElement("div");try{a.style.font="condensed 100px sans-serif"}catch(b){}E=""!==a.style.font}return E}function L(a,b){return[a.style,a.weight,K()?a.stretch:"","100px",b].join(" ")}\nA.prototype.load=function(a,b){var c=this,k=a||"BESbswy",q=0,D=b||3E3,H=(new Date).getTime();return new Promise(function(a,b){if(J()&&!G()){var M=new Promise(function(a,b){function e(){(new Date).getTime()-H>=D?b():document.fonts.load(L(c,\'"\'+c.family+\'"\'),k).then(function(c){1<=c.length?a():setTimeout(e,25)},function(){b()})}e()}),N=new Promise(function(a,c){q=setTimeout(c,D)});Promise.race([N,M]).then(function(){clearTimeout(q);a(c)},function(){b(c)})}else m(function(){function u(){var b;if(b=-1!=\nf&&-1!=g||-1!=f&&-1!=h||-1!=g&&-1!=h)(b=f!=g&&f!=h&&g!=h)||(null===B&&(b=/AppleWebKit\\/([0-9]+)(?:\\.([0-9]+))/.exec(window.navigator.userAgent),B=!!b&&(536>parseInt(b[1],10)||536===parseInt(b[1],10)&&11>=parseInt(b[2],10))),b=B&&(f==v&&g==v&&h==v||f==w&&g==w&&h==w||f==x&&g==x&&h==x)),b=!b;b&&(d.parentNode&&d.parentNode.removeChild(d),clearTimeout(q),a(c))}function I(){if((new Date).getTime()-H>=D)d.parentNode&&d.parentNode.removeChild(d),b(c);else{var a=document.hidden;if(!0===a||void 0===a)f=e.a.offsetWidth,\ng=n.a.offsetWidth,h=p.a.offsetWidth,u();q=setTimeout(I,50)}}var e=new r(k),n=new r(k),p=new r(k),f=-1,g=-1,h=-1,v=-1,w=-1,x=-1,d=document.createElement("div");d.dir="ltr";t(e,L(c,"sans-serif"));t(n,L(c,"serif"));t(p,L(c,"monospace"));d.appendChild(e.a);d.appendChild(n.a);d.appendChild(p.a);document.body.appendChild(d);v=e.a.offsetWidth;w=n.a.offsetWidth;x=p.a.offsetWidth;I();z(e,function(a){f=a;u()});t(e,L(c,\'"\'+c.family+\'",sans-serif\'));z(n,function(a){g=a;u()});t(n,L(c,\'"\'+c.family+\'",serif\'));\nz(p,function(a){h=a;u()});t(p,L(c,\'"\'+c.family+\'",monospace\'))})})};"object"===typeof module?module.exports=A:(window.FontFaceObserver=A,window.FontFaceObserver.prototype.load=A.prototype.load);}());\n\n(function( w ){\nif( w.document.documentElement.className.indexOf( "fonts-loaded" ) > -1 ){ return; }\n\nvar html = document.documentElement;\nvar FS500 = new w.FontFaceObserver("Fira Sans", { weight: 500 });\n\nFS500.load().then(function() {\nhtml.classList.add(\'fonts-loaded\');\nsessionStorage.fontsLoaded = true;\nconsole.log(\'FS500-loaded\');\n}).catch(function () {\nsessionStorage.fontsLoaded = false;\nconsole.log(\'FS500-unloaded\');\n});\n\nif (sessionStorage.fontsLoaded) {\nhtml.classList.add(\'fonts-loaded\');\n}\n}(this));\n</script>\n<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/jquery-1.8.3.min.js"></script>\n<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/chance.min.js"></script>\n<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/html2canvas.min.js"></script>\n<script>\n  window.create_callback_for_blocked = function(key) {\n    return function() {\n      googletag.cmd.push(function () {\n        googletag.display(key);\n      });\n    }\n  }\n\n  window.habr_blockers_checker = new function() {\n    var result;\n    var callbacksQueue = [];\n    var calledOnce = false;\n\n    function fireCallbacks() {\n      callbacksQueue.forEach(function(callback) {\n        callback(result);\n      });\n      callbacksQueue = [];\n    }\n\n    this.detect = function(imgUrl, callback) {\n      var checksRemain = 2;\n      var detected = false;\n      var error1 = false;\n      var error2 = false;\n\n      if (typeof callback !== \'function\') {\n        return;\n      };\n\n      callbacksQueue.push(callback);\n\n      if (typeof result !== \'undefined\') {\n        fireCallbacks();\n      };\n\n      if (calledOnce) {\n        return;\n      }\n      calledOnce = true;\n\n      imgUrl += \'?ch=*&rn=*\';\n\n      function beforeCheck(timeout) {\n        if (checksRemain === 0 || timeout > 1E3) {\n          result = checksRemain === 0 && detected;\n          fireCallbacks();\n        } else {\n          setTimeout(function() {\n            beforeCheck(timeout * 2)\n          }, timeout * 2);\n        }\n      }\n\n      function checkImages() {\n        if (--checksRemain) {\n          return;\n        };\n        detected = !error1 && error2;\n      }\n\n      var random = Math.random() * 11;\n\n      var img1 = new Image;\n      img1.onload = checkImages;\n      img1.onerror = function() {\n        error1 = true;\n        checkImages()\n      };\n      img1.src = imgUrl.replace(/\\*/, 1).replace(/\\*/, random);\n\n      var img2 = new Image;\n      img2.onload = checkImages;\n      img2.onerror = function() {\n        error2 = true;\n        checkImages()\n      };\n      img2.src = imgUrl.replace(/\\*/, 2).replace(/\\*/, random);\n\n      beforeCheck(250, callback)\n    };\n\n    this.detectWrapper = function(callback) {\n      return this.detect(\'/images/px.gif\', callback);\n    };\n  };\n\n  window.display_dfp_slot = function(key) {\n    if (window.habr_blockers_checker) {\n      window.habr_blockers_checker.detectWrapper(window.create_callback_for_blocked(key));\n    } else {\n      window.create_callback_for_blocked(key)();\n    }\n  };\n</script>\n\n\n<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/raven.min.js"></script>\n<script>Raven.config(\'https://9d127adffe724363a380a189afcdb015@sentry.srv.habr.com/11\', {\n  maxBreadcrumbs: 50,\n  sampleRate: 0.5,\n  whitelistUrls: [/https?:\\/\\/((www)\\.)?(m\\.)?habr\\.com/],\n}).install()</script>\n\n<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/_parts/advertise.js"></script>\n<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/_parts/adriver.js"></script>\n<script src="https://www.googletagservices.com/tag/js/gpt.js" async></script>\n<script src="https://static.criteo.net/js/ld/publishertag.js" async></script>\n\n<script>\n  var googletag = googletag || {};\n  googletag.cmd = googletag.cmd || [];\n</script>\n\n<script>\n  // TODO: move this code to module\n  //       move dot in chains to start of line and use one indent level:\n  //               ```\n  //                  start()\n  //                    .chainEnd()\n  //               ```\n\n  var ENABLE_YANDEX_ADS = false;\n\n  function display_yandex_rtb(yandexId, divId) {\n    $(\'#\' + divId).show();\n    (function(w, d, n, s, t) {\n      w[n] = w[n] || [];\n      w[n].push(function() {\n        Ya.Context.AdvManager.render({\n          blockId: yandexId,\n          renderTo: divId,\n          async: true\n        });\n      });\n      t = d.getElementsByTagName(\'script\')[0];\n      s = d.createElement(\'script\');\n      s.type = \'text/javascript\';\n      s.src = \'//an.yandex.ru/system/context.js\';\n      s.async = true;\n      t.parentNode.insertBefore(s, t);\n    })(this, this.document, \'yandexContextAsyncCallbacks\');\n  }\n\n  function listen_googletag_and_render_yandex(yandexId, targetDivId) {\n    if (!window.googletag || !window.googletag.cmd) {\n      return;\n    }\n    window.googletag.cmd.push(function() {\n      if (!window.googletag.pubads) {\n        return;\n      }\n      if (ENABLE_YANDEX_ADS) {\n        window.googletag.pubads()\n          .addEventListener(\'slotRenderEnded\', function(event) {\n            var divId = event.slot.getSlotElementId();\n            if (divId === targetDivId && event.isEmpty) {\n              window.display_yandex_rtb(yandexId, divId);\n            }\n          });\n      }\n    });\n  }\n\n  function getRoxotItem(storageKey, config) {\n    if (config) {\n      var { randomVal, returnCode } = config;\n    } else {\n      var randomVal = 100,\n          returnCode = \'101\';\n    }\n    try {\n      var groupId = localStorage.getItem(storageKey);\n      if (groupId === null) {\n        groupId = 1 + Math.floor(Math.random() * randomVal);\n        localStorage.setItem(storageKey, groupId);\n      }\n      return \'\' + groupId;\n    }\n    catch (e) {\n      return returnCode;\n    }\n  }\n\n  function getRoxotEvent() {\n    return \'\' + (1 + Math.floor(Math.random() * 100));\n  }\n\n  function leftpad(str, len, ch) {\n    str = String(str);\n\n    var i = -1;\n\n    if (!ch && ch !== 0) {\n      ch = \' \';\n    };\n\n    len = len - str.length;\n\n    while (++i < len) {\n      str = ch + str;\n    }\n\n    return str;\n  }\n\n  var WEEK_DAYS = [\'su\', \'mo\', \'tu\', \'we\', \'th\', \'fr\', \'sa\'];\n\n  function initializeDFP(usesABP) {\n    var currentDate = new Date();\n    var hours = currentDate.getHours();\n    var hoursStr = leftpad(hours, 2, \'0\');\n    var weekDayCode = WEEK_DAYS[currentDate.getDay()];\n    googletag.cmd.push(function() {\n      if (usesABP) {\n  googletag.defineSlot(\'/235032688/HH/HH02_inpage_wide\', [[1, 1], [780, 130], [780, 200], [780, 180], [780, 110], [728, 90]], \'div-gpt-hh-inpage-wide\').addService(googletag.pubads());\n  window.listen_googletag_and_render_yandex(\'R-A-149298-32\', \'div-gpt-hh-inpage-wide\');\n} else {\n  googletag.defineSlot(\'/235032688/HH/HH02_inpage_wide\', [[1, 1], [780, 200], [780, 130], [780, 180], [780, 110], [728, 90], [780, 195], [780, 210], [780, 260]], \'div-gpt-hh-inpage-wide\').addService(googletag.pubads());\n  window.listen_googletag_and_render_yandex(\'R-A-149298-36\', \'div-gpt-hh-inpage-wide\');\n}\n      if (usesABP) {\n  googletag.defineSlot(\'/235032688/HH/HH01_ATF_Poster\', [[1, 1], [300, 500], [300, 250], [300, 300], [300, 400], [300, 200], [300, 100], [240, 400]], \'div-gpt-hh-atf\').addService(googletag.pubads());\n  window.listen_googletag_and_render_yandex(\'R-A-149298-31\', \'div-gpt-hh-atf\');\n} else {\n  googletag.defineSlot(\'/235032688/HH/HH01_ATF_Poster\', [[1, 1], [300, 500], [300, 600], [300, 250], [300, 300], [300, 400], [300, 200], [300, 150], [300, 100], [240, 400]], \'div-gpt-hh-atf\').addService(googletag.pubads());\n  window.listen_googletag_and_render_yandex(\'R-A-149298-35\', \'div-gpt-hh-atf\');\n}\n\n      googletag.pubads().enableSingleRequest();\n      if (!usesABP) {\n        googletag.pubads().disableInitialLoad(); //We will wait for the Criteo Bidder Call before calling the adserver\n      }\n      googletag.pubads().collapseEmptyDivs();\n      googletag.pubads().\n      setTargeting(\'roxot-group-id\', getRoxotItem(\'roxot-gid\', { randomVal: 10000, returnCode: \'10001\'})).\n      setTargeting(\'roxot-sector-id\', getRoxotItem(\'roxot-sid\')).\n      setTargeting(\'roxot-deep\', getRoxotItem(\'roxot-deep\')).\n      setTargeting(\'roxot-event-group-id\', getRoxotEvent()).\n      setTargeting(\'roxot-event\', getRoxotEvent()).\n      setTargeting(\'roxot-event-deep\', getRoxotEvent()).\n      setTargeting(\'roxot-minutes\', (new Date).getUTCMinutes().toString()).\n      setTargeting(\'roxot-hours\', (new Date).getUTCHours().toString()).\n      setTargeting(\'roxot-day\', (new Date).getUTCDay().toString()).\n      setTargeting(\'chr\', hoursStr).\n      setTargeting(\'cwd\', weekDayCode).\n      setTargeting(\'aa\', (usesABP) ? \'yes\' : \'no\').\n      setTargeting(\'path\', window.location.pathname + window.location.search).\n      setTargeting(\'feedtype\', ["all_all","posts"]).\n      setTargeting(\'dev\', [0]).\n      setTargeting(\'user\', ["guest"]).\n      setTargeting(\'pagetype\', ["feed"]);\n      googletag.enableServices();\n\n      if (!usesABP) {\n        window.Criteo = window.Criteo || {};\n        window.Criteo.events = window.Criteo.events || [];\n        var launchAdServer = function () {\n          googletag.cmd.push(function () {\n            Criteo.SetDFPKeyValueTargeting(); //This will append Criteo keywords to the adserver call\n            googletag.pubads().refresh(); //This will trigger the adserver call\n          });\n        };\n        Criteo.events.push(function () {\n          var adUnits = {\n            \'placements\': [\n              {\'slotid\': \'div-gpt-hh-inpage-wide\', \'zoneid\': 1173491}, // TMTM - RU - CDB - SA - Habr - 780x180\n              {\'slotid\': \'div-gpt-hh-atf\', \'zoneid\': 1173489}, // TMTM - RU - CDB - SA - Habr - 300x600\n            ]\n          };\n          // Define the price band range\n          Criteo.SetLineItemRanges(\'0..599:1;600..1398:2;1400..3000:5\');\n          // Call Criteo and execute the callback function for a given timeout\n          Criteo.RequestBids(adUnits, launchAdServer, 750);\n        });\n      }\n    });\n  }\n  if (window.habr_blockers_checker) {\n    window.habr_blockers_checker.detectWrapper(initializeDFP);\n  } else {\n    initializeDFP(false);\n  }\n</script>\n\n\n\n  </head>\n\n  <body class="nl">\n\n    <div class="layout">\n      <div class="layout__row layout__row_services">\n        <div id="TMpanel">\n  <div class="container">\n    <div class="logo-wrapper">\n      <a href="https://habr.com/ru/" class="logo" title="">\n          <svg width="62" height="24" viewBox="0 0 62 24" xmlns="http://www.w3.org/2000/svg">\n    <path d="M16.875 19L11.075 10.225L16.825 1.4H12.6L8.75 7.4L4.94999 1.4H0.574994L6.32499 10.15L0.524994 19H4.79999L8.64999 12.975L12.525 19H16.875Z" />\n    <path d="M24.2607 5.775C20.8857 5.775 18.9607 7.625 18.6107 9.85H22.0107C22.2107 9.175 22.8607 8.6 24.1107 8.6C25.3357 8.6 26.2357 9.225 26.2357 10.425V11.025H23.4107C20.1107 11.025 18.1107 12.55 18.1107 15.2C18.1107 17.8 20.1107 19.3 22.6107 19.3C24.2857 19.3 25.6357 18.65 26.4357 17.6V19H29.8107V10.55C29.8107 7.4 27.5857 5.775 24.2607 5.775ZM23.6107 16.475C22.4857 16.475 21.7607 15.925 21.7607 15.025C21.7607 14.1 22.5607 13.55 23.6857 13.55H26.2357V14.125C26.2357 15.625 25.0107 16.475 23.6107 16.475Z" />\n    <path d="M39.925 6.3C38.125 6.3 36.65 6.95 35.7 8.275C35.95 5.85 36.925 4.65 39.375 4.275L44.3 3.55V0.375L39.025 1.25C33.925 2.1 32.35 5.5 32.35 11.175C32.35 16.275 34.825 19.3 39.2 19.3C43.125 19.3 45.55 16.3 45.55 12.7C45.55 8.825 43.3 6.3 39.925 6.3ZM39.025 16.25C37.125 16.25 36.075 14.725 36.075 12.675C36.075 10.7 37.175 9.275 39.05 9.275C40.875 9.275 41.9 10.75 41.9 12.7C41.9 14.65 40.9 16.25 39.025 16.25Z" />\n    <path d="M55.2855 5.775C53.3855 5.775 52.1605 6.6 51.5105 7.575V6.075H48.0105V23.775H51.6605V17.75C52.3105 18.65 53.5355 19.3 55.1855 19.3C58.3605 19.3 60.8855 16.8 60.8855 12.55C60.8855 8.225 58.3605 5.775 55.2855 5.775ZM54.4105 16.15C52.7105 16.15 51.5855 14.775 51.5855 12.6V12.5C51.5855 10.325 52.7105 8.925 54.4105 8.925C56.1105 8.925 57.2105 10.35 57.2105 12.55C57.2105 14.75 56.1105 16.15 54.4105 16.15Z" />\n</svg>\n\n      </a>\n      \n\n        <span class="projects-dropdown" id="dropdown-control">\n          <svg width="10" height="6" viewBox="0 0 10 6" fill="none" xmlns="http://www.w3.org/2000/svg">\n    <path fill-rule="evenodd" clip-rule="evenodd" d="M5.70711 5.70711C5.31658 6.09763 4.68342 6.09763 4.29289 5.70711L0.292892 1.70711C-0.097632 1.31658 -0.0976319 0.683417 0.292892 0.292893C0.683417 -0.0976308 1.31658 -0.0976308 1.70711 0.292893L5 3.58579L8.29289 0.292894C8.68342 -0.0976301 9.31658 -0.0976301 9.70711 0.292894C10.0976 0.683418 10.0976 1.31658 9.70711 1.70711L5.70711 5.70711Z" />\n</svg>\n\n        </span>\n        <div class="dropdown hidden" id="dropdown">\n          <div class="dropdown-heading">\n            Все сервисы Хабра\n          </div>\n          <a class="service" href="/">\n            <div class="service-title">\n              <svg width="52" height="22" viewBox="0 0 52 22" fill="none" xmlns="http://www.w3.org/2000/svg">\n                <path d="M13.86 17.0001L8.514 9.23405L13.816 1.51205H11.528L7.26 7.76005L2.97 1.51205H0.659997L5.984 9.19005L0.615997 17.0001H2.926L7.194 10.6861L11.528 17.0001H13.86Z" fill="#333333"/>\n                <path d="M20.181 5.67005C17.651 5.67005 16.111 7.10005 15.759 8.81605H17.585C17.893 8
.6963V14.636C21.2243 15.45 22.4123 16.242 24.1943 16.242C26.7463 16.242 29.2543 14.372 29.2543 10.456C29.2543 6.56202 26.7683 4.67002 24.2603 4.67002ZM24.0183 14.526C21.9723 14.526 20.6303 12.964 20.6303 10.5V10.412C20.6303 7.94802 21.9723 6.38602 24.0183 6.38602C25.9983 6.38602 27.3183 8.03602 27.3183 10.456C27.3183 12.876 25.9983 14.526 24.0183 14.526Z" fill="#333333"/>\n              <path d="M39.4123 4.91202L33.7583 13.074V4.91202H31.8883V16H33.7583L39.4123 7.83802V16H41.2823V4.91202H39.4123Z" fill="#333333"/>\n              <path d="M46.0815 4.91202L45.5095 11.71C45.3555 13.624 44.9595 14.328 43.5735 14.328H43.2655V16.044H43.7935C46.0595 16.044 47.0935 14.856 47.3355 11.842L47.7755 6.60602H51.8455V16H53.7375V4.91202H46.0815Z" fill="#333333"/>\n              <path d="M61.2045 4.67002C58.6745 4.67002 57.1345 6.10002 56.7825 7.81602H58.6085C58.9165 7.00202 59.7085 6.34202 61.1605 6.34202C62.5905 6.34202 63.6685 7.11202 63.6685 8.65202V9.40002H60.7205C58.0145 9.40002 56.3645 10.698 56.3645 12.832C56.3645 14.944 58.0365 16.242 60.1925 16.242C61.6005 16.242 62.9205 15.714 63.7565 14.68V16H65.5385V8.65202C65.5385 6.16602 63.8005 4.67002 61.2045 4.67002ZM60.4345 14.592C59.2025 14.592 58.2785 13.976 58.2785 12.81C58.2785 11.622 59.3125 11.006 60.8305 11.006H63.6685V11.82C63.6685 13.514 62.1945 14.592 60.4345 14.592Z" fill="#333333"/>\n              <path d="M76.104 4.91202V9.37802H70.626V4.91202H68.734V16H70.626V11.094H76.104V16H77.996V4.91202H76.104Z" fill="#333333"/>\n              <path d="M85.9003 14.526C83.8983 14.526 82.5783 12.876 82.5783 10.456C82.5783 8.05802 83.8543 6.38602 85.8783 6.38602C87.6383 6.38602 88.4523 7.53002 88.7383 8.45402H90.6303C90.3443 6.69402 88.8263 4.67002 85.8783 4.67002C82.6883 4.67002 80.6423 7.13402 80.6423 10.456C80.6423 13.844 82.7323 16.242 85.8783 16.242C88.6283 16.242 90.3883 14.394 90.6303 12.414H88.7383C88.4963 13.36 87.7483 14.526 85.9003 14.526Z" fill="#333333"/>\n            </svg>\n            </div>\n            <p class="service-description">\n              Удаленная работа для IT-специалистов\n            </p>\n          </a>\n        </div>\n    </div>\n    <div class="bmenu">\n      <a\n        class="bmenu__conversion"\n        href="https://habr.com/sandbox/start/"\n        onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'habr_top_panel\', \'become_an_author\'); }"\n      >Как стать автором</a>\n\n      <a\n        id="feature-effect"\n        class="bmenu__theme"\n        style="display: none;"\n        target="_blank"\n      >\n        <img alt="" width="20" style="position:relative; vertical-align: middle; top: -2px; margin-right: 4px;" />\n        <span class="bmenu__text"></span>\n      </a>\n    </div>\n\n      <div id="megapost-head-effect" class="bmenu_inner" style="display:flex!important;visibility:visible!important;">\n  <span class="bmenu slink">\n  </span>\n</div>\n\n  </div>\n</div>\n\n<script>\n  var dropdown = document.querySelector(\'#dropdown\');\n  var dropdownControl = document.querySelector(\'#dropdown-control\');\n  var logoWrapper = document.querySelector(\'.logo-wrapper\');\n\n  document.addEventListener(\'click\', function(e) {\n      if (dropdown) {\n        var isClickInside = logoWrapper.contains(e.target);\n        var dropdownClosed = dropdown.classList.contains(\'hidden\');\n        if (!isClickInside && !dropdownClosed) {\n          dropdown.classList.add(\'hidden\');\n          dropdownControl.classList.remove(\'reverted\');\n        }\n      }\n  });\n  if (dropdownControl) {\n    dropdownControl.onclick = function () {\n      dropdown.classList.toggle(\'hidden\');\n      dropdownControl.classList.toggle(\'reverted\');\n    }\n  }\n</script>\n\n      </div>\n\n      <div class="layout__row layout__row_navbar">\n        <div class="layout__cell">\n          <div class="main-navbar">\n  <div class="main-navbar__section main-navbar__section_left">\n    <ul class="nav-links" id="navbar-links">\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/top/" class="nav-links__item-link nav-links__item-link_current">Все потоки</a>\n    </li>\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/flows/develop/" class="nav-links__item-link ">Разработка</a>\n    </li>\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/flows/admin/" class="nav-links__item-link ">Администрирование</a>\n    </li>\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/flows/design/" class="nav-links__item-link ">Дизайн</a>\n    </li>\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/flows/management/" class="nav-links__item-link ">Менеджмент</a>\n    </li>\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/flows/marketing/" class="nav-links__item-link ">Маркетинг</a>\n    </li>\n    <li class="nav-links__item">\n      <a href="https://habr.com/ru/flows/popsci/" class="nav-links__item-link ">Научпоп</a>\n    </li>\n</ul>\n\n    <form action="https://habr.com/ru/search/#h" method="get" class="search-form" id="search-form">\n  <button type="button" class="btn btn_navbar_search icon-svg_search" id="search-form-btn" title="Поиск по сайту">\n    <svg class="icon-svg" width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg">\n<path fill-rule="evenodd" clip-rule="evenodd" d="M17 11C17 14.3137 14.3137 17 11 17C7.68629 17 5 14.3137 5 11C5 7.68629 7.68629 5 11 5C14.3137 5 17 7.68629 17 11ZM15.5838 17.5574C14.2857 18.4665 12.7051 19 11 19C6.58172 19 3 15.4183 3 11C3 6.58172 6.58172 3 11 3C15.4183 3 19 6.58172 19 11C19 12.9998 18.2662 14.8282 17.0533 16.2307C17.0767 16.2502 17.0994 16.2709 17.1214 16.2929L20.4143 19.5858C20.8048 19.9763 20.8048 20.6095 20.4143 21C20.0238 21.3905 19.3906 21.3905 19.0001 21L15.7072 17.7071C15.6605 17.6604 15.6194 17.6102 15.5838 17.5574Z" />\n</svg>\n\n  </button>\n  <label class="search-form__field-wrapper">\n    <input type="text" name="q" class="search-form__field" id="search-form-field" placeholder="Поиск" tabindex="-1"/>\n    <button type="button" class="btn btn_search-close" id="search-form-clear" title="Закрыть">\n      <svg class="icon-svg icon-svg_navbar-close-search" width="31" height="32" viewBox="0 0 31 32" aria-hidden="true" version="1.1" role="img"><path d="M26.67 0L15.217 11.448 3.77 0 0 3.77l11.447 11.45L0 26.666l3.77 3.77L15.218 18.99l11.45 11.448 3.772-3.77-11.448-11.45L30.44 3.772z"/></svg>\n\n    </button>\n  </label>\n</form>\n\n  </div>\n\n  <div class="main-navbar__section main-navbar__section_right">\n      <button type="button" class="btn btn_medium btn_navbar_lang js-show_lang_settings">\n        <svg class="icon-svg" width="18" height="18">\n          <use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#globus-v2" />\n        </svg>\n      </button>\n      <a href="https://habr.com/ru/auth/login/" id="login" class="btn btn_medium btn_navbar_login">Войти</a>\n      <a href="https://habr.com/ru/auth/register/" class="btn btn_medium btn_navbar_registration">Регистрация</a>\n\n\n  </div>\n</div>\n\n        </div>\n      </div>\n\n      <div class="layout__row layout__row_body">\n        <div class="layout__cell layout__cell_body">\n          \n            \n  \n  <section class="column-wrapper column-wrapper_lists js-sticky-wrapper">\n    <div class="content_left js-content_left">\n      <div class="page-header page-header_110 ">\n  Все потоки\n\n  \n</div>\n\n        <div class="tabs">\n    <div class="tabs__level tabs-level_top tabs-menu">\n        <a href="https://habr.com/ru/top/" class="tabs-menu__item tabs-menu__item_link" rel="nofollow"  >\n          <h3 class="tabs-menu__item-text tabs-menu__item-text_active">\n            Статьи\n            \n            \n          </h3>\n        </a>\n        <a href="https://habr.com/ru/news/" class="tabs-menu__item tabs-menu__item_link" rel="nofollow"  >\n          <h3 class="tabs-menu__item-text ">\n            Новости\n            \n            \n          </h3>\n        </a>\n        <a href="https://habr.com/ru/hubs/" class="tabs-menu__item tabs-menu__item_link" rel="nofollow"  >\n          <h3 class="tabs-menu__item-text ">\n            Хабы\n            \n            \n          </h3>\n        </a>\n        <a href="https://habr.com/ru/users/" class="tabs-menu__item tabs-menu__item_link" rel="nofollow"  >\n          <h3 class="tabs-menu__item-text ">\n            Авторы\n            \n            \n          </h3>\n        </a>\n        <a href="https://habr.com/ru/companies/" class="tabs-menu__item tabs-menu__item_link" rel="nofollow"  >\n          <h3 class="tabs-menu__item-text ">\n            Компании\n            \n            \n          </h3>\n        </a>\n    </div>\n\n      <div class="tabs__level tabs__level_bottom">\n        <ul class="toggle-menu ">\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/all/" class="toggle-menu__item-link toggle-menu__item-link_active" rel="nofollow" >\n                Все подряд\n                \n                <sup class="toggle-menu__item-counter toggle-menu__item-counter_new">55</sup>\n              </a>\n            </li>\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/top/" class="toggle-menu__item-link " rel="nofollow" >\n                Лучшие\n                \n                \n              </a>\n            </li>\n        </ul>\n      </div>\n        <div class="tabs__level tabs__level_bottom">\n          <ul class="toggle-menu ">\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/all/all/" class="toggle-menu__item-link toggle-menu__item-link_active" rel="nofollow" title="Все публикации в хронологическом порядке">\n                  Без порога\n                  \n                  \n              </a>\n            </li>\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/all/top10/" class="toggle-menu__item-link " rel="nofollow" title="Все публикации с рейтингом 10 и выше">\n                  ≥10\n                  \n                  \n              </a>\n            </li>\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/all/top25/" class="toggle-menu__item-link " rel="nofollow" title="Все публикации с рейтингом 25 и выше">\n                  ≥25\n                  \n                  \n              </a>\n            </li>\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/all/top50/" class="toggle-menu__item-link " rel="nofollow" title="Все публикации с рейтингом 50 и выше">\n                  ≥50\n                  \n                  \n              </a>\n            </li>\n            <li class="toggle-menu__item">\n              <a href="https://habr.com/ru/all/top100/" class="toggle-menu__item-link " rel="nofollow" title="Все публикации с рейтингом 100 и выше">\n                  ≥100\n                  \n                  \n              </a>\n            </li>\n          </ul>\n        </div>\n  </div>\n\n      \n      <div class="posts_list">\n          <ul class="content-list content-list_posts shortcuts_items">\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556056">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/OlegSivchenko/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/27b/f35/f6f/27bf35f6f595fc136b70c384752ba387.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">OlegSivchenko</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 09:19</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556056/" class="post__title_link">Не умереть, а именно уснуть. Что меня озадачивает в современных работах по продлению жизни</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/popular_science/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Научно-популярное\'); }">Научно-популярное</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/biotech/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Биотехнологии\'); }">Биотехнологии</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/health/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Здоровье\'); }">Здоровье</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/741/365/144/741365144bc6eed4b606e262db2cfc2c.jpeg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Сегодняшний пост (что не вполне обычно для моего блога) не претендует на научную достоверность и во многом является попыткой резюмировать мысли на тему, обозначенную в заголовке. Основным материалом, побудившим меня к написанию этого поста, стал текст уважаемого Дмитрия Тюлина «<a href="https://habr.com/ru/post/555210/" rel="noopener noreferrer nofollow">Старение и бессмертие: взгляд биолога</a>», а также дискуссия под ним. Также меня заинтересовала <a href="https://www.nkj.ru/archive/articles/24069/" rel="noopener noreferrer nofollow">статья</a> Николая Мушкамбарова о биологии мейоза, на которую ссылается Дмитрий Тюлин. Этот материал натолкнул меня на две линии размышлений и выводов, которыми я хочу здесь поделиться.    </p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556056/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_editorial_ru,h_21910,h_21912,h_21996" id="infopanel_post_556056">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 38: &uarr;33 и &darr;5">+28</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_editorial_ru,h_21910,h_21912,h_21996" data-type="2" data-id="556056" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">55</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">12,3k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556056/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">92</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556050">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/iLushkersky/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/0b6/dee/b5f/0b6deeb5f52d3aac34ff5a428d75da64.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">iLushkersky</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 08:18</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556050/" class="post__title_link">А что если гравитация и ускоренное расширение Вселенной — это следствие энтропии?</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/popular_science/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Научно-популярное\'); }">Научно-популярное</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/physics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Физика\'); }">Физика</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/astronomy/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Астрономия\'); }">Астрономия</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/5cf/5ae/133/5cf5ae133f94ecc61b581ff7e14721fd.jpeg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Притяжение властвует на больших расстояниях, оно универсально и очевидно в сравнении с другими взаимодействиями, но нюанс заключается в том, что оно невероятно слабо — в <em>10<sup>39 </sup></em>раз слабее электромагнитного взаимодействия, а ее влияние на микроскопическом уровне вовсе незаметно. Природа гравитации в мире элементарных частиц ломает умы ученых не один десяток лет, ведь она не хочет мириться ни с квантовой физикой, ни с электродинамикой. Струнная теория так же не может удовлетворить конфликт гравитации с другими взаимодействиями. Но, кажется, мы нашли способ помирить гравитацию с физикой. Как? Предположить, что она — не фундаментальное взаимодействие.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556050/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_21910,h_21968,h_22022" id="infopanel_post_556050">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 29: &uarr;26 и &darr;3">+23</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_21910,h_21968,h_22022" data-type="2" data-id="556050" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">73</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">22,7k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556050/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">101</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556002">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/ArkadiyXIII/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/47c/a40/834/47ca40834e97604a4298612c8b345dae.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">ArkadiyXIII</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 07:47</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556002/" class="post__title_link">Для чего нужно интеграционное тестирование?</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/it_testing/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Тестирование IT-систем\'); }">Тестирование IT-систем</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/programming/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Программирование\'); }">Программирование</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/refactoring/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Проектирование и рефакторинг\'); }">Проектирование и рефакторинг</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/web_testing/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Тестирование веб-сервисов\'); }">Тестирование веб-сервисов</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n\n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Эта статья является конспектом книги «<a href="https://www.litres.ru/vladimir-horikov/principy-unit-testirovaniya-pdf-epub-64083637/" rel="noopener noreferrer nofollow">Принципы юнит-тестирования</a>». Материал статьи посвящен интеграционным тестам.</p><p>Юнит-тесты прекрасно справляются с проверкой бизнес-логики, но проверять эту логику «в вакууме» недостаточно. Необходимо проверять,&nbsp;как разные ее части интегрируются друг с другом и внешними системами: базой&nbsp;данных, шиной сообщений и т. д.</p><p>В этой статье рассматривается роль интеграционных тестов, когда их следует использовать и когда лучше положиться на классические юнит-тесты. Также затронем эффективное написание интеграционных тестов.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556002/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_210,h_359,h_7504,h_19279" id="infopanel_post_556002">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 4: &uarr;3 и &darr;1">+2</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_210,h_359,h_7504,h_19279" data-type="2" data-id="556002" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">41</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">4,3k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556002/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">3</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556048">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/capissimo/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">capissimo</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 07:17</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556048/" class="post__title_link">Python, исследование данных и выборы: часть 5</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/python/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Python\'); }">Python</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/programming/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Программирование\'); }">Программирование</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/data_mining/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Data Mining\'); }">Data Mining</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/study/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Учебный процесс в IT\'); }">Учебный процесс в IT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/statistics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Статистика в IT\'); }">Статистика в IT</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover ">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/1c2/952/165/1c29521658bfe85baf4f348a33f93f24.png"   style="object-position: % %"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Заключительный пост №5<strong> для</strong> <strong>начинающих</strong> посвящен сопоставительной визуализации электоральных данных.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556048/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556048">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 3: &uarr;2 и &darr;1">+1</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" data-id="556048" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">35</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">2,1k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556048/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">8</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n                <li class="content-list__item content-list__item_post shortcuts_item" id="effect" style="display: none;">\n   <div class="default-block">\n    <div class="default-block__header">\n      <h2 class="default-block__header-title">Минуточку внимания</h2>\n    </div>\n    <div class="default-block__content">\n      <ul class="megapost-teasers" id="megapost-teasers">\n\n      </ul>\n    </div>\n  </div>\n</li>\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556044">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/capissimo/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">capissimo</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 06:34</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556044/" class="post__title_link">Python, исследование данных и выборы: часть 4</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/python/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Python\'); }">Python</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/programming/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Программирование\'); }">Программирование</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/data_mining/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Data Mining\'); }">Data Mining</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/study/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Учебный процесс в IT\'); }">Учебный процесс в IT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/statistics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Статистика в IT\'); }">Статистика в IT</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover ">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/848/ff2/331/848ff2331f6b0abf9367f56628da0abf.png"   style="object-position: % %"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Пост №4 <strong>для</strong> <strong>начинающих</strong> посвящен техническим приемам визуализации данных.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556044/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556044">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter  " title="Всего голосов 2: &uarr;1 и &darr;1">0</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" data-id="556044" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">25</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">1,2k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556044/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556042">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/capissimo/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">capissimo</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 06:01</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556042/" class="post__title_link">Python, исследование данных и выборы: часть 3</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/python/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Python\'); }">Python</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/programming/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Программирование\'); }">Программирование</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/data_mining/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Data Mining\'); }">Data Mining</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/study/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Учебный процесс в IT\'); }">Учебный процесс в IT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/statistics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Статистика в IT\'); }">Статистика в IT</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover ">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/c90/bd9/7ef/c90bd97efe58d8c07d83a7265da0eed1.png"   style="object-position: % %"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Пост №3 <strong>для</strong> <strong>начинающих</strong> посвящен генерированию распределений, их свойствам, а также графикам для их сопоставительного анализа.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556042/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556042">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter  " title="Всего голосов 2: &uarr;1 и &darr;1">0</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" data-id="556042" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">28</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">1,5k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556042/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">2</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556040">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/capissimo/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">capissimo</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 05:02</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556040/" class="post__title_link">Python, исследование данных и выборы: часть 2</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/python/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Python\'); }">Python</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/programming/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Программирование\'); }">Программирование</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/data_mining/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Data Mining\'); }">Data Mining</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/study/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Учебный процесс в IT\'); }">Учебный процесс в IT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/statistics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Статистика в IT\'); }">Статистика в IT</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover ">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/f08/8c0/f3b/f088c0f3b91e38dcaabb2b59639a3f50.png"   style="object-position: % %"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Пост №2<strong> для</strong> <strong>начинающих</strong> посвящен описательным статистикам, группированию данных и нормальному распределению. Все эти сведения заложат основу для дальнейшего анализа электоральных данных.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556040/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556040">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 5: &uarr;3 и &darr;2">+1</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" data-id="556040" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">37</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">2,2k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556040/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">6</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n                  <li class="content-list__item content-list__item_post shortcuts_item"><!-- /235032688/HH/HH02_inpage_wide -->\n<div class="dfp-slot">\n  <a href="https://tmtm.ru/services/advertising/" target="_blank" class="dfp-slot__label">Реклама</a>\n<div class="dfp-slot__placeholder">\n  <span class="dfp-slot__placeholder-text">AdBlock похитил этот баннер, но&nbsp;баннеры не&nbsp;зубы &mdash; отрастут<br/><br/> <a href="https://u.tmtm.ru/tmtalkadblock" class="btn btn_large btn_blue" style="display:inline-flex!important;" target="_blank">Подробнее</a></span>\n</div>\n\n  <div class="dfp-slot__banner dfp-slot__banner_wide" id=\'div-gpt-hh-inpage-wide\'>\n    <script>\n      window.display_dfp_slot(\'div-gpt-hh-inpage-wide\');\n    </script>\n  </div>\n</div>\n</li>\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_544730">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/dostigai/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/aff/85d/752/aff85d752f5f4597438ad88bd681d7b8.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">dostigai</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 03:08</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/southbridge/blog/544730/" class="post__title_link">Однажды револьвер уравнял шансы сильных и слабых. А потом придумали интернет</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/southbridge/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании Southbridge\'); }">Блог компании Southbridge</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/infosecurity/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Информационная безопасность\'); }">Информационная безопасность</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/network_technologies/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Сетевые технологии\'); }">Сетевые технологии</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/dwh/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Хранение данных\'); }">Хранение данных</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n\n    <div class="post__text post__text-html  post__text_v1 ">\n      <p><img src="https://habrastorage.org/webt/6f/dd/eo/6fddeoxmdczs6ruhnoknh3n_8du.jpeg" alt="image"></p><br>\r\n<p>Количество хорошо подготовленных целевых кибератак на <strong>критическую информационную инфраструктуру</strong> предприятий и целых городов в разных странах растёт с каждым годом. Причём в некоторых <a href="https://ru.wikipedia.org/wiki/Stuxnet" rel="nofollow noopener noreferrer">случаях </a> пострадавшие объекты КИИ даже не имели выхода в интернет. По мнению специалистов от кибербезопасности, выбор цели, задействованные ресурсы, подбор методов, уровень подготовки и действий в целом может говорить о том, что та или иная хакерская группировка, стоящая за каждой высококлассной атакой, работает на ту или иную иностранную спецслужбу.</p><br>\r\n<p>В России, как всегда, «долго запрягают». ФЗ-187 о безопасности КИИ на фоне вышеупомянутого выглядит запоздалым и долго исполняемым. Конечно, во многом по объективным причинам… и это лучшее, что у нас сейчас есть.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/southbridge/blog/544730/#habracut">Читать дальше &rarr;</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_southbridge,h_50,h_17123,h_19197" id="infopanel_post_544730">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 16: &uarr;10 и &darr;6">+4</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_southbridge,h_50,h_17123,h_19197" data-type="2" data-id="544730" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">19</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">5,9k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/southbridge/blog/544730/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">16</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556038">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/nickTS/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/d6a/e1c/e96/d6ae1ce96ec4c6b220fb8017f3b071b3.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">nickTS</span>\n    </a>\n\n    <span class="post__time">6 мая 2021 в 01:19</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/itsoft/blog/556038/" class="post__title_link">Первый полет New Shepard с людьми на борту назначен на 20 июля 2021</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/itsoft/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании ITSOFT\'); }">Блог компании ITSOFT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/popular_science/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Научно-популярное\'); }">Научно-популярное</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/space/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Космонавтика\'); }">Космонавтика</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/futurenow/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Будущее здесь\'); }">Будущее здесь</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/2a0/c49/a0b/2a0c49a0b221b8606ee8f620308da0ed.jpeg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p><em>Об этом на своем </em><a href="https://www.blueorigin.com/news/bid-for-the-very-first-seat-on-new-shepard"><em><u>сайте</u></em></a><em> сообщила компания Blue Origin. В первом рейсе одно место предлагается победителю аукциона – закрытые торги начались 5 мая. Саму новость и начало аукциона компания приурочила к 60-летию первого полета американского астронавта в космос (в честь которого, кстати, и назван корабль) – Алана Шепарда.</em></p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/itsoft/blog/556038/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_itsoft,h_21910,h_21962,h_22014" id="infopanel_post_556038">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 10: &uarr;10 и &darr;0">+10</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_itsoft,h_21910,h_21962,h_22014" data-type="2" data-id="556038" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">6</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">4k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/itsoft/blog/556038/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">9</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556028">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/i7071270/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/a7c/9c8/5a7/a7c9c85a7d346670defcb8bcf1aef661.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">i7071270</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 22:39</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556028/" class="post__title_link">«Промышленная» лампа на 40Вт</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/health/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Здоровье\'); }">Здоровье</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/futurenow/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Будущее здесь\'); }">Будущее здесь</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/webt/vp/ng/t_/vpngt_iecxrqwxfcyp3pti9cjzo.jpeg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>В последнее время в продуктовых магазинах (окей, лента и др) стали появляться <strong>"промышленные" лампы</strong>. Я специально не стал указывать бренд в заголовке, они отличаются только надписью на лампе, даже ценник примерно одинаковый.</p><p>Есть на 20Вт и более - но все их объединяет одно <s>их лучше не покупать</s>, они очень легкие и стоят разумных денег, до 600р.</p><p>Конечно же, нам обещают <s>300часов</s> 30 000часов работы, отсутствие пульсаций, а некоторые производители заявляют о промышленном применении данных ламп, но к этому мы еще вернемся.</p><p>Нам обещают: 40Вт, ЦТ 4000k, световой поток 3200лм (<a href="http://ecola.ru/catalogue60.html" rel="noopener noreferrer nofollow">http://ecola.ru/catalogue60.html</a>)</p><p>На практике: <strong><em>построена лампа на чипе bp2865g, имеет активную мощность ~36Вт, но PF(cosf) ~0,52</em></strong>, т.е. получаем потребление ~55Ва, <a href="https://habr.com/ru/company/lamptest/blog/535596/" rel="noopener noreferrer nofollow">сразу вспоминаем статью Lamptest </a>(при мощности ламп более 20Вт должен быть PF(cosf) ~0,9).</p><p>Немного снимков с тепловизора, лампа работает 7 минут, корпус разогрелся всего до 80 градусов.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556028/#habracut">Узнать что в них промышленного</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_21996,h_22014" id="infopanel_post_556028">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 12: &uarr;8 и &darr;4">+4</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_21996,h_22014" data-type="2" data-id="556028" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">13</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">10,6k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556028/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">17</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n                <li class="content-list__item content-list__item_post shortcuts_item">\n\n  <div class="promo-block promo-block_vacancies">\n    <h2 class="promo-block__header">\n      \n      <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'blockname\'); }" href="https://career.habr.com/vacancies" target="_blank" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=block_name&utm_campaign=vacancies_postlist" class="promo-block__title-link" rel="nofollow">\n        Вакансии\n      </a>\n    </h2>\n\n      <div class="promo-block__content">\n        <ul class="content-list content-list_promo" >\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/vacancies/1000049512" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=vacancy&utm_campaign=vacancies_postlist" >\n    <div class="promo-item__wrap">\n      <div class="promo-item__title promo-item__title_hovered">Fullstack разработчик PHP, JS, CSS на полный рабочий день удаленно</div>\n      <div class="promo-item__attrs">\n          <span class="promo-item__attrs-item promo-item__amount_rur">\n              <span title="80000 rur">\n                от 80\xa0000\n              </span>\n              <span title="140000 rur">\n                до 140\xa0000\n              </span>\n          </span>\n        <span class="promo-item__attrs-item">Reclamix</span>\n        \n        <span class="promo-item__attrs-item">Можно удаленно</span>\n      </div>\n    </div>\n  </a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/vacancies/1000073606" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=vacancy&utm_campaign=vacancies_postlist" >\n    <div class="promo-item__wrap">\n      <div class="promo-item__title promo-item__title_hovered">Middle Java Developer</div>\n      <div class="promo-item__attrs">\n          <span class="promo-item__attrs-item promo-item__amount_rur">\n              <span title="150000 rur">\n                от 150\xa0000\n              </span>\n          </span>\n        <span class="promo-item__attrs-item">Gameram</span>\n        <span class="promo-item__attrs-item">Самара</span>\n        <span class="promo-item__attrs-item">Можно удаленно</span>\n      </div>\n    </div>\n  </a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/vacancies/1000075384" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=vacancy&utm_campaign=vacancies_postlist" >\n    <div class="promo-item__wrap">\n      <div class="promo-item__title promo-item__title_hovered">Middle+/Senior Android Kotlin Developer</div>\n      <div class="promo-item__attrs">\n          <span class="promo-item__attrs-item promo-item__amount_rur">\n              <span title="180000 rur">\n                от 180\xa0000\n              </span>\n              <span title="300000 rur">\n                до 300\xa0000\n              </span>\n          </span>\n        <span class="promo-item__attrs-item">Mobigility Inc.</span>\n        \n        <span class="promo-item__attrs-item">Можно удаленно</span>\n      </div>\n    </div>\n  </a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/vacancies/1000076847" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=vacancy&utm_campaign=vacancies_postlist" >\n    <div class="promo-item__wrap">\n      <div class="promo-item__title promo-item__title_hovered">Менеджер проектов</div>\n      <div class="promo-item__attrs">\n          <span class="promo-item__attrs-item promo-item__amount_rur">\n              <span title="150000 rur">\n                до 150\xa0000\n              </span>\n          </span>\n        <span class="promo-item__attrs-item">Articul Technology</span>\n        \n        <span class="promo-item__attrs-item">Можно удаленно</span>\n      </div>\n    </div>\n  </a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/vacancies/1000076844" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=vacancy&utm_campaign=vacancies_postlist" >\n    <div class="promo-item__wrap">\n      <div class="promo-item__title promo-item__title_hovered">Android разработчик</div>\n      <div class="promo-item__attrs">\n          <span class="promo-item__attrs-item promo-item__amount_rur">\n              <span title="70000 rur">\n                от 70\xa0000\n              </span>\n              <span title="150000 rur">\n                до 150\xa0000\n              </span>\n          </span>\n        <span class="promo-item__attrs-item">AppCraft</span>\n        <span class="promo-item__attrs-item">Рязань</span>\n        <span class="promo-item__attrs-item">Можно удаленно</span>\n      </div>\n    </div>\n  </a>\n\n            </li>\n        </ul>\n      </div>\n\n    <div class="promo-block__footer">\n      <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_post\' } else {  var action = \'career_feed\' }  ga(\'send\', \'event\', \'tm_block\', action, \'posts\'); }" href="https://career.habr.com/vacancies/" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=vacancies_all&utm_campaign=vacancies_postlist" class="promo-block__footer-link promo-block__footer-link_selected" target="_blank" rel="nofollow">Больше вакансий на Хабр Карьере</a>\n    </div>\n  </div>\n</li>\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556024">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/Furriest/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/927/130/b05/927130b056159f52821165e8bdce69d7.png" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">Furriest</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 22:36</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556024/" class="post__title_link">Настраиваем отказоустойчивость Pi-Hole в связке с Mikrotik</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/network_technologies/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Сетевые технологии\'); }">Сетевые технологии</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/a38/cc0/0a3/a38cc00a3b980ef2fcd235f8da23b48d.png"   style="object-position: 0% 86.136363636364%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>В <a href="https://habr.com/ru/post/468621/" rel="noopener noreferrer nofollow">прошлой статье</a> мы внедрили домашний сервер DoH с использованием Pi-Hole, чем не только пофильтровали большое количество рекламы, но и инкапсулировали наши DNS-запросы в HTTPS, что вывело их из поля фильтрации запросов оператором связи.</p><p>Всем замечательно это решение, но у него есть один нюанс. Если вдруг у нас закончились деньги на счету у оператора связи или по каким-то другим причинам пропал канал связи до внешнего мира, мы даже не сможем пополнить счет, чтобы восстановить сервис, потому что не будет работать DNS. Или, например, если наш Pi-Hole по каким-то причинам перестал работать -  вот вроде и вся сеть работает, и гугл пингуется, а пока не пропишешь другой DNS-сервер - не будет счастья. А если вы еще в этот момент заняты чем-то другим и не можете приступить к восстановлению незамедлительно - домашние негодуют, портят радостное существование своими жалобами и даже котики, чуя общую нервозность, стремятся нагадить вам в тапки.</p><p>Огорчать котиков - дело последнее, поэтому в этой статье я опишу, как вы можете внедрить автоматическое переключение с использования Pi-Hole на использование операторских (как, впрочем, и любых других) DNS при проблемах на Pi-Hole. </p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556024/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_17123" id="infopanel_post_556024">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 16: &uarr;16 и &darr;0">+16</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_17123" data-type="2" data-id="556024" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">99</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">9,1k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556024/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">13</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556018">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/egaxegax/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/377/221/2ca/3772212cae56cdecf113de497f75fddf.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">egaxegax</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 21:21</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556018/" class="post__title_link">Карта метро Москвы с расчётом пути</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/javascript/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'JavaScript\'); }">JavaScript</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/vector_graphics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Работа с векторной графикой\'); }">Работа с векторной графикой</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/html5/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'HTML\'); }">HTML</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/canvas/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Canvas\'); }">Canvas</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/423/4db/aee/4234dbaee2ee94f6cb5e44dc03b91c7c.png"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>В своей предыдущей статье про интерактивную <a href="http://habrahabr.ru/post/268199" rel="noopener noreferrer nofollow">карту метро Москвы</a> я описывал процесс создания векторной карты на <em>svg</em>-движке, сравнивая с канвасным отображением. </p><p>Спустя время я решил вернуться к своей <a href="https://egaxegax.github.io/dbcartajs/svg/mosmetro.html" rel="noopener noreferrer nofollow">карте</a> и добавил в неё возможность вывода маршрута кратчайшего пути между выбранными станциями по алгоритму <a href="https://habr.com/ru/post/200252" rel="noopener noreferrer nofollow">BFS</a>, обхода графа в ширину.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556018/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_357,h_449,h_17103,h_17187" id="infopanel_post_556018">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 6: &uarr;5 и &darr;1">+4</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_357,h_449,h_17103,h_17187" data-type="2" data-id="556018" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">19</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">6,1k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556018/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">14</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_555860">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/ph_piter/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/3be/b11/2b0/3beb112b076924a916b27c845d88dcfa.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">ph_piter</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 21:16</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/piter/blog/555860/" class="post__title_link">Издательство Питер. Колонка редактора</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/piter/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании Издательский дом «Питер»\'); }">Блог компании Издательский дом «Питер»</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/lib/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Профессиональная литература\'); }">Профессиональная литература</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n\n    <div class="post__text post__text-html  post__text_v1 ">\n      <a href="https://habr.com/ru/company/piter/blog/555860/"><div style="text-align:center;"><img src="https://habrastorage.org/webt/mi/sm/cq/mismcqetge7xg2rmwga6uqsr8su.png" alt="image"></div></a><br>\r\nПривет, Хаброжители! Предлагаем ознакомиться с краткими обзорами сданных в типографию новинок. <br>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/piter/blog/555860/#habracut">Читать дальше &rarr;</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_piter,h_19309" id="infopanel_post_555860">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 7: &uarr;5 и &darr;2">+3</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_piter,h_19309" data-type="2" data-id="555860" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">3k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/piter/blog/555860/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">7</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n                <li class="content-list__item content-list__item_post shortcuts_item">\n\n  <div class="promo-block promo-block_courses">\n    <h2 class="promo-block__header">\n      <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'blockname\'); }" href="https://career.habr.com/courses" target="_blank" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=block_name&utm_campaign=courses_postlist" class="promo-block__title-link" rel="nofollow">\n        Курсы\n      </a>\n    </h2>\n\n    <div class="promo-block__content">\n      <ul class="content-list content-list_promo" >\n          <li class="content-list__item content-list__item_promo">\n            <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/courses/265" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=course&utm_campaign=courses_postlist" >\n  <div class="promo-item__wrap">\n    <div class="promo-item__title promo-item__title_hovered">\n        <img src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/058/logo/medium_90c46342f487198001713f1faa9f8eee.png" class="promo-item__title-image" width="20" height="20" />\n      Факультет Java-разработки\n    </div>\n    <div class="promo-item__attrs">\n        <span class="promo-item__attrs-item">\n            27 мая 2021\n        </span>\n        <span class="promo-item__attrs-item">\n            1 год\n        </span>\n        <span class="promo-item__attrs-item promo-item__amount_rur">\n            180\xa0000 \n        </span>\n        <span class="promo-item__attrs-item">\n          GeekBrains\n        </span>\n    </div>\n  </div>\n</a>\n\n          </li>\n          <li class="content-list__item content-list__item_promo">\n            <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/courses/603" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=course&utm_campaign=courses_postlist" >\n  <div class="promo-item__wrap">\n    <div class="promo-item__title promo-item__title_hovered">\n        <img src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/023/logo/medium_003285e04cd9c6506d56e6d082755cc1.png" class="promo-item__title-image" width="20" height="20" />\n      DevOps практики и инструменты\n    </div>\n    <div class="promo-item__attrs">\n        <span class="promo-item__attrs-item">\n            27 мая 2021\n        </span>\n        <span class="promo-item__attrs-item promo-item__amount_rur">\n            95\xa0000 \n        </span>\n        <span class="promo-item__attrs-item">\n          OTUS\n        </span>\n    </div>\n  </div>\n</a>\n\n          </li>\n          <li class="content-list__item content-list__item_promo">\n            <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/courses/361" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=course&utm_campaign=courses_postlist" >\n  <div class="promo-item__wrap">\n    <div class="promo-item__title promo-item__title_hovered">\n        <img src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/023/logo/medium_003285e04cd9c6506d56e6d082755cc1.png" class="promo-item__title-image" width="20" height="20" />\n      Разработчик Golang\n    </div>\n    <div class="promo-item__attrs">\n        <span class="promo-item__attrs-item">\n            27 мая 2021\n        </span>\n        <span class="promo-item__attrs-item">\n            5 месяцев\n        </span>\n        <span class="promo-item__attrs-item promo-item__amount_rur">\n            80\xa0000 \n        </span>\n        <span class="promo-item__attrs-item">\n          OTUS\n        </span>\n    </div>\n  </div>\n</a>\n\n          </li>\n          <li class="content-list__item content-list__item_promo">\n            <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/courses/262" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=course&utm_campaign=courses_postlist" >\n  <div class="promo-item__wrap">\n    <div class="promo-item__title promo-item__title_hovered">\n        <img src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/058/logo/medium_90c46342f487198001713f1faa9f8eee.png" class="promo-item__title-image" width="20" height="20" />\n      Факультет Python-разработки\n    </div>\n    <div class="promo-item__attrs">\n        <span class="promo-item__attrs-item">\n            27 мая 2021\n        </span>\n        <span class="promo-item__attrs-item">\n            16 месяцев\n        </span>\n        <span class="promo-item__attrs-item promo-item__amount_rur">\n            180\xa0000 \n        </span>\n        <span class="promo-item__attrs-item">\n          GeekBrains\n        </span>\n    </div>\n  </div>\n</a>\n\n          </li>\n          <li class="content-list__item content-list__item_promo">\n            <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="https://career.habr.com/courses/1239" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=course&utm_campaign=courses_postlist" >\n  <div class="promo-item__wrap">\n    <div class="promo-item__title promo-item__title_hovered">\n        <img src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/023/logo/medium_003285e04cd9c6506d56e6d082755cc1.png" class="promo-item__title-image" width="20" height="20" />\n      Роботизация процессов (RPA)\n    </div>\n    <div class="promo-item__attrs">\n        <span class="promo-item__attrs-item">\n            27 мая 2021\n        </span>\n        <span class="promo-item__attrs-item promo-item__amount_">\n            Бесплатно\n        </span>\n        <span class="promo-item__attrs-item">\n          OTUS\n        </span>\n    </div>\n  </div>\n</a>\n\n          </li>\n      </ul>\n    </div>\n\n    <div class="promo-block__footer">\n      <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'career_courses_post\' } else {  var action = \'career_courses_feed\' }  ga(\'send\', \'event\', \'tm_block\', action, \'posts\'); }" href="https://career.habr.com/courses" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=courses_all&utm_campaign=courses_postlist" class="promo-block__footer-link promo-block__footer-link_selected" target="_blank" rel="nofollow">Больше курсов на Хабр Карьере</a>\n    </div>\n  </div>\n</li>\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_555916">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/gerasimovich/" class="post__user-info user-info" title="Автор публикации">\n        <span class="default-image_mini default-image_green">\n          <svg class="icon-svg" width="24" height="24" viewBox="0 0 24 24" aria-hidden="true" version="1.1" role="img"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"/></svg>\n        </span>\n      <span class="user-info__nickname user-info__nickname_small">gerasimovich</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 21:05</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/it_people/blog/555916/" class="post__title_link">Три способа стать геймдизайнером, иконы игр и тренды GameDev. Интервью конференции DUMP</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/it_people/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании IT-People\'); }">Блог компании IT-People</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/tech_events/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Конференции\'); }">Конференции</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/game_design/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Дизайн игр\'); }">Дизайн игр</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/interviews/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Интервью\'); }">Интервью</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/cfc/2af/348/cfc2af3480aa7491894a66d007e80ac6.jpg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Когда играешь в особенно крутую игру, останавливаться не хочется, пока не пройдешь всё до конца. А ещё хочется создать свою игру! Знакомая история? Для участников DUMP тоже:) В этом году впервые на конференции будет представлена секция GameDev.&nbsp;</p><p>Мы решили узнать больше о разработке игр и пообщались с представителями индустрии из компании Targem Games — Евгением Бушуевым (Game Designer Crossout) и Алексеем Честных (Creative Director).</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/it_people/blog/555916/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_it_people,h_20754,h_20800,h_22020" id="infopanel_post_555916">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 1: &uarr;1 и &darr;0">+1</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_it_people,h_20754,h_20800,h_22020" data-type="2" data-id="555916" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">9</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">1,3k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/it_people/blog/555916/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">4</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556004">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/danaumov/" class="post__user-info user-info" title="Автор публикации">\n        <span class="default-image_mini default-image_green">\n          <svg class="icon-svg" width="24" height="24" viewBox="0 0 24 24" aria-hidden="true" version="1.1" role="img"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"/></svg>\n        </span>\n      <span class="user-info__nickname user-info__nickname_small">danaumov</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 19:59</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/rshb/blog/556004/" class="post__title_link">Вклад биотехнологий в решение проблем Агротеха</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/rshb/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании Россельхозбанк\'); }">Блог компании Россельхозбанк</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/biotech/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Биотехнологии\'); }">Биотехнологии</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/92e/1ce/86a/92e1ce86a9e293ad32d5a8f8994cda58.png"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p><strong>Проблемы аграриев взялись решать биотехнологи</strong></p><p>Благодаря биотехнологиям, всё больше процессов в агросфере выстраивается так, чтобы быть эффективными и прибыльными, не нанося вред природе. От специалистов-биотехнологов зависит, будем ли мы выращивать овощи и фрукты на городских мини-фермах и <a href="https://habr.com/ru/company/rshb/blog/546370/">будет ли мясо производиться в пробирке</a> из одной клетки или печататься на 3D-принтере и многое другое.&nbsp;</p><p>Существенную долю рынка мировых биотехнологий, - 51 %, составляют сельское хозяйство, пищевая промышленность и химпром. По <a href="https://rosng.ru/post/posle-koronavirusa-v-mire-nachnetsya-rost-biotehnologiy-ekspert">прогнозам экспертов</a>, до 2028 года рост рынка биотехнологий в год составит в среднем 15 %. </p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/rshb/blog/556004/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_rshb,h_21912" id="infopanel_post_556004">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 12: &uarr;9 и &darr;3">+6</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_rshb,h_21912" data-type="2" data-id="556004" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">11</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">2,2k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/rshb/blog/556004/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_555914">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/honyaki/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/96e/81d/bc0/96e81dbc01247c6c855b1806b355efa3.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">honyaki</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 19:45</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/skillfactory/blog/555914/" class="post__title_link">Как я посчитал миллионное число Фибоначчи</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/skillfactory/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании SkillFactory\'); }">Блог компании SkillFactory</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/zadachki/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Занимательные задачки\'); }">Занимательные задачки</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/python/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Python\'); }">Python</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/maths/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Математика\'); }">Математика</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/de4/f4e/871/de4f4e871d23e5f9d6715fc3d8ccec02.jpg"   style="object-position: 0% 87.272727272727%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Все мы понимаем, что рекурсивное вычисление чисел Фибоначчи крайне неэффективно. Многим людям наверняка хотелось проверить, где пределы (не)эффективности, но не доходили руки, не хватало времени. Специально к старту нового потока курса <a href="https://skillfactory.ru/python-fullstack-web-developer?utm_source=infopartners&amp;utm_medium=habr&amp;utm_campaign=habr_FPW&amp;utm_term=regular&amp;utm_content=050521">Fullstack-разработчик на Python</a> мы решили поделиться переводом статьи, автор которой шаг за шагом показывает возможности современного Python на примере разных подходов к вычислению чисел Фибоначчи. В статье вы найдёте проблемные значения n и сравнение производительности оптимального и неоптимального решений на графике.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/skillfactory/blog/555914/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_skillfactory,h_287,h_340,h_17812" id="infopanel_post_555914">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 29: &uarr;15 и &darr;14">+1</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_skillfactory,h_287,h_340,h_17812" data-type="2" data-id="555914" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">35</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">5,7k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/skillfactory/blog/555914/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">34</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n                <li class="content-list__item content-list__item_post shortcuts_item">\n\n  <div class="promo-block promo-block_freelansim-tasks">\n    <h2 class="promo-block__header">\n      \n      <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' }  ga(\'send\', \'event\', \'tm_block\', action, \'blockname\'); }" href="http://freelance.habr.com/" target="_blank" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=block_name&utm_campaign=tasks_postlist" class="promo-block__title-link" rel="nofollow">Заказы</a>\n    </h2>\n\n      <div class="promo-block__content">\n        <ul class="content-list content-list_promo" >\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="http://freelance.habr.com/tasks/367301" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=task&utm_campaign=tasks_postlist">\n  <div class="promo-item__wrap">\n    <span class="promo-item__title promo-item__title_hovered">Дизайн сайта о лайф-коучинге и здоровом образе жизни</span>\n    <div class="promo-item__attrs">\n      <span class="promo-item__attrs-item">\n        <span class="promo-item__amount_rur">800 </span>\n        <span class="promo-item__per">за час</span>\n      </span>\n      <span class="promo-item__attrs-item">2 отклика</span>\n      <span class="promo-item__attrs-item">11 просмотров</span>\n    </div>\n  </div>\n</a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="http://freelance.habr.com/tasks/367299" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=task&utm_campaign=tasks_postlist">\n  <div class="promo-item__wrap">\n    <span class="promo-item__title promo-item__title_hovered">Сверстать страницы личного кабинета</span>\n    <div class="promo-item__attrs">\n      <span class="promo-item__attrs-item">\n        <span class="promo-item__amount_rur">5\xa0000 </span>\n        <span class="promo-item__per">за проект</span>\n      </span>\n      <span class="promo-item__attrs-item">5 откликов</span>\n      <span class="promo-item__attrs-item">12 просмотров</span>\n    </div>\n  </div>\n</a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="http://freelance.habr.com/tasks/367297" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=task&utm_campaign=tasks_postlist">\n  <div class="promo-item__wrap">\n    <span class="promo-item__title promo-item__title_hovered">Такси</span>\n    <div class="promo-item__attrs">\n      <span class="promo-item__attrs-item">\n        <span class="promo-item__amount_rur">350\xa0000 </span>\n        <span class="promo-item__per">за проект</span>\n      </span>\n      <span class="promo-item__attrs-item">3 отклика</span>\n      <span class="promo-item__attrs-item">14 просмотров</span>\n    </div>\n  </div>\n</a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="http://freelance.habr.com/tasks/367289" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=task&utm_campaign=tasks_postlist">\n  <div class="promo-item__wrap">\n    <span class="promo-item__title promo-item__title_hovered">Разработать чат-бот для Microsoft Teams</span>\n    <div class="promo-item__attrs">\n      <span class="promo-item__attrs-item">\n        <span class="promo-item__amount_rur">15\xa0000 </span>\n        <span class="promo-item__per">за проект</span>\n      </span>\n      <span class="promo-item__attrs-item">0 откликов</span>\n      <span class="promo-item__attrs-item">10 просмотров</span>\n    </div>\n  </div>\n</a>\n\n            </li>\n            <li class="content-list__item content-list__item_promo">\n              <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'post\'); }" href="http://freelance.habr.com/tasks/367287" class="promo-item" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=task&utm_campaign=tasks_postlist">\n  <div class="promo-item__wrap">\n    <span class="promo-item__title promo-item__title_hovered">Оформить курсовую работу. Java + Spring</span>\n    <div class="promo-item__attrs">\n      <span class="promo-item__attrs-item">\n        <span class="promo-item__amount_rur">7\xa0000 </span>\n        <span class="promo-item__per">за проект</span>\n      </span>\n      <span class="promo-item__attrs-item">1 отклик</span>\n      <span class="promo-item__attrs-item">11 просмотров</span>\n    </div>\n  </div>\n</a>\n\n            </li>\n        </ul>\n      </div>\n    <div class="promo-block__footer">\n      <a onclick="if (typeof ga === \'function\') { if (g_is_ugc_post) { var action = \'freelance_post\' } else {  var action = \'freelance_feed\' } ga(\'send\', \'event\', \'tm_block\', action, \'posts\'); }" href="http://freelance.habr.com/tasks/" class="promo-block__footer-link promo-block__footer-link_selected" data-utm="?utm_source=habr&utm_medium=habr_block&utm_content=tasks_all&utm_campaign=tasks_postlist" target="_blank" rel="nofollow">Больше заказов на Хабр Фрилансе</a>\n    </div>\n  </div>\n</li>\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_556000">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/capissimo/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">capissimo</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 19:35</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/556000/" class="post__title_link">Python, исследование данных и выборы: часть 1</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/python/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Python\'); }">Python</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/programming/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Программирование\'); }">Программирование</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/data_mining/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Data Mining\'); }">Data Mining</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/study/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Учебный процесс в IT\'); }">Учебный процесс в IT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/statistics/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Статистика в IT\'); }">Статистика в IT</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover ">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/1c7/3ce/7ac/1c73ce7ac215107a7b21810d3ebfce74.png"   style="object-position: % %"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Серия из 5 постов <strong>для</strong> <strong>начинающих</strong> представляет собой «ремикс» первой главы книги 2015 года под названием «Clojure для исследования данных» (Clojure for Data Science). Автор книги, Генри Гарнер, любезно дал согласие на использование материалов книги для данного ремикса с использованием языка Python.</p><p>Книга была написана как приглашение в так называемую «науку о данных», которая в последние годы получила сильный импульс к развитию в связи с потребностью в быстрой и своевременной обработке больших наборов данных локально и в распределенной среде.  </p><p>Три главы книги были адаптированы под язык Python в течение следующего года после издания книги, т.е. в 2016 году. Публикация ремикса книги в РФ не получилась по разным причинам, но одна из главных станет понятной в конце этой серии постов. В конце заключительного поста можно будет проголосовать за или против размещения следующей серии постов. А пока же…</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556000/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556000">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 5: &uarr;4 и &darr;1">+3</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" data-id="556000" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">74</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">4,4k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/556000/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">4</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_555998">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/Stedihabr/" class="post__user-info user-info" title="Автор публикации">\n        <span class="default-image_mini default-image_pink">\n          <svg class="icon-svg" width="24" height="24" viewBox="0 0 24 24" aria-hidden="true" version="1.1" role="img"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"/></svg>\n        </span>\n      <span class="user-info__nickname user-info__nickname_small">Stedihabr</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 19:22</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/company/itsoft/blog/555998/" class="post__title_link">Украдено у Apple</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/company/itsoft/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Блог компании ITSOFT\'); }">Блог компании ITSOFT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/history/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'История IT\'); }">История IT</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/antikvariat/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Старое железо\'); }">Старое железо</a>, \n        </li>\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/it_bigraphy/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Биографии гиков\'); }">Биографии гиков</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/e9c/b11/447/e9cb1144709e3b787d77bbe13e0164b1.png"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>В 1980 году компания Franklin Computer выпустила клон Apple II под названием Franklin Ace, разработанный под «яблочное» ПО. Из Apple II скопировали практически все, включая программное обеспечение из ПЗУ и документацию, и продали клон по более низкой цене. Мы даже нашли место в мануале, где забыли поменять «Apple» на «Ace». В Apple пришли в ярость и подали на Franklin в суд. В конце концов мы победили и вынудили Franklin убрать Ace с рынка.  </p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/itsoft/blog/555998/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_corp_ru,c_itsoft,h_21906,h_21930,h_21938" id="infopanel_post_555998">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 35: &uarr;29 и &darr;6">+23</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_corp_ru,c_itsoft,h_21906,h_21930,h_21938" data-type="2" data-id="555998" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">11</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">11k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/company/itsoft/blog/555998/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">9</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_555988">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/Hiro_Protagonist/" class="post__user-info user-info" title="Автор публикации">\n        <span class="default-image_mini default-image_pink">\n          <svg class="icon-svg" width="24" height="24" viewBox="0 0 24 24" aria-hidden="true" version="1.1" role="img"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"/></svg>\n        </span>\n      <span class="user-info__nickname user-info__nickname_small">Hiro_Protagonist</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 18:47</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/555988/" class="post__title_link">Лингвистическая фантастика. Книги, в которых язык больше, чем просто средство для общения</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/sci-fi/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Научная фантастика\'); }">Научная фантастика</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/176/775/b2a/176775b2a73b083fdfb11703c730bbda.jpg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Обычно когда речь идет про «научную фантастику», то наукой, которая лежит в основе сюжетов выступают физика, биология, может, компьютерные технологии. Что-то из области точных наук. Но некоторые фантасты не спешат идти проторенными путями, предпочитая удивлять читателя. Например, обращаясь к лингвистике и показывая миры или конфликты, в которых слово играет ключевую роль.&nbsp;</p><p>Очень приятно знакомиться с изобретательными способами показать, что речь — это инструмент, причем весьма функциональный и пластичный. На тему необычных языковых систем, вопросов взаимопонимания и того, как слово может влиять на человека (и не только) можно сказать не меньше интересных вещей, чем по поводу искусственного интеллекта или терраформирования Марса. Вот несколько тому примеров.</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/555988/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_21984" id="infopanel_post_555988">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 34: &uarr;32 и &darr;2">+30</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_21984" data-type="2" data-id="555988" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">135</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">14,7k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/555988/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">23</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n              <li class="content-list__item content-list__item_post shortcuts_item" id="post_555934">\n                \n    <article class="post post_preview" lang="ru">\n  <header class="post__meta">\n    <a href="https://habr.com/ru/users/biolog_snork/" class="post__user-info user-info" title="Автор публикации">\n        <img src="//habrastorage.org/getpro/habr/avatars/359/2e8/8a7/3592e88a7977d3df342bbcdff9e52244.jpg" width="24" height="24" class="user-info__image-pic user-info__image-pic_small">\n      <span class="user-info__nickname user-info__nickname_small">biolog_snork</span>\n    </a>\n\n    <span class="post__time">5 мая 2021 в 18:43</span>\n\n  </header>\n\n  <h2 class="post__title">\n    <a href="https://habr.com/ru/post/555934/" class="post__title_link">Страшные волосатики, или посмертный кошмар кузнечика</a>\n  </h2>\n\n    <ul class="post__hubs inline-list">\n        <li class="inline-list__item inline-list__item_hub">\n          <a href="https://habr.com/ru/hub/popular_science/" class="inline-list__item-link hub-link " rel="nofollow" title="Вы не подписаны на этот хаб" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'hub\', \'feed page\', \'Научно-популярное\'); }">Научно-популярное</a>\n        </li>\n    </ul>\n\n  <ul class="post__marks inline-list"></ul>\n\n  <div class="post__body post__body_crop">\n    <div class="post__body-cover post__body-cover_fit-cover">\n      <img src="https://habrastorage.org/getpro/habr/upload_files/8d6/48d/c7e/8d648dc7e3d596d8b2ae7138a7ac1fc7.jpg"   style="object-position: 0% 0%"  />\n    </div> \n    <div class="post__text post__text-html  post__text_v2 ">\n      <p>Волосатики — это тип, как правило, паразитоидных животных клады нематоид. Данные существа являются очень милыми свободно живущими червячками внешне похожими на нематод. Правда свободно живущими они являются только на взрослой стадии развития, потому-то их и называют паразитоидами.&nbsp;</p>\n    </div>\n    \n    <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/555934/#habracut">Читать далее</a>\n  </div>\n\n  \n\n  <footer class="post__footer">\n      <ul class="post-stats  js-user_" data-post-type="publish_ugc_ru,h_21910" id="infopanel_post_555934">\n      <li class="post-stats__item">\n          <div class="post-stats__result">\n\n              <span class="post-stats__result-icon">\n                <svg class="icon-svg_votes" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating" /></svg>\n              </span>\n\n            <span class="post-stats__result-counter voting-wjt__counter_positive " title="Всего голосов 26: &uarr;23 и &darr;3">+20</span>\n          </div>\n      </li>\n    <li class="post-stats__item post-stats__item_bookmark">\n      <button type="button" class="btn bookmark-btn bookmark-btn_post " data-post-type="publish_ugc_ru,h_21910" data-type="2" data-id="555934" data-action="add" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" onclick="posts_add_to_favorite(this);" disabled>\n        <span class="btn_inner"><svg class="icon-svg_bookmark" width="10" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>\n      </button>\n    </li>\n\n    <li class="post-stats__item post-stats__item_views">\n      <div class="post-stats__views" title="Количество просмотров">\n        <svg class="icon-svg_views-count" width="21" height="12"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-stats__views-count">7,2k</span>\n      </div>\n    </li>\n\n      <li class="post-stats__item post-stats__item_comments">\n          <a href="https://habr.com/ru/post/555934/#comments" class="post-stats__comments-link" rel="nofollow">\n            <svg class="icon-svg_post-comments" width="16" height="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">10</span>\n          </a>\n      </li>\n\n\n\n\n\n\n\n\n  </ul>\n\n  </footer>\n</article>\n\n\n              </li>\n\n\n\n\n\n\n\n          </ul>\n            <div class="page__footer">\n    <ul class="arrows-pagination">\n\n        <li class="arrows-pagination__item">\n          \n            <a title="На страницу назад (Alt + &larr;)" class="arrows-pagination__item-link arrows-pagination__item-link_prev" id="previous_page" href="/ru/all/page49/" rel="">&larr;&nbsp;<span>сюда</span></a>\n          \n        </li>\n\n        <li class="arrows-pagination__item">\n          <span class="arrows-pagination__item-link">туда&nbsp;&rarr;</span>\n        </li>\n\n    </ul>\n\n    <ul class="toggle-menu toggle-menu_pagination" id="nav-pagess">\n        <li class="toggle-menu__item toggle-menu__item_pagination">\n          \n            <a href="/ru/all/" class="toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_bordered" title="Первая страница" rel="">\n                <span class="icon-svg icon-svg_arrow-first"><svg class="icon-svg" width="28" height="24" viewBox="0 0 28 24"><path d="M8.452 5.455l2.93 3.192c.89.969 1.335 1.361 2.225 1.909h-13.608v2.773h13.634c-.838.5-1.492 1.102-2.252 1.913l-2.93 3.192 2.276 1.964 7.588-8.452-7.588-8.452-2.276 1.961zM24.297 0h3.087v23.891h-3.087v-23.891z"/></svg>\n</span>\n            </a>\n          \n        </li>\n\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page43/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >43</a>\n            \n          </li>\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page44/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >44</a>\n            \n          </li>\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page45/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >45</a>\n            \n          </li>\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page46/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >46</a>\n            \n          </li>\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page47/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >47</a>\n            \n          </li>\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page48/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >48</a>\n            \n          </li>\n\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            \n              <a href="/ru/all/page49/" class="toggle-menu__item-link toggle-menu__item-link_pagination" >49</a>\n            \n          </li>\n          <li class="toggle-menu__item toggle-menu__item_pagination">\n            <span class="toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_active">50</span>\n          </li>\n\n\n    </ul>\n  </div>\n\n\n        \n      </div>\n    </div>\n    <div class="sidebar">\n      <div class="sidebar_right_ad">\n        <!-- /235032688/HH/HH01_ATF_Poster -->\n<div class="dfp-slot dfp-slot_top is_visible">\n  <a href="https://tmtm.ru/services/advertising/" target="_blank" class="dfp-slot__label">Реклама</a>\n<div class="dfp-slot__placeholder">\n  <span class="dfp-slot__placeholder-text">Баннер исчез, и под ним проявились пиктограммы от НЛО <a href="https://u.habr.com/msb21_ab" class="btn btn_large btn_blue" style="display:inline-flex!important;" target="_blank">Посмотреть</a></span>\n</div>\n\n\n  <div class="dfp-slot__banner" id="div-gpt-hh-atf">\n    <script>\n      window.display_dfp_slot(\'div-gpt-hh-atf\');\n    </script>\n  </div>\n</div>\n\n      </div>\n        <div class="sidebar_right sidebar_content-area js-sidebar_right">\n          <div class="default-block default-block_sidebar" id="companies_rating">\n  <div class="default-block__header">\n    <h3 class="default-block__header-title">Лучшие компании</h3>\n  </div>\n\n  <div class="default-block__content companies-rating">\n    <ul class="companies-rating__list">\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/ruvds/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/f27/ea8/5bd/f27ea85bd62fbd985c308110885af7e0.png" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/ruvds/">RUVDS.com</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">4\xa0025,63</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/selectel/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/66a/f7d/039/66af7d03979b6d18654293d8f1e72837.png" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/selectel/">Selectel</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">3\xa0166,75</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/macloud/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/762/a3f/7f5/762a3f7f5d8dd06a124724495e436a14.png" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/macloud/">Маклауд</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">2\xa0810,91</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/vdsina/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/349/b75/e68/349b75e680748f727261c7de1a4e1c5f.png" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/vdsina/">VDSina.ru</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">2\xa0040,99</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/itsoft/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/f48/d46/029/f48d460297f1a9fe1a9e3e0a1e7aedc9.png" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/itsoft/">ITSOFT</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">723,26</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/timeweb/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/f16/9bf/2f9/f169bf2f9f64895ed94992d0d15e98fc.jpg" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/timeweb/">Timeweb</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">683,19</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/flipperdevices/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/595/777/b2c/595777b2c329a0b31b848c2a755e7df8.jpg" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/flipperdevices/">Flipper Devices Inc.</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">629,24</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/tuturu/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/d22/183/e95/d22183e95aa359a4bfa126050940009c.jpg" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/tuturu/">Туту.ру</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">603,49</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/otus/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/habr/company/968/422/761/968422761136a38a89fc391fd927f903.jpg" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/otus/">OTUS</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">549,48</span>\n        </div>\n      </li>\n      <li class="companies-rating__item">\n        <div class="companies-rating__body">\n          <a class="companies-rating__avatar" href="/company/lamptest/">\n              <img class="companies-rating__img" src="//habrastorage.org/getpro/geektimes/company/faa/8f3/29f/faa8f329f54ab8821c7f2d1459ec2bda.jpg" width="32" height="32" role="img" />\n          </a>\n          <a class="companies-rating__name" href="/company/lamptest/">LampTest</a>\n        </div>\n\n        <div class="companies-rating__meta">\n          <span class="companies-rating__rating">537,02</span>\n        </div>\n      </li>\n    </ul>\n  </div>\n\n  <div class="default-block__footer">\n    <a href="/companies/" class="default-block__footer-link" rel="nofollow">Все компании</a>\n  </div>\n</div>\n\n          \n            \n\n  <div class="default-block default-block_sidebar" id="most-reading">\n    <div class="default-block__header">\n      <h3 class="default-block__header-title">Читают сейчас</h3>\n    </div>\n\n      <div class="default-block__content default-block__content_most-read" id="broadcast_most-read">\n            <ul class="content-list content-list_most-read">\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558858/" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'post\'); }">Как меня чуть не уволили из-за токсичного поведения и что было дальше</a>\n                <div class="post-info__meta">\n                  <span class="post-info__meta-item" title="Количество просмотров">\n                    <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter post-info__meta-counter_small">21,1k</span>\n                  </span>\n                    <a onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'comment\'); }" href="https://habr.com/ru/post/558858/#comments" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg>\n                      <span class="post-info__meta-counter post-info__meta-counter_small">\n                        101\n                        \n                      </span>\n                    </a>\n                </div>\n              </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/vdsina/blog/558912/" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'post\'); }">Apple превращается в ещё одну Microsoft</a>\n                <div class="post-info__meta">\n                  <span class="post-info__meta-item" title="Количество просмотров">\n                    <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter post-info__meta-counter_small">4,8k</span>\n                  </span>\n                    <a onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'comment\'); }" href="https://habr.com/ru/company/vdsina/blog/558912/#comments" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg>\n                      <span class="post-info__meta-counter post-info__meta-counter_small">\n                        8\n                        \n                      </span>\n                    </a>\n                </div>\n              </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558828/" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'post\'); }">Следует ли мне бросить видеоигры?</a>\n                <div class="post-info__meta">\n                  <span class="post-info__meta-item" title="Количество просмотров">\n                    <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter post-info__meta-counter_small">38,8k</span>\n                  </span>\n                    <a onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'comment\'); }" href="https://habr.com/ru/post/558828/#comments" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg>\n                      <span class="post-info__meta-counter post-info__meta-counter_small">\n                        322\n                        \n                      </span>\n                    </a>\n                </div>\n              </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/vdsina/blog/558220/" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'post\'); }">Пиринговые мессенджеры\xa0— враг государства?</a>\n                <div class="post-info__meta">\n                  <span class="post-info__meta-item" title="Количество просмотров">\n                    <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter post-info__meta-counter_small">8,9k</span>\n                  </span>\n                    <a onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'comment\'); }" href="https://habr.com/ru/company/vdsina/blog/558220/#comments" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg>\n                      <span class="post-info__meta-counter post-info__meta-counter_small">\n                        35\n                        \n                      </span>\n                    </a>\n                </div>\n              </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/news/t/558888/" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'post\'); }">Google подала иск против Роскомнадзора</a>\n                <div class="post-info__meta">\n                  <span class="post-info__meta-item" title="Количество просмотров">\n                    <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter post-info__meta-counter_small">12,2k</span>\n                  </span>\n                    <a onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'comment\'); }" href="https://habr.com/ru/news/t/558888/#comments" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg>\n                      <span class="post-info__meta-counter post-info__meta-counter_small">\n                        39\n                        \n                      </span>\n                    </a>\n                </div>\n              </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558864/" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'post\'); }">Недорогая видеостена на 8 мониторов (спойлер — NVidia)</a>\n                <div class="post-info__meta">\n                  <span class="post-info__meta-item" title="Количество просмотров">\n                    <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter post-info__meta-counter_small">22,6k</span>\n                  </span>\n                    <a onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'comment\'); }" href="https://habr.com/ru/post/558864/#comments" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg>\n                      <span class="post-info__meta-counter post-info__meta-counter_small">\n                        64\n                        \n                      </span>\n                    </a>\n                </div>\n              </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://u.habr.com/honormb15_chitayut" class="post-info__title" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'read_now,feed\', \'https://u.habr.com/honormb15_chitayut\'); }">Ноут для студента-программиста: обзор</a>\n                  <div class="post-info__meta-label">\n                    Мегапост\n                  </div>\n              </li>\n          </ul>\n    </div>\n  </div>\n\n\n        </div>\n    </div>\n  </section>\n\n  <div class="overlay hidden" id="js-vote-result">\n  <div class="popup popup_reasons">\n    <div class="popup__head">\n      <span class="popup__head-title js-result-popup_title"></span>\n      <button type="button" class="btn btn_small btn_popup-close js-hide_result-reason">\n        <svg class="icon-svg" width="12" height="12">\n          <use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#close" />\n        </svg>\n      </button>\n    </div>\n    <div class="popup__body">\n      <div class="js-reasons-vote_result-empty">Пока никто не указал причину минусов</div>\n      <div class="js-reasons-vote_result-content">\n        <div class="reasons-vote__title">Причины минусов</div>\n        <div id="js-result-popup_list"></div>\n      </div>\n    </div>\n  </div>\n</div>\n\n\n\n        </div>\n      </div>\n\n        <div class="layout__row layout__row_promo-blocks">\n          <div class="layout__cell">\n              <section class="column-wrapper column-wrapper_bottom column-wrapper_bordered">\n    <div class="content_left">\n      \n\n\n  <div class="default-block default-block_content">\n    <div class="default-block__header default-block__header_large">\n      <h2 class="default-block__header-title default-block__header-title_large">Самое читаемое</h2>\n    </div>\n    <div class="default-block__content default-block__content_most-read" id="broadcast_tabs_posts">\n      <ul class="toggle-menu toggle-menu__most-read">\n        <li class="toggle-menu__item">\n          <a href="#broadcast_posts_today" class="toggle-menu__item-link active" rel="nofollow">Сутки</a>\n        </li>\n        <li class="toggle-menu__item">\n          <a href="#broadcast_posts_week" class="toggle-menu__item-link" rel="nofollow">Неделя</a>\n        </li>\n        <li class="toggle-menu__item">\n          <a href="#broadcast_posts_month" class="toggle-menu__item-link" rel="nofollow">Месяц</a>\n        </li>\n      </ul>\n\n        <div class="tabs__content tabs__content_reading" id="broadcast_posts_today">\n            <ul class="content-list content-list_most-read">\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558828/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Следует ли мне бросить видеоигры?</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;41</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">38,8k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">91</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/558828/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        322\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558864/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Недорогая видеостена на 8 мониторов (спойлер — NVidia)</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;56</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">22,6k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">56</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/558864/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        64\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558858/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Как меня чуть не уволили из-за токсичного поведения и что было дальше</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;114</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">21,1k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">56</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/558858/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        101\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/558866/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Спросите Итана: по какой фундаментальной причине E = mc²?</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;10</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">13,7k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">45</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/558866/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        26\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                <a href="https://u.habr.com/rt_chitayut" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'https://u.habr.com/rt_chitayut\'); }">Ракеты и снаряды дата-инженеров</a>\n                <div class="post-info__meta-label">\n                  Подборка\n                </div>\n              </li>\n            </ul>\n        </div>\n        <div class="tabs__content tabs__content_reading" id="broadcast_posts_week">\n            <ul class="content-list content-list_most-read">\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/itsoft/blog/557504/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Банки ультимативно лезут к нам в ш̶т̶а̶н̶ы̶ личную жизнь</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;181</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">102k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">120</span>\n                    </span>\n                    <a href="https://habr.com/ru/company/itsoft/blog/557504/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        398\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/itsoft/blog/558124/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Почему мир скоро может остаться без бананов</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;127</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">70,5k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">77</span>\n                    </span>\n                    <a href="https://habr.com/ru/company/itsoft/blog/558124/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        251\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/ruvds/blog/556124/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Как Unix-way убивает десктопный Linux</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;202</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">59,4k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">183</span>\n                    </span>\n                    <a href="https://habr.com/ru/company/ruvds/blog/556124/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        1613\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/dcmiran/blog/557708/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Ребята взломали машину для мороженого\xa0— и начали холодную войну с её производителем</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;74</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">58,9k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">50</span>\n                    </span>\n                    <a href="https://habr.com/ru/company/dcmiran/blog/557708/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        222\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                <a href="https://u.habr.com/yprfs" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'https://u.habr.com/yprfs\'); }">Работа для грустных: как выражение лица влияет на успех соискателя</a>\n                <div class="post-info__meta-label">\n                  Турбо\n                </div>\n              </li>\n            </ul>\n        </div>\n        <div class="tabs__content tabs__content_reading" id="broadcast_posts_month">\n            <ul class="content-list content-list_most-read">\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/553752/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Как рекламщики уничтожили электронную почту, и что сейчас они делают с мобильной связью</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;168</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">189k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">94</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/553752/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        752\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/554810/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Все английские времена в одной простой схеме</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;61</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">159k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">764</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/554810/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        124\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/company/vdsina/blog/555474/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Как я обогреваю свой дом при помощи майнинга криптовалют</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;50</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">112k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">124</span>\n                    </span>\n                    <a href="https://habr.com/ru/company/vdsina/blog/555474/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        107\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n                <li class="content-list__item content-list__item_devided post-info">\n                  <a href="https://habr.com/ru/post/555884/" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'post\'); }">Что недоговаривают Тинькофф Инвестиции. Вытаскиваем все данные по портфелю через API в большую таблицу Excel</a>\n                  <div class="post-info__meta">\n                    <span class="post-info__meta-item" title="Рейтинг">\n                      <svg class="post-info__meta-icon icon-svg_rating" width="11" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold" /></svg><span class="post-info__meta-counter">&plus;148</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Количество просмотров">\n                      <svg class="post-info__meta-icon icon-svg_views" width="16" height="9"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye" /></svg><span class="post-info__meta-counter">111k</span>\n                    </span>\n                    <span class="post-info__meta-item" title="Закладки">\n                      <svg class="post-info__meta-icon icon-svg_bookmark-mini" width="8" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book" /></svg><span class="post-info__meta-counter">489</span>\n                    </span>\n                    <a href="https://habr.com/ru/post/555884/#comments" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'comment\'); }" class="post-info__meta-item" rel="nofollow" title="Комментарии">\n                      <svg class="post-info__meta-icon icon-svg_comments" width="14" height="13"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment" /></svg><span class="post-info__meta-counter">\n                        104\n                        \n                      </span>\n                    </a>\n                  </div>\n                </li>\n              <li class="content-list__item content-list__item_devided post-info">\n                <a href="https://u.habr.com/eduonline_chitayut" class="post-info__title post-info__title_large" onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\',  \'most_read,feed\' , \'https://u.habr.com/eduonline_chitayut\'); }">Я бросила учёбу, падре! Как мы учимся онлайн</a>\n                <div class="post-info__meta-label">\n                  Мегапост\n                </div>\n              </li>\n            </ul>\n        </div>\n    </div>\n  </div>\n\n    </div>\n\n    <div class="sidebar">\n      <div class="sidebar_right">\n        <div class="content-list__item content-list__item_post shortcuts_item" id="effect-sidebar" style="display: none;">\n   <div class="default-block">\n    <div class="default-block__header">\n      <h2 class="default-block__header-title">Минуточку внимания</h2>\n    </div>\n    <div class="default-block__content">\n      <ul class="megapost-teasers" id="megapost-teasers-sidebar">\n\n      </ul>\n    </div>\n  </div>\n</div>\n      </div>\n    </div>\n  </section>\n\n          </div>\n        </div>\n\n      <div class="layout__row layout__row_footer-links">\n        <div class="layout__cell">\n          <div class="footer-grid footer-grid_menu">\n  <div class="footer-grid__item footer-block">\n    <h3 class="footer-block__title">\n      Ваш аккаунт\n    </h3>\n    <div class="footer-block__content">\n      <ul class="footer-menu">\n          <li class="footer-menu__item">\n            <a href="https://habr.com/ru/auth/login/" class="footer-menu__item-link">Войти</a>\n          </li>\n          <li class="footer-menu__item">\n            <a href="https://habr.com/ru/auth/register/" class="footer-menu__item-link">Регистрация</a>\n          </li>\n      </ul>\n    </div>\n  </div>\n\n  <div class="footer-grid__item footer-block">\n    <h3 class="footer-block__title">Разделы</h3>\n    <div class="footer-block__content">\n      <ul class="footer-menu">\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/posts/top/" class="footer-menu__item-link">Публикации</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/news/" class="footer-menu__item-link">Новости</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/hubs/" class="footer-menu__item-link">Хабы</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/companies/" class="footer-menu__item-link">Компании</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/users/" class="footer-menu__item-link">Пользователи</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/sandbox/" class="footer-menu__item-link">Песочница</a>\n        </li>\n      </ul>\n    </div>\n  </div>\n\n  <div class="footer-grid__item footer-block">\n    <h3 class="footer-block__title">Информация</h3>\n    <div class="footer-block__content">\n      <ul class="footer-menu">\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/docs/help/" class="footer-menu__item-link">Устройство сайта</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/docs/authors/" class="footer-menu__item-link">Для авторов</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/docs/companies/" class="footer-menu__item-link">Для компаний</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/docs/docs/" class="footer-menu__item-link">Документы</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://account.habr.com/info/agreement/?hl=ru_RU" class="footer-menu__item-link">Соглашение</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://account.habr.com/info/confidential/?hl=ru_RU" class="footer-menu__item-link">Конфиденциальность</a>\n        </li>\n      </ul>\n    </div>\n  </div>\n\n  <div class="footer-grid__item footer-block">\n    <h3 class="footer-block__title">Услуги</h3>\n    <div class="footer-block__content">\n      <ul class="footer-menu">\n        <li class="footer-menu__item">\n          <a href="https://tmtm.ru/services/advertising/" target="_blank" class="footer-menu__item-link">Реклама</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://tmtm.ru/services/corpblog/" target="_blank" class="footer-menu__item-link">Тарифы</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://tmtm.ru/services/content/" target="_blank" class="footer-menu__item-link">Контент</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://tmtm.ru/workshops/" target="_blank" class="footer-menu__item-link">Семинары</a>\n        </li>\n        <li class="footer-menu__item">\n          <a href="https://habr.com/ru/megaprojects/" target="_blank" class="footer-menu__item-link">Мегапроекты</a>\n        </li>\n      </ul>\n    </div>\n  </div>\n</div>\n\n\n        </div>\n      </div>\n\n      <div class="layout__row layout__row_footer">\n        <div class="layout__cell">\n          <script>\n  $(document).ready(function () {\n    window.voteReasonsList = JSON.parse(\'{"1":{"id":"1","title":"Низкий технический уровень материала","order":1},"2":{"id":"2","title":"Больше рекламы, чем пользы","order":2},"3":{"id":"3","title":"Не соответствует тематике Хабра","order":3},"4":{"id":"4","title":"В тексте много ошибок и опечаток","order":4},"5":{"id":"5","title":"Пост небрежно оформлен","order":5},"6":{"id":"6","title":"Личная неприязнь к автору или компании","order":6},"7":{"id":"7","title":"В статье нет новой для меня информации","order":7},"8":{"id":"8","title":"Ничего не понял после прочтения","order":8},"22":{"id":"22","title":"Не согласен с изложенным","order":9},"9":{"id":"9","title":"Другое","order":10}}\');\n  });\n</script>\n<script>\n\n$(document).on(\'hljsUpdate\', function () {\n  if (typeof hljs === \'undefined\') {\n    initHighlightJS();\n  } else {\n    $(\'pre code\').each(function (i, e) {\n      hljs.highlightBlock(e, \'    \');\n    });\n  }\n})\n\nfunction createScript(url) {\n  var hljsScript = document.createElement("script");\n  hljsScript.src = url;\n  hljsScript.type = \'text/javascript\';\n  document.body.appendChild(hljsScript)\n\n  return hljsScript;\n}\n\nfunction initHighlightJS() {\n  if (typeof hljs !== \'undefined\') {\n    $(\'pre code\').each(function (i, e) {\n      hljs.highlightBlock(e, \'    \');\n    });\n    return;\n  };\n\n  var hljsScript = createScript(\'https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/highlight.pack.js\');\n\n  hljsScript.onload = function() {\n    var hljsLangs = createScript(\'https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/highlight.langs.js\');\n    hljsLangs.onload = function () {\n      hljs.initHighlighting();\n    }\n  }\n}\n\n\nvar codeElements = document.querySelectorAll(\'pre code\');\n\nif (codeElements.length) {\n  initHighlightJS();\n}\n\n</script>\n\n<script>\n\nvar mathElements = document.getElementsByTagName(\'math\');\n\nfunction mathJaxConfig() {\n  MathJax.Hub.Config({\n    showProcessingMessages: false,\n    showMathMenu: true,\n    tex2jax: {\n      inlineMath: [[\'$inline$\',\'$inline$\']],\n      displayMath: [[\'$$display$$\',\'$$display$$\']],\n      processEscapes: true\n    },\n    MathMenu: {\n      showRenderer: true,\n      showContext:  true\n    }\n  });\n\n  MathJax.Extension.Img2jax = {\n    PreProcess: function (element) {\n      var hasMath = false;\n      var images = element.querySelectorAll(\'[data-tex]\');\n      for (var i = images.length - 1; i >= 0; i--) {\n        var img = images[i];\n        var tex = img.alt.replace(/(\\r\\n|\\n|\\r)/gm, " ");\n        if (tex && tex[0] === \'$\'){\n          var script = document.createElement("script"); script.type = "math/tex";\n          hasMath = true;\n          if (img.getAttribute(\'data-tex\') == "display"){script.type += ";mode=display"}\n          MathJax.HTML.setScript(script, tex.substring(1,tex.length-1));\n          img.parentNode.replaceChild(script,img);\n        }\n      }\n    }\n  };\n\n  MathJax.Hub.Register.PreProcessor(["PreProcess", MathJax.Extension.Img2jax]);\n}\n\nfunction mathjaxInit() {\n if (typeof MathJax === \'undefined\') {\n    var url = \'https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.1/MathJax.js?config=TeX-AMS_SVG-full&locale=ru\';\n    var mathScript = document.createElement("script");\n    mathScript.src = url;\n    mathScript.type = \'text/javascript\';\n    document.body.appendChild(mathScript)\n\n    mathScript.onload = function() {\n      mathJaxConfig();\n    }\n  } else {\n    mathJaxConfig();\n  }\n}\n\nif (mathElements.length) {\n  mathjaxInit();\n}\n\n</script>\n<div class="footer-grid footer">\n  <div class="footer-grid__item footer-grid__item_copyright">\n    <span class="footer__copyright">&copy; 2006 &ndash; 2021 «<a href="https://company.habr.com/" class="footer__link">Habr</a>»</span>\n  </div>\n  <div class="footer-grid__item footer-grid__item_link footer-grid__item_lang">\n    <svg class="icon-svg icon-svg_lang-footer" width="16" height="16">\n      <use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#globus-v2" />\n    </svg>\n    <a href="#" class="footer__link js-show_lang_settings">Настройка языка</a>\n  </div>\n  <div class="footer-grid__item footer-grid__item_link">\n      <a href="https://habr.com/ru/about/" class="footer__link">О сайте</a>\n  </div>\n  <div class="footer-grid__item footer-grid__item_link">\n    <a href="https://habr.com/ru/feedback/" class="footer__link">Служба поддержки</a>\n  </div>\n  <div class="footer-grid__item footer-grid__item_link">\n      <a href="https://m.habr.com/ru?mobile=yes" class="footer__link">Мобильная версия</a>\n  </div>\n\n  <div class="footer-grid__item footer-grid__item_social">\n    <ul class="social-icons">\n      <li class="social-icons__item">\n        <a href="https://twitter.com/habr_com"\n          class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_twitter"\n          target="_blank"\n          rel="nofollow noopener noreferrer"\n          onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'footer\', \'Social_icons\', \'twitter\'); }"\n        >\n          <svg class="icon-svg" aria-hidden="true" aria-labelledby="title" version="1.1" role="img" width="24" height="24" viewBox="0 0 24 24"><path d="M17.414 8.642c-.398.177-.826.296-1.276.35.459-.275.811-.71.977-1.229-.43.254-.905.439-1.41.539-.405-.432-.982-.702-1.621-.702-1.227 0-2.222.994-2.222 2.222 0 .174.019.344.058.506-1.846-.093-3.484-.978-4.579-2.322-.191.328-.301.71-.301 1.117 0 .77.392 1.45.988 1.849-.363-.011-.706-.111-1.006-.278v.028c0 1.077.766 1.974 1.782 2.178-.187.051-.383.078-.586.078-.143 0-.282-.014-.418-.04.282.882 1.103 1.525 2.075 1.542-.76.596-1.718.951-2.759.951-.179 0-.356-.01-.53-.031.983.63 2.15.998 3.406.998 4.086 0 6.321-3.386 6.321-6.321l-.006-.287c.433-.314.81-.705 1.107-1.15z"/></svg>\n        </a>\n      </li>\n      <li class="social-icons__item">\n        <a href="https://www.facebook.com/habrahabr.ru"\n          class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_facebook"\n          target="_blank"\n          rel="nofollow noopener noreferrer"\n          onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'footer\', \'Social_icons\', \'facebook\'); }"\n        >\n          <svg class="icon-svg" aria-hidden="true" aria-labelledby="title" version="1.1" role="img" width="24" height="24" viewBox="0 0 24 24"><path d="M14.889 8.608h-1.65c-.195 0-.413.257-.413.6v1.192h2.063v1.698h-2.063v5.102h-1.948v-5.102h-1.766v-1.698h1.766v-1c0-1.434.995-2.6 2.361-2.6h1.65v1.808z"/></svg>\n        </a>\n      </li>\n        <li class="social-icons__item">\n          <a href="https://vk.com/habr"\n            class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_vkontakte"\n            target="_blank"\n            rel="nofollow noopener noreferrer"\n            onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'footer\', \'Social_icons\', \'vkontakte\'); }"\n          >\n            <svg class="icon-svg" aria-hidden="true" aria-labelledby="title" version="1.1" role="img" width="24" height="24" viewBox="0 0 24 24"><path d="M16.066 11.93s1.62-2.286 1.782-3.037c.054-.268-.064-.418-.343-.418h-1.406c-.322 0-.44.139-.537.343 0 0-.76 1.619-1.685 2.64-.297.33-.448.429-.612.429-.132 0-.193-.11-.193-.408v-2.607c0-.365-.043-.472-.343-.472h-2.254c-.172 0-.279.1-.279.236 0 .343.526.421.526 1.352v1.921c0 .386-.022.537-.204.537-.483 0-1.631-1.663-2.274-3.552-.129-.386-.268-.494-.633-.494h-1.406c-.204 0-.354.139-.354.343 0 .375.44 2.114 2.167 4.442 1.159 1.566 2.683 2.414 4.056 2.414.838 0 1.041-.139 1.041-.494v-1.202c0-.301.118-.429.29-.429.193 0 .534.062 1.33.848.945.901 1.01 1.276 1.525 1.276h1.578c.161 0 .311-.075.311-.343 0-.354-.462-.987-1.17-1.738-.29-.386-.762-.805-.912-.998-.215-.226-.151-.354-.001-.59z"/></svg>\n          </a>\n        </li>\n      <li class="social-icons__item">\n        <a href="https://telegram.me/habr_com"\n          class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_telegram"\n          target="_blank"\n          rel="nofollow noopener noreferrer"\n          onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'footer\', \'Social_icons\', \'telegram\'); }"\n        >\n          <svg class="icon-svg" aria-hidden="true" aria-labelledby="title" version="1.1" role="img" width="24" height="24" viewBox="0 0 24 24"><path d="M17.17 7.621l-10.498 3.699c-.169.059-.206.205-.006.286l2.257.904 1.338.536 6.531-4.796s.189.057.125.126l-4.68 5.062-.27.299.356.192 2.962 1.594c.173.093.397.016.447-.199.058-.254 1.691-7.29 1.728-7.447.047-.204-.087-.328-.291-.256zm-6.922 8.637c0 .147.082.188.197.084l1.694-1.522-1.891-.978v2.416z"/></svg>\n        </a>\n      </li>\n        <li class="social-icons__item">\n          <a href="https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w"\n            class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_youtube"\n            target="_blank"\n            rel="nofollow noopener noreferrer"\n            onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'footer\', \'Social_icons\', \'youtube\'); }"\n          >\n            <svg class="icon-svg" aria-hidden="true" aria-labelledby="title" version="1.1" role="img" width="32" height="32" viewBox="0 0 32 32"><path d="M3.2 0h25.6c1.767 0 3.2 1.433 3.2 3.2v25.6c0 1.767-1.433 3.2-3.2 3.2h-25.6c-1.767 0-3.2-1.433-3.2-3.2v-25.6c0-1.767 1.433-3.2 3.2-3.2zm18.133 16l-10.667-5.333v10.667l10.667-5.333z"/></svg>\n\n          </a>\n        </li>\n        <li class="social-icons__item">\n          <a href="https://zen.yandex.ru/habr"\n            class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_zen"\n            target="_blank"\n            rel="nofollow noopener noreferrer"\n            onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'footer\', \'Social_icons\', \'zen\'); }"\n          >\n            <svg width="30" height="30" viewBox="0 0 30 30" fill="none" xmlns="http://www.w3.org/2000/svg">\n    <rect width="30" height="30" rx="3" fill="#2C3036"/>\n    <path fill-rule="evenodd" clip-rule="evenodd" d="M26.25 15.1241V14.9998V14.8759C21.2684 14.7252 18.9904 14.6009 17.1735 12.8263C15.3994 11.0098 15.2747 8.73179 15.1243 3.75H15H14.8757C14.7253 8.73179 14.6006 11.0098 12.8264 12.8263C11.0095 14.6009 8.73151 14.7252 3.75 14.8759V14.9998V15.1241C8.73151 15.2748 11.0095 15.3991 12.8264 17.1733C14.6006 18.9903 14.7253 21.2682 14.8757 26.25H15H15.1243C15.2747 21.2682 15.3994 18.9903 17.1735 17.1733C18.9904 15.3991 21.2684 15.2748 26.25 15.1241Z" fill="white"/>\n</svg>\n\n          </a>\n        </li>\n    </ul>\n  </div>\n</div>\n\n        </div>\n      </div>\n\n      <a href="#" class="layout__elevator hidden" id="scroll_to_top" title="Наверх"  onclick="if (typeof ga === \'function\') { ga(\'send\', \'event\', \'navigation_button\', \'down\'); }">\n        <svg class="icon-svg icon-svg_scroll-up" width="32" height="32" viewBox="0 0 32 32" aria-hidden="true" version="1.1" role="img"><path d="M16 0C7.164 0 0 7.164 0 16s7.164 16 16 16 16-7.164 16-16S24.836 0 16 0zm8.412 19.523c-.517.512-1.355.512-1.872 0L16 13.516l-6.54 6.01c-.518.51-1.356.51-1.873 0-.516-.513-.517-1.343 0-1.855l7.476-7.326c.517-.512 1.356-.512 1.873 0l7.476 7.327c.516.513.516 1.342 0 1.854z"/></svg>\n      </a>\n    </div>\n\n    <div class="overlay hidden" id="js-lang_settings">\n  <div class="popup">\n    <div class="popup__head popup__head_lang-settings">\n      <span class="popup__head-title js-popup_title" data-section="1">Настройка языка</span>\n      <button type="button" class="btn btn_small btn_popup-close js-hide_lang_settings">\n        <svg class="icon-svg" width="12" height="12">\n          <use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#close" />\n        </svg>\n      </button>\n    </div>\n    <div class="popup__body">\n      <form action="/json/settings/i18n/" method="post" class="form form_lang-settings" id="lang-settings-form">\n        <fieldset class="form__fieldset form__fieldset_thin" data-section="2">\n          <legend class="form__legend form__legend_lang-settings js-popup_hl_legend">Интерфейс</legend>\n            <div class="form-field form-field_lang-settings">\n              <span class="radio radio_custom ">\n                <input type="radio" name="hl" id="hl_langs_ru" class="radio__input js-hl_langs" value="ru" checked>\n                <label for="hl_langs_ru" class="radio__label radio__label_another">Русский</label>\n              </span>\n            </div>\n            <div class="form-field form-field_lang-settings">\n              <span class="radio radio_custom ">\n                <input type="radio" name="hl" id="hl_langs_en" class="radio__input js-hl_langs" value="en" >\n                <label for="hl_langs_en" class="radio__label radio__label_another">English</label>\n              </span>\n            </div>\n        </fieldset>\n\n        <fieldset class="form__fieldset form__fieldset_thin">\n          <legend class="form__legend form__legend_lang-settings js-popup_fl_legend" data-section="3">Язык публикаций</legend>\n            <div class="form-field form-field_lang-settings">\n              <span class="checkbox checkbox_custom">\n                <input type="checkbox" name="fl[]" id="fl_langs_ru" class="checkbox__input js-fl_langs" value="ru" checked>\n                <label for="fl_langs_ru" class="checkbox__label checkbox__label_another js-popup_feed_ru">Русский</label>\n              </span>\n            </div>\n            <div class="form-field form-field_lang-settings">\n              <span class="checkbox checkbox_custom">\n                <input type="checkbox" name="fl[]" id="fl_langs_en" class="checkbox__input js-fl_langs" value="en" >\n                <label for="fl_langs_en" class="checkbox__label checkbox__label_another js-popup_feed_en">Английский</label>\n              </span>\n            </div>\n        </fieldset>\n\n        <div class="form__footer form__footer_lang-settings">\n          <button type="submit" class="btn btn_blue btn_huge btn_full-width js-popup_save_btn">Сохранить настройки</button>\n        </div>\n      </form>\n    </div>\n  </div>\n</div>\n\n\n\n    <script>\n  function composeTeaser(t, blockType) {\n    const listener = " onclick=\\"if (typeof ga === \'function\') { ga(\'send\', \'event\', \'tm_block\', \'promo,"\n      + blockType + "\', \'"+ t.linkUrl +"\'); }\\"";\n    let teaser = \'<li class="megapost-teasers__item teaser">\'\n    + \'<a href="\' + t.linkUrl + \'" target="_blank" class="teaser__image" rel="nofollow\';\n\n    if (t.external) teaser += \' sponsored\';\n\n    teaser += \'"\';\n\n    teaser += listener;\n\n    teaser += \'>\'\n    + \'<img src="\' + t.imageUrl + \'" class="teaser__image-pic"/>\'\n    + \'<div class="megapost-teasers__label">\'\n    + t.label;\n\n    if (t.external) teaser += `<svg width="11" height="11" viewBox="0 0 11 11" fill="none" xmlns="http://www.w3.org/2000/svg">\n<path fill-rule="evenodd" clip-rule="evenodd" d="M7.5 0C7.22386 0 7 0.223858 7 0.5C7 0.776142 7.22386 1 7.5 1H9.29289L5.14645 5.14645C4.95118 5.34171 4.95118 5.65829 5.14645 5.85355C5.34171 6.04882 5.65829 6.04882 5.85355 5.85355L10 1.70711V3.5C10 3.77614 10.2239 4 10.5 4C10.7761 4 11 3.77614 11 3.5V0.5C11 0.223858 10.7761 0 10.5 0H7.5ZM0.5 1C0.223858 1 0 1.22386 0 1.5V10.5C0 10.7761 0.223858 11 0.5 11H9.5C9.77614 11 10 10.7761 10 10.5V6C10 5.72386 9.77614 5.5 9.5 5.5C9.22386 5.5 9 5.72386 9 6V10H1V2H5C5.27614 2 5.5 1.77614 5.5 1.5C5.5 1.22386 5.27614 1 5 1H0.5Z" fill="#6667A2"/>\n</svg>\n`;\n\n    teaser += \'</div></a>\'\n    + \'<a href="\' + t.linkUrl + \'" target="_blank" class="teaser__body" rel="nofollow\';\n\n    if (t.external) teaser += \' sponsored\';\n\n    teaser += \'"\';\n\n    teaser += listener;\n\n    teaser += \'>\'\n    + \'<h3 class="teaser__body-title">\'\n    + t.title\n    + \'</h3></a></li>\';\n\n    return teaser;\n  }\n</script>\n    <script type="text/javascript">\n  // global vars\n  var g_base_url = \'habr.com/ru\';\n  var g_base_fullurl = \'https://habr.com/ru/\';\n  var g_tmid_fullurl = \'https://account.habr.com/\';\n  var g_is_guest = false;\n  var g_show_xpanel = false;\n  var g_is_enableShortcuts = \'1\';\n  var g_is_ugc_post = \'\';\n  var g_is_company_post = \'\';\n  var g_current_hl = \'ru\';\n  var g_current_fl = \'ru\';\n\n</script>\n\n    <script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/vendors.bundle.js"></script>\n    <script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/main.bundle.js"></script>\n    \n\n      <script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/check-login.js"></script>\n    \n    \n<!-- Yandex.Metrika counter -->\n<script type="text/javascript">\n(function(m,e,t,r,i,k,a){\n  m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};\n  m[i].l=1*new Date();\n  k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)\n})(window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");\n\n    ym(24049213, "init", {\n      clickmap:true\n      , trackLinks:true\n      , accurateTrackBounce:true\n    });\n</script>\n<noscript>\n  <div>\n      <img src="https://mc.yandex.ru/watch/24049213" style="position:absolute; left:-9999px;" alt="" />\n  </div>\n</noscript>\n<!-- /Yandex.Metrika counter -->\n\n    <script type="text/javascript">\n  function stripUrl(currentUrl, queryParam) {\n   return currentUrl.replace(/\\?([^#]*)/, function(_, search) {\n      var result = search.split(\'&\').map(function(param) {\n        var regexp = new RegExp(`^${queryParam}`);\n        if (regexp.test(param)) {\n          return \'\';\n        }\n        return param;\n      }).filter(Boolean).join(\'&\');\n      return result ? \'?\' + result : \'\';\n    });\n  }\n\n  (function() {\n    if (location.search.indexOf(\'cv\') != -1 && history.replaceState) {\n      var currentUrl = location.toString();\n      var strippedUrl = stripUrl(currentUrl, \'cv\');\n      history.replaceState({}, \'\', strippedUrl);\n    }\n  })();\n\n  function callGA(usesABP) {\n    if (typeof window.adb1 === \'undefined\') { window.adb1 = \'yes\';}\n    if (usesABP) { window.adb1 = \'aa\'; }\n\n    var user_type = \'guest\';\n\n    var page_type = "other";\n\n    (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n      m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n    })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n        ga(\'create\', \'UA-726094-1\',  \'auto\');\n        ga(\'create\', \'UA-726094-24\', \'auto\', {\'name\': \'HGM\', \'allowLinker\': true});\n\n    ga(\'HGM.require\', \'linker\');\n    ga(\'HGM.linker:autoLink\', [\'toster.ru\', \'habr.com\', \'account.habr.com\', \'m.habr.com\']);\n\n    ga(\'require\', \'displayfeatures\');\n    ga(\'set\', \'dimension1\', user_type); // user type - guest/readonly/habrauser\n    ga(\'set\', \'dimension2\', page_type);\n    ga(\'set\', \'dimension3\', \'na\');\n    ga(\'set\', \'dimension4\', window.adb1);\n    ga(\'set\', \'dimension6\', \'ru\');\n    \n\n\n    (function() {\n      var removeUtms = function(){\n        var location = window.location;\n        if (location.search.indexOf(\'utm_\') != -1 && history.replaceState) {\n          var currentUrl = location.toString();\n          var strippedUrl = stripUrl(currentUrl, \'utm_\');\n          history.replaceState({}, \'\', strippedUrl);\n        }\n      };\n      ga(\'require\', \'GTM-559GVC8\');\n      ga(\'send\', \'pageview\', { \'hitCallback\': removeUtms });\n    })();\n\n    ga(\'HGM.set\', \'dimension1\', user_type);\n    ga(\'HGM.set\', \'dimension2\', "habrahabr");\n    ga(\'HGM.set\', \'dimension4\', window.adb1);\n\n    ga(\'HGM.send\', \'pageview\');\n  }\n\n\n  if (window.habr_blockers_checker) {\n    window.habr_blockers_checker.detectWrapper(callGA);\n  } else {\n    callGA(false)\n  }\n\n</script>\n\n    <!-- Facebook Pixel Code -->\n<img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=317458588730613&ev=PageView&noscript=1"/>\n<!-- End Facebook Pixel Code -->\n\n    <img src="https://vk.com/rtrg?p=VK-RTRG-421343-57vKE" style="position:fixed; left:-999px;" alt=""/>\n    \n  </body>\n</html>\n'
In [9]:
# прасим нужную страницу с постами

soup_2 = BeautifulSoup(result_2.text, 'html.parser')
soup_2
Out[9]:
<!DOCTYPE html>

<html class="no-js" lang="ru">
<head>
<meta content="text/html; charset=utf-8" http-equiv="content-type"/>
<meta content="width=1024" name="viewport"/>
<title>Все публикации подряд / Хабр</title>
<meta content="444736788986613" property="fb:app_id">
<meta content="website" property="og:type"/>
<meta content="472597926099084" property="fb:pages"/>
<meta content="Хабр" property="og:site_name"/>
<link href="https://habrastorage.org/storage/stuff/habr/habr_ru.png" rel="image_src"/>
<meta content="https://habrastorage.org/storage/stuff/habr/habr_ru.png" property="og:image"/>
<meta content="1200" property="og:image:width"/>
<meta content="628" property="og:image:height"/>
<meta content="Все публикации подряд / Хабр" property="og:title"/>
<meta content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом." property="og:description"/>
<meta content="71593b225aeafc4e" name="yandex-verification"/>
<meta content="unsafe-url" name="referrer"/>
<meta content="ed24b2b9721edf0a282c5b4a3232c4" name="pocket-site-verification"/>
<meta content="https://dr.habracdn.net/habr/oldassets/60a75345/images/" name="biu"/>
<style type="text/css">
  @font-face{font-family:'Fira Sans';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.woff2) format("woff2"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.woff) format("woff"),url(https://dr.habracdn.net/habr/oldassets/60a75345/fonts/FiraSans/firaSans-medium.ttf) format("truetype")}
</style>
<link href="https://dr.habracdn.net/habr/oldassets/60a75345/styles/main.bundle.css" media="all" rel="stylesheet"/>
<meta content="67d46b975fa41645" name="yandex-verification">
<link href="https://dr.habracdn.net/habr/oldassets/60a75345/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
<link href="https://dr.habracdn.net/habr/oldassets/60a75345/images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
<link href="https://dr.habracdn.net/habr/oldassets/60a75345/images/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
<link href="https://dr.habracdn.net/habr/oldassets/60a75345/site.webmanifest" rel="manifest"/>
<link color="#77a2b6" href="https://dr.habracdn.net/habr/oldassets/60a75345/images/safari-pinned-tab.svg" rel="mask-icon"/>
<meta content="Хабр" name="application-name"/>
<meta content="#77a2b6" name="msapplication-TileColor"/>
<meta content="#77a2b6" name="theme-color"/>
<link href="https://habr.com/ru/rss/all/all/?fl=ru" rel="alternate" title="Все публикации подряд" type="application/rss+xml">
<script>/* Font Face Observer v2.0.13 - © Bram Stein. License: BSD-3-Clause */(function(){'use strict';var f,g=[];function l(a){g.push(a);1==g.length&&f()}function m(){for(;g.length;)g[0](),g.shift()}f=function(){setTimeout(m)};function n(a){this.a=p;this.b=void 0;this.f=[];var b=this;try{a(function(a){q(b,a)},function(a){r(b,a)})}catch(c){r(b,c)}}var p=2;function t(a){return new n(function(b,c){c(a)})}function u(a){return new n(function(b){b(a)})}function q(a,b){if(a.a==p){if(b==a)throw new TypeError;var c=!1;try{var d=b&&b.then;if(null!=b&&"object"==typeof b&&"function"==typeof d){d.call(b,function(b){c||q(a,b);c=!0},function(b){c||r(a,b);c=!0});return}}catch(e){c||r(a,e);return}a.a=0;a.b=b;v(a)}}
function r(a,b){if(a.a==p){if(b==a)throw new TypeError;a.a=1;a.b=b;v(a)}}function v(a){l(function(){if(a.a!=p)for(;a.f.length;){var b=a.f.shift(),c=b[0],d=b[1],e=b[2],b=b[3];try{0==a.a?"function"==typeof c?e(c.call(void 0,a.b)):e(a.b):1==a.a&&("function"==typeof d?e(d.call(void 0,a.b)):b(a.b))}catch(h){b(h)}}})}n.prototype.g=function(a){return this.c(void 0,a)};n.prototype.c=function(a,b){var c=this;return new n(function(d,e){c.f.push([a,b,d,e]);v(c)})};
function w(a){return new n(function(b,c){function d(c){return function(d){h[c]=d;e+=1;e==a.length&&b(h)}}var e=0,h=[];0==a.length&&b(h);for(var k=0;k<a.length;k+=1)u(a[k]).c(d(k),c)})}function x(a){return new n(function(b,c){for(var d=0;d<a.length;d+=1)u(a[d]).c(b,c)})};window.Promise||(window.Promise=n,window.Promise.resolve=u,window.Promise.reject=t,window.Promise.race=x,window.Promise.all=w,window.Promise.prototype.then=n.prototype.c,window.Promise.prototype["catch"]=n.prototype.g);}());

(function(){function l(a,b){document.addEventListener?a.addEventListener("scroll",b,!1):a.attachEvent("scroll",b)}function m(a){document.body?a():document.addEventListener?document.addEventListener("DOMContentLoaded",function c(){document.removeEventListener("DOMContentLoaded",c);a()}):document.attachEvent("onreadystatechange",function k(){if("interactive"==document.readyState||"complete"==document.readyState)document.detachEvent("onreadystatechange",k),a()})};function r(a){this.a=document.createElement("div");this.a.setAttribute("aria-hidden","true");this.a.appendChild(document.createTextNode(a));this.b=document.createElement("span");this.c=document.createElement("span");this.h=document.createElement("span");this.f=document.createElement("span");this.g=-1;this.b.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.c.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";
this.f.style.cssText="max-width:none;display:inline-block;position:absolute;height:100%;width:100%;overflow:scroll;font-size:16px;";this.h.style.cssText="display:inline-block;width:200%;height:200%;font-size:16px;max-width:none;";this.b.appendChild(this.h);this.c.appendChild(this.f);this.a.appendChild(this.b);this.a.appendChild(this.c)}
function t(a,b){a.a.style.cssText="max-width:none;min-width:20px;min-height:20px;display:inline-block;overflow:hidden;position:absolute;width:auto;margin:0;padding:0;top:-999px;white-space:nowrap;font-synthesis:none;font:"+b+";"}function y(a){var b=a.a.offsetWidth,c=b+100;a.f.style.width=c+"px";a.c.scrollLeft=c;a.b.scrollLeft=a.b.scrollWidth+100;return a.g!==b?(a.g=b,!0):!1}function z(a,b){function c(){var a=k;y(a)&&a.a.parentNode&&b(a.g)}var k=a;l(a.b,c);l(a.c,c);y(a)};function A(a,b){var c=b||{};this.family=a;this.style=c.style||"normal";this.weight=c.weight||"normal";this.stretch=c.stretch||"normal"}var B=null,C=null,E=null,F=null;function G(){if(null===C)if(J()&&/Apple/.test(window.navigator.vendor)){var a=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))(?:\.([0-9]+))/.exec(window.navigator.userAgent);C=!!a&&603>parseInt(a[1],10)}else C=!1;return C}function J(){null===F&&(F=!!document.fonts);return F}
function K(){if(null===E){var a=document.createElement("div");try{a.style.font="condensed 100px sans-serif"}catch(b){}E=""!==a.style.font}return E}function L(a,b){return[a.style,a.weight,K()?a.stretch:"","100px",b].join(" ")}
A.prototype.load=function(a,b){var c=this,k=a||"BESbswy",q=0,D=b||3E3,H=(new Date).getTime();return new Promise(function(a,b){if(J()&&!G()){var M=new Promise(function(a,b){function e(){(new Date).getTime()-H>=D?b():document.fonts.load(L(c,'"'+c.family+'"'),k).then(function(c){1<=c.length?a():setTimeout(e,25)},function(){b()})}e()}),N=new Promise(function(a,c){q=setTimeout(c,D)});Promise.race([N,M]).then(function(){clearTimeout(q);a(c)},function(){b(c)})}else m(function(){function u(){var b;if(b=-1!=
f&&-1!=g||-1!=f&&-1!=h||-1!=g&&-1!=h)(b=f!=g&&f!=h&&g!=h)||(null===B&&(b=/AppleWebKit\/([0-9]+)(?:\.([0-9]+))/.exec(window.navigator.userAgent),B=!!b&&(536>parseInt(b[1],10)||536===parseInt(b[1],10)&&11>=parseInt(b[2],10))),b=B&&(f==v&&g==v&&h==v||f==w&&g==w&&h==w||f==x&&g==x&&h==x)),b=!b;b&&(d.parentNode&&d.parentNode.removeChild(d),clearTimeout(q),a(c))}function I(){if((new Date).getTime()-H>=D)d.parentNode&&d.parentNode.removeChild(d),b(c);else{var a=document.hidden;if(!0===a||void 0===a)f=e.a.offsetWidth,
g=n.a.offsetWidth,h=p.a.offsetWidth,u();q=setTimeout(I,50)}}var e=new r(k),n=new r(k),p=new r(k),f=-1,g=-1,h=-1,v=-1,w=-1,x=-1,d=document.createElement("div");d.dir="ltr";t(e,L(c,"sans-serif"));t(n,L(c,"serif"));t(p,L(c,"monospace"));d.appendChild(e.a);d.appendChild(n.a);d.appendChild(p.a);document.body.appendChild(d);v=e.a.offsetWidth;w=n.a.offsetWidth;x=p.a.offsetWidth;I();z(e,function(a){f=a;u()});t(e,L(c,'"'+c.family+'",sans-serif'));z(n,function(a){g=a;u()});t(n,L(c,'"'+c.family+'",serif'));
z(p,function(a){h=a;u()});t(p,L(c,'"'+c.family+'",monospace'))})})};"object"===typeof module?module.exports=A:(window.FontFaceObserver=A,window.FontFaceObserver.prototype.load=A.prototype.load);}());

(function( w ){
if( w.document.documentElement.className.indexOf( "fonts-loaded" ) > -1 ){ return; }

var html = document.documentElement;
var FS500 = new w.FontFaceObserver("Fira Sans", { weight: 500 });

FS500.load().then(function() {
html.classList.add('fonts-loaded');
sessionStorage.fontsLoaded = true;
console.log('FS500-loaded');
}).catch(function () {
sessionStorage.fontsLoaded = false;
console.log('FS500-unloaded');
});

if (sessionStorage.fontsLoaded) {
html.classList.add('fonts-loaded');
}
}(this));
</script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/jquery-1.8.3.min.js"></script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/chance.min.js"></script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/html2canvas.min.js"></script>
<script>
  window.create_callback_for_blocked = function(key) {
    return function() {
      googletag.cmd.push(function () {
        googletag.display(key);
      });
    }
  }

  window.habr_blockers_checker = new function() {
    var result;
    var callbacksQueue = [];
    var calledOnce = false;

    function fireCallbacks() {
      callbacksQueue.forEach(function(callback) {
        callback(result);
      });
      callbacksQueue = [];
    }

    this.detect = function(imgUrl, callback) {
      var checksRemain = 2;
      var detected = false;
      var error1 = false;
      var error2 = false;

      if (typeof callback !== 'function') {
        return;
      };

      callbacksQueue.push(callback);

      if (typeof result !== 'undefined') {
        fireCallbacks();
      };

      if (calledOnce) {
        return;
      }
      calledOnce = true;

      imgUrl += '?ch=*&rn=*';

      function beforeCheck(timeout) {
        if (checksRemain === 0 || timeout > 1E3) {
          result = checksRemain === 0 && detected;
          fireCallbacks();
        } else {
          setTimeout(function() {
            beforeCheck(timeout * 2)
          }, timeout * 2);
        }
      }

      function checkImages() {
        if (--checksRemain) {
          return;
        };
        detected = !error1 && error2;
      }

      var random = Math.random() * 11;

      var img1 = new Image;
      img1.onload = checkImages;
      img1.onerror = function() {
        error1 = true;
        checkImages()
      };
      img1.src = imgUrl.replace(/\*/, 1).replace(/\*/, random);

      var img2 = new Image;
      img2.onload = checkImages;
      img2.onerror = function() {
        error2 = true;
        checkImages()
      };
      img2.src = imgUrl.replace(/\*/, 2).replace(/\*/, random);

      beforeCheck(250, callback)
    };

    this.detectWrapper = function(callback) {
      return this.detect('/images/px.gif', callback);
    };
  };

  window.display_dfp_slot = function(key) {
    if (window.habr_blockers_checker) {
      window.habr_blockers_checker.detectWrapper(window.create_callback_for_blocked(key));
    } else {
      window.create_callback_for_blocked(key)();
    }
  };
</script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/libs/raven.min.js"></script>
<script>Raven.config('https://9d127adffe724363a380a189afcdb015@sentry.srv.habr.com/11', {
  maxBreadcrumbs: 50,
  sampleRate: 0.5,
  whitelistUrls: [/https?:\/\/((www)\.)?(m\.)?habr\.com/],
}).install()</script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/_parts/advertise.js"></script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/_parts/adriver.js"></script>
<script async="" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
<script async="" src="https://static.criteo.net/js/ld/publishertag.js"></script>
<script>
  var googletag = googletag || {};
  googletag.cmd = googletag.cmd || [];
</script>
<script>
  // TODO: move this code to module
  //       move dot in chains to start of line and use one indent level:
  //               ```
  //                  start()
  //                    .chainEnd()
  //               ```

  var ENABLE_YANDEX_ADS = false;

  function display_yandex_rtb(yandexId, divId) {
    $('#' + divId).show();
    (function(w, d, n, s, t) {
      w[n] = w[n] || [];
      w[n].push(function() {
        Ya.Context.AdvManager.render({
          blockId: yandexId,
          renderTo: divId,
          async: true
        });
      });
      t = d.getElementsByTagName('script')[0];
      s = d.createElement('script');
      s.type = 'text/javascript';
      s.src = '//an.yandex.ru/system/context.js';
      s.async = true;
      t.parentNode.insertBefore(s, t);
    })(this, this.document, 'yandexContextAsyncCallbacks');
  }

  function listen_googletag_and_render_yandex(yandexId, targetDivId) {
    if (!window.googletag || !window.googletag.cmd) {
      return;
    }
    window.googletag.cmd.push(function() {
      if (!window.googletag.pubads) {
        return;
      }
      if (ENABLE_YANDEX_ADS) {
        window.googletag.pubads()
          .addEventListener('slotRenderEnded', function(event) {
            var divId = event.slot.getSlotElementId();
            if (divId === targetDivId && event.isEmpty) {
              window.display_yandex_rtb(yandexId, divId);
            }
          });
      }
    });
  }

  function getRoxotItem(storageKey, config) {
    if (config) {
      var { randomVal, returnCode } = config;
    } else {
      var randomVal = 100,
          returnCode = '101';
    }
    try {
      var groupId = localStorage.getItem(storageKey);
      if (groupId === null) {
        groupId = 1 + Math.floor(Math.random() * randomVal);
        localStorage.setItem(storageKey, groupId);
      }
      return '' + groupId;
    }
    catch (e) {
      return returnCode;
    }
  }

  function getRoxotEvent() {
    return '' + (1 + Math.floor(Math.random() * 100));
  }

  function leftpad(str, len, ch) {
    str = String(str);

    var i = -1;

    if (!ch && ch !== 0) {
      ch = ' ';
    };

    len = len - str.length;

    while (++i < len) {
      str = ch + str;
    }

    return str;
  }

  var WEEK_DAYS = ['su', 'mo', 'tu', 'we', 'th', 'fr', 'sa'];

  function initializeDFP(usesABP) {
    var currentDate = new Date();
    var hours = currentDate.getHours();
    var hoursStr = leftpad(hours, 2, '0');
    var weekDayCode = WEEK_DAYS[currentDate.getDay()];
    googletag.cmd.push(function() {
      if (usesABP) {
  googletag.defineSlot('/235032688/HH/HH02_inpage_wide', [[1, 1], [780, 130], [780, 200], [780, 180], [780, 110], [728, 90]], 'div-gpt-hh-inpage-wide').addService(googletag.pubads());
  window.listen_googletag_and_render_yandex('R-A-149298-32', 'div-gpt-hh-inpage-wide');
} else {
  googletag.defineSlot('/235032688/HH/HH02_inpage_wide', [[1, 1], [780, 200], [780, 130], [780, 180], [780, 110], [728, 90], [780, 195], [780, 210], [780, 260]], 'div-gpt-hh-inpage-wide').addService(googletag.pubads());
  window.listen_googletag_and_render_yandex('R-A-149298-36', 'div-gpt-hh-inpage-wide');
}
      if (usesABP) {
  googletag.defineSlot('/235032688/HH/HH01_ATF_Poster', [[1, 1], [300, 500], [300, 250], [300, 300], [300, 400], [300, 200], [300, 100], [240, 400]], 'div-gpt-hh-atf').addService(googletag.pubads());
  window.listen_googletag_and_render_yandex('R-A-149298-31', 'div-gpt-hh-atf');
} else {
  googletag.defineSlot('/235032688/HH/HH01_ATF_Poster', [[1, 1], [300, 500], [300, 600], [300, 250], [300, 300], [300, 400], [300, 200], [300, 150], [300, 100], [240, 400]], 'div-gpt-hh-atf').addService(googletag.pubads());
  window.listen_googletag_and_render_yandex('R-A-149298-35', 'div-gpt-hh-atf');
}

      googletag.pubads().enableSingleRequest();
      if (!usesABP) {
        googletag.pubads().disableInitialLoad(); //We will wait for the Criteo Bidder Call before calling the adserver
      }
      googletag.pubads().collapseEmptyDivs();
      googletag.pubads().
      setTargeting('roxot-group-id', getRoxotItem('roxot-gid', { randomVal: 10000, returnCode: '10001'})).
      setTargeting('roxot-sector-id', getRoxotItem('roxot-sid')).
      setTargeting('roxot-deep', getRoxotItem('roxot-deep')).
      setTargeting('roxot-event-group-id', getRoxotEvent()).
      setTargeting('roxot-event', getRoxotEvent()).
      setTargeting('roxot-event-deep', getRoxotEvent()).
      setTargeting('roxot-minutes', (new Date).getUTCMinutes().toString()).
      setTargeting('roxot-hours', (new Date).getUTCHours().toString()).
      setTargeting('roxot-day', (new Date).getUTCDay().toString()).
      setTargeting('chr', hoursStr).
      setTargeting('cwd', weekDayCode).
      setTargeting('aa', (usesABP) ? 'yes' : 'no').
      setTargeting('path', window.location.pathname + window.location.search).
      setTargeting('feedtype', ["all_all","posts"]).
      setTargeting('dev', [0]).
      setTargeting('user', ["guest"]).
      setTargeting('pagetype', ["feed"]);
      googletag.enableServices();

      if (!usesABP) {
        window.Criteo = window.Criteo || {};
        window.Criteo.events = window.Criteo.events || [];
        var launchAdServer = function () {
          googletag.cmd.push(function () {
            Criteo.SetDFPKeyValueTargeting(); //This will append Criteo keywords to the adserver call
            googletag.pubads().refresh(); //This will trigger the adserver call
          });
        };
        Criteo.events.push(function () {
          var adUnits = {
            'placements': [
              {'slotid': 'div-gpt-hh-inpage-wide', 'zoneid': 1173491}, // TMTM - RU - CDB - SA - Habr - 780x180
              {'slotid': 'div-gpt-hh-atf', 'zoneid': 1173489}, // TMTM - RU - CDB - SA - Habr - 300x600
            ]
          };
          // Define the price band range
          Criteo.SetLineItemRanges('0..599:1;600..1398:2;1400..3000:5');
          // Call Criteo and execute the callback function for a given timeout
          Criteo.RequestBids(adUnits, launchAdServer, 750);
        });
      }
    });
  }
  if (window.habr_blockers_checker) {
    window.habr_blockers_checker.detectWrapper(initializeDFP);
  } else {
    initializeDFP(false);
  }
</script>
</link></meta></meta></head>
<body class="nl">
<div class="layout">
<div class="layout__row layout__row_services">
<div id="TMpanel">
<div class="container">
<div class="logo-wrapper">
<a class="logo" href="https://habr.com/ru/" title="">
<svg height="24" viewbox="0 0 62 24" width="62" xmlns="http://www.w3.org/2000/svg">
<path d="M16.875 19L11.075 10.225L16.825 1.4H12.6L8.75 7.4L4.94999 1.4H0.574994L6.32499 10.15L0.524994 19H4.79999L8.64999 12.975L12.525 19H16.875Z"></path>
<path d="M24.2607 5.775C20.8857 5.775 18.9607 7.625 18.6107 9.85H22.0107C22.2107 9.175 22.8607 8.6 24.1107 8.6C25.3357 8.6 26.2357 9.225 26.2357 10.425V11.025H23.4107C20.1107 11.025 18.1107 12.55 18.1107 15.2C18.1107 17.8 20.1107 19.3 22.6107 19.3C24.2857 19.3 25.6357 18.65 26.4357 17.6V19H29.8107V10.55C29.8107 7.4 27.5857 5.775 24.2607 5.775ZM23.6107 16.475C22.4857 16.475 21.7607 15.925 21.7607 15.025C21.7607 14.1 22.5607 13.55 23.6857 13.55H26.2357V14.125C26.2357 15.625 25.0107 16.475 23.6107 16.475Z"></path>
<path d="M39.925 6.3C38.125 6.3 36.65 6.95 35.7 8.275C35.95 5.85 36.925 4.65 39.375 4.275L44.3 3.55V0.375L39.025 1.25C33.925 2.1 32.35 5.5 32.35 11.175C32.35 16.275 34.825 19.3 39.2 19.3C43.125 19.3 45.55 16.3 45.55 12.7C45.55 8.825 43.3 6.3 39.925 6.3ZM39.025 16.25C37.125 16.25 36.075 14.725 36.075 12.675C36.075 10.7 37.175 9.275 39.05 9.275C40.875 9.275 41.9 10.75 41.9 12.7C41.9 14.65 40.9 16.25 39.025 16.25Z"></path>
<path d="M76.104 4.91202V9.37802H70.626V4.91202H68.734V16H70.626V11.094H76.104V16H77.996V4.91202H76.104Z" fill="#333333"></path>
<path d="M85.9003 14.526C83.8983 14.526 82.5783 12.876 82.5783 10.456C82.5783 8.05802 83.8543 6.38602 85.8783 6.38602C87.6383 6.38602 88.4523 7.53002 88.7383 8.45402H90.6303C90.3443 6.69402 88.8263 4.67002 85.8783 4.67002C82.6883 4.67002 80.6423 7.13402 80.6423 10.456C80.6423 13.844 82.7323 16.242 85.8783 16.242C88.6283 16.242 90.3883 14.394 90.6303 12.414H88.7383C88.4963 13.36 87.7483 14.526 85.9003 14.526Z" fill="#333333"></path>
</svg>
</div>
<p class="service-description">
              Удаленная работа для IT-специалистов
            </p>
</a>
</div>
</div>
<div class="bmenu">
<a class="bmenu__conversion" href="https://habr.com/sandbox/start/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'habr_top_panel', 'become_an_author'); }">Как стать автором</a>
<a class="bmenu__theme" id="feature-effect" style="display: none;" target="_blank">
<img alt="" style="position:relative; vertical-align: middle; top: -2px; margin-right: 4px;" width="20"/>
<span class="bmenu__text"></span>
</a>
</div>
<div class="bmenu_inner" id="megapost-head-effect" style="display:flex!important;visibility:visible!important;">
<span class="bmenu slink">
</span>
</div>
</div>
</div>
<script>
  var dropdown = document.querySelector('#dropdown');
  var dropdownControl = document.querySelector('#dropdown-control');
  var logoWrapper = document.querySelector('.logo-wrapper');

  document.addEventListener('click', function(e) {
      if (dropdown) {
        var isClickInside = logoWrapper.contains(e.target);
        var dropdownClosed = dropdown.classList.contains('hidden');
        if (!isClickInside && !dropdownClosed) {
          dropdown.classList.add('hidden');
          dropdownControl.classList.remove('reverted');
        }
      }
  });
  if (dropdownControl) {
    dropdownControl.onclick = function () {
      dropdown.classList.toggle('hidden');
      dropdownControl.classList.toggle('reverted');
    }
  }
</script>
</div>
<div class="layout__row layout__row_navbar">
<div class="layout__cell">
<div class="main-navbar">
<div class="main-navbar__section main-navbar__section_left">
<ul class="nav-links" id="navbar-links">
<li class="nav-links__item">
<a class="nav-links__item-link nav-links__item-link_current" href="https://habr.com/ru/top/">Все потоки</a>
</li>
<li class="nav-links__item">
<a class="nav-links__item-link" href="https://habr.com/ru/flows/develop/">Разработка</a>
</li>
<li class="nav-links__item">
<a class="nav-links__item-link" href="https://habr.com/ru/flows/admin/">Администрирование</a>
</li>
<li class="nav-links__item">
<a class="nav-links__item-link" href="https://habr.com/ru/flows/design/">Дизайн</a>
</li>
<li class="nav-links__item">
<a class="nav-links__item-link" href="https://habr.com/ru/flows/management/">Менеджмент</a>
</li>
<li class="nav-links__item">
<a class="nav-links__item-link" href="https://habr.com/ru/flows/marketing/">Маркетинг</a>
</li>
<li class="nav-links__item">
<a class="nav-links__item-link" href="https://habr.com/ru/flows/popsci/">Научпоп</a>
</li>
</ul>
<form action="https://habr.com/ru/search/#h" class="search-form" id="search-form" method="get">
<button class="btn btn_navbar_search icon-svg_search" id="search-form-btn" title="Поиск по сайту" type="button">
<svg class="icon-svg" fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
<path clip-rule="evenodd" d="M17 11C17 14.3137 14.3137 17 11 17C7.68629 17 5 14.3137 5 11C5 7.68629 7.68629 5 11 5C14.3137 5 17 7.68629 17 11ZM15.5838 17.5574C14.2857 18.4665 12.7051 19 11 19C6.58172 19 3 15.4183 3 11C3 6.58172 6.58172 3 11 3C15.4183 3 19 6.58172 19 11C19 12.9998 18.2662 14.8282 17.0533 16.2307C17.0767 16.2502 17.0994 16.2709 17.1214 16.2929L20.4143 19.5858C20.8048 19.9763 20.8048 20.6095 20.4143 21C20.0238 21.3905 19.3906 21.3905 19.0001 21L15.7072 17.7071C15.6605 17.6604 15.6194 17.6102 15.5838 17.5574Z" fill-rule="evenodd"></path>
</svg>
</button>
<label class="search-form__field-wrapper">
<input class="search-form__field" id="search-form-field" name="q" placeholder="Поиск" tabindex="-1" type="text"/>
<button class="btn btn_search-close" id="search-form-clear" title="Закрыть" type="button">
<svg aria-hidden="true" class="icon-svg icon-svg_navbar-close-search" height="32" role="img" version="1.1" viewbox="0 0 31 32" width="31"><path d="M26.67 0L15.217 11.448 3.77 0 0 3.77l11.447 11.45L0 26.666l3.77 3.77L15.218 18.99l11.45 11.448 3.772-3.77-11.448-11.45L30.44 3.772z"></path></svg>
</button>
</label>
</form>
</div>
<div class="main-navbar__section main-navbar__section_right">
<button class="btn btn_medium btn_navbar_lang js-show_lang_settings" type="button">
<svg class="icon-svg" height="18" width="18">
<use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#globus-v2"></use>
</svg>
</button>
<a class="btn btn_medium btn_navbar_login" href="https://habr.com/ru/auth/login/" id="login">Войти</a>
<a class="btn btn_medium btn_navbar_registration" href="https://habr.com/ru/auth/register/">Регистрация</a>
</div>
</div>
</div>
</div>
<div class="layout__row layout__row_body">
<div class="layout__cell layout__cell_body">
<section class="column-wrapper column-wrapper_lists js-sticky-wrapper">
<div class="content_left js-content_left">
<div class="page-header page-header_110">
  Все потоки

  
</div>
<div class="tabs">
<div class="tabs__level tabs-level_top tabs-menu">
<a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/top/" rel="nofollow">
<h3 class="tabs-menu__item-text tabs-menu__item-text_active">
            Статьи
            
            
          </h3>
</a>
<a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/news/" rel="nofollow">
<h3 class="tabs-menu__item-text">
            Новости
            
            
          </h3>
</a>
<a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/hubs/" rel="nofollow">
<h3 class="tabs-menu__item-text">
            Хабы
            
            
          </h3>
</a>
<a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/users/" rel="nofollow">
<h3 class="tabs-menu__item-text">
            Авторы
            
            
          </h3>
</a>
<a class="tabs-menu__item tabs-menu__item_link" href="https://habr.com/ru/companies/" rel="nofollow">
<h3 class="tabs-menu__item-text">
            Компании
            
            
          </h3>
</a>
</div>
span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556050/">А что если гравитация и ускоренное расширение Вселенной — это следствие энтропии?</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/popular_science/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Научно-популярное'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Научно-популярное</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/physics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Физика'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Физика</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/astronomy/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Астрономия'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Астрономия</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/5cf/5ae/133/5cf5ae133f94ecc61b581ff7e14721fd.jpeg" style="object-position: 0% 0%">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Притяжение властвует на больших расстояниях, оно универсально и очевидно в сравнении с другими взаимодействиями, но нюанс заключается в том, что оно невероятно слабо — в <em>10<sup>39 </sup></em>раз слабее электромагнитного взаимодействия, а ее влияние на микроскопическом уровне вовсе незаметно. Природа гравитации в мире элементарных частиц ломает умы ученых не один десяток лет, ведь она не хочет мириться ни с квантовой физикой, ни с электродинамикой. Струнная теория так же не может удовлетворить конфликт гравитации с другими взаимодействиями. Но, кажется, мы нашли способ помирить гравитацию с физикой. Как? Предположить, что она — не фундаментальное взаимодействие.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556050/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21910,h_21968,h_22022" id="infopanel_post_556050">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 29: ↑26 и ↓3">+23</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556050" data-post-type="publish_ugc_ru,h_21910,h_21968,h_22022" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">73</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">22,7k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556050/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">101</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556002">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/ArkadiyXIII/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/47c/a40/834/47ca40834e97604a4298612c8b345dae.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">ArkadiyXIII</span>
</a>
<span class="post__time">6 мая 2021 в 07:47</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556002/">Для чего нужно интеграционное тестирование?</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it_testing/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Тестирование IT-систем'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Тестирование IT-систем</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/refactoring/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Проектирование и рефакторинг'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Проектирование и рефакторинг</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/web_testing/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Тестирование веб-сервисов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Тестирование веб-сервисов</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__text post__text-html post__text_v2">
<p>Эта статья является конспектом книги «<a href="https://www.litres.ru/vladimir-horikov/principy-unit-testirovaniya-pdf-epub-64083637/" rel="noopener noreferrer nofollow">Принципы юнит-тестирования</a>». Материал статьи посвящен интеграционным тестам.</p><p>Юнит-тесты прекрасно справляются с проверкой бизнес-логики, но проверять эту логику «в вакууме» недостаточно. Необходимо проверять, как разные ее части интегрируются друг с другом и внешними системами: базой данных, шиной сообщений и т. д.</p><p>В этой статье рассматривается роль интеграционных тестов, когда их следует использовать и когда лучше положиться на классические юнит-тесты. Также затронем эффективное написание интеграционных тестов.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556002/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_210,h_359,h_7504,h_19279" id="infopanel_post_556002">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 4: ↑3 и ↓1">+2</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556002" data-post-type="publish_ugc_ru,h_210,h_359,h_7504,h_19279" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">41</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">4,3k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556002/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">3</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556048">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">capissimo</span>
</a>
<span class="post__time">6 мая 2021 в 07:17</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556048/">Python, исследование данных и выборы: часть 5</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/1c2/952/165/1c29521658bfe85baf4f348a33f93f24.png" style="object-position: % %">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Заключительный пост №5<strong> для</strong> <strong>начинающих</strong> посвящен сопоставительной визуализации электоральных данных.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556048/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556048">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑2 и ↓1">+1</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556048" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">35</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">2,1k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556048/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">8</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="effect" style="display: none;">
<div class="default-block">
<div class="default-block__header">
<h2 class="default-block__header-title">Минуточку внимания</h2>
</div>
<div class="default-block__content">
<ul class="megapost-teasers" id="megapost-teasers">
</ul>
</div>
</div>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556044">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">capissimo</span>
</a>
<span class="post__time">6 мая 2021 в 06:34</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556044/">Python, исследование данных и выборы: часть 4</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/848/ff2/331/848ff2331f6b0abf9367f56628da0abf.png" style="object-position: % %">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Пост №4 <strong>для</strong> <strong>начинающих</strong> посвящен техническим приемам визуализации данных.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556044/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556044">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter" title="Всего голосов 2: ↑1 и ↓1">0</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556044" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">25</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,2k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556044/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556042">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">capissimo</span>
</a>
<span class="post__time">6 мая 2021 в 06:01</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556042/">Python, исследование данных и выборы: часть 3</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/c90/bd9/7ef/c90bd97efe58d8c07d83a7265da0eed1.png" style="object-position: % %">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Пост №3 <strong>для</strong> <strong>начинающих</strong> посвящен генерированию распределений, их свойствам, а также графикам для их сопоставительного анализа.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556042/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556042">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter" title="Всего голосов 2: ↑1 и ↓1">0</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556042" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">28</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,5k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556042/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">2</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556040">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">capissimo</span>
</a>
<span class="post__time">6 мая 2021 в 05:02</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556040/">Python, исследование данных и выборы: часть 2</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/f08/8c0/f3b/f088c0f3b91e38dcaabb2b59639a3f50.png" style="object-position: % %">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Пост №2<strong> для</strong> <strong>начинающих</strong> посвящен описательным статистикам, группированию данных и нормальному распределению. Все эти сведения заложат основу для дальнейшего анализа электоральных данных.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556040/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556040">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 5: ↑3 и ↓2">+1</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556040" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">37</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">2,2k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556040/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">6</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item"><!-- /235032688/HH/HH02_inpage_wide -->
<div class="dfp-slot">
<a class="dfp-slot__label" href="https://tmtm.ru/services/advertising/" target="_blank">Реклама</a>
<div class="dfp-slot__placeholder">
<span class="dfp-slot__placeholder-text">AdBlock похитил этот баннер, но баннеры не зубы — отрастут<br/><br/> <a class="btn btn_large btn_blue" href="https://u.tmtm.ru/tmtalkadblock" style="display:inline-flex!important;" target="_blank">Подробнее</a></span>
</div>
<div class="dfp-slot__banner dfp-slot__banner_wide" id="div-gpt-hh-inpage-wide">
<script>
      window.display_dfp_slot('div-gpt-hh-inpage-wide');
    </script>
</div>
</div>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_544730">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/dostigai/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/aff/85d/752/aff85d752f5f4597438ad88bd681d7b8.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">dostigai</span>
</a>
<span class="post__time">6 мая 2021 в 03:08</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/company/southbridge/blog/544730/">Однажды револьвер уравнял шансы сильных и слабых. А потом придумали интернет</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/southbridge/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Southbridge'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Southbridge</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/infosecurity/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Информационная безопасность'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Информационная безопасность</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/network_technologies/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Сетевые технологии'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Сетевые технологии</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/dwh/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Хранение данных'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Хранение данных</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__text post__text-html post__text_v1">
<p><img alt="image" src="https://habrastorage.org/webt/6f/dd/eo/6fddeoxmdczs6ruhnoknh3n_8du.jpeg"/></p><br/>
<p>Количество хорошо подготовленных целевых кибератак на <strong>критическую информационную инфраструктуру</strong> предприятий и целых городов в разных странах растёт с каждым годом. Причём в некоторых <a href="https://ru.wikipedia.org/wiki/Stuxnet" rel="nofollow noopener noreferrer">случаях </a> пострадавшие объекты КИИ даже не имели выхода в интернет. По мнению специалистов от кибербезопасности, выбор цели, задействованные ресурсы, подбор методов, уровень подготовки и действий в целом может говорить о том, что та или иная хакерская группировка, стоящая за каждой высококлассной атакой, работает на ту или иную иностранную спецслужбу.</p><br/>
<p>В России, как всегда, «долго запрягают». ФЗ-187 о безопасности КИИ на фоне вышеупомянутого выглядит запоздалым и долго исполняемым. Конечно, во многом по объективным причинам… и это лучшее, что у нас сейчас есть.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company
</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556028/#habracut">Узнать что в них промышленного</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21996,h_22014" id="infopanel_post_556028">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 12: ↑8 и ↓4">+4</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556028" data-post-type="publish_ugc_ru,h_21996,h_22014" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">13</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">10,6k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556028/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">17</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item">
<div class="promo-block promo-block_vacancies">
<h2 class="promo-block__header">
<a class="promo-block__title-link" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=block_name&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' } ga('send', 'event', 'tm_block', action, 'blockname'); }" rel="nofollow" target="_blank">
        Вакансии
      </a>
</h2>
<div class="promo-block__content">
<ul class="content-list content-list_promo">
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=vacancy&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies/1000049512" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">Fullstack разработчик PHP, JS, CSS на полный рабочий день удаленно</div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item promo-item__amount_rur">
<span title="80000 rur">
                от 80 000
              </span>
<span title="140000 rur">
                до 140 000
              </span>
</span>
<span class="promo-item__attrs-item">Reclamix</span>
<span class="promo-item__attrs-item">Можно удаленно</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=vacancy&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies/1000073606" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">Middle Java Developer</div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item promo-item__amount_rur">
<span title="150000 rur">
                от 150 000
              </span>
</span>
<span class="promo-item__attrs-item">Gameram</span>
<span class="promo-item__attrs-item">Самара</span>
<span class="promo-item__attrs-item">Можно удаленно</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=vacancy&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies/1000075384" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">Middle+/Senior Android Kotlin Developer</div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item promo-item__amount_rur">
<span title="180000 rur">
                от 180 000
              </span>
<span title="300000 rur">
                до 300 000
              </span>
</span>
<span class="promo-item__attrs-item">Mobigility Inc.</span>
<span class="promo-item__attrs-item">Можно удаленно</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=vacancy&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies/1000076847" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">Менеджер проектов</div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item promo-item__amount_rur">
<span title="150000 rur">
                до 150 000
              </span>
</span>
<span class="promo-item__attrs-item">Articul Technology</span>
<span class="promo-item__attrs-item">Можно удаленно</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=vacancy&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies/1000076844" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">Android разработчик</div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item promo-item__amount_rur">
<span title="70000 rur">
                от 70 000
              </span>
<span title="150000 rur">
                до 150 000
              </span>
</span>
<span class="promo-item__attrs-item">AppCraft</span>
<span class="promo-item__attrs-item">Рязань</span>
<span class="promo-item__attrs-item">Можно удаленно</span>
</div>
</div>
</a>
</li>
</ul>
</div>
<div class="promo-block__footer">
<a class="promo-block__footer-link promo-block__footer-link_selected" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=vacancies_all&amp;utm_campaign=vacancies_postlist" href="https://career.habr.com/vacancies/" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_post' } else {  var action = 'career_feed' }  ga('send', 'event', 'tm_block', action, 'posts'); }" rel="nofollow" target="_blank">Больше вакансий на Хабр Карьере</a>
</div>
</div>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556024">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/Furriest/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/927/130/b05/927130b056159f52821165e8bdce69d7.png" width="24"/>
<span class="user-info__nickname user-info__nickname_small">Furriest</span>
</a>
<span class="post__time">5 мая 2021 в 22:36</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556024/">Настраиваем отказоустойчивость Pi-Hole в связке с Mikrotik</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/network_technologies/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Сетевые технологии'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Сетевые технологии</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/a38/cc0/0a3/a38cc00a3b980ef2fcd235f8da23b48d.png" style="object-position: 0% 86.136363636364%">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>В <a href="https://habr.com/ru/post/468621/" rel="noopener noreferrer nofollow">прошлой статье</a> мы внедрили домашний сервер DoH с использованием Pi-Hole, чем не только пофильтровали большое количество рекламы, но и инкапсулировали наши DNS-запросы в HTTPS, что вывело их из поля фильтрации запросов оператором связи.</p><p>Всем замечательно это решение, но у него есть один нюанс. Если вдруг у нас закончились деньги на счету у оператора связи или по каким-то другим причинам пропал канал связи до внешнего мира, мы даже не сможем пополнить счет, чтобы восстановить сервис, потому что не будет работать DNS. Или, например, если наш Pi-Hole по каким-то причинам перестал работать -  вот вроде и вся сеть работает, и гугл пингуется, а пока не пропишешь другой DNS-сервер - не будет счастья. А если вы еще в этот момент заняты чем-то другим и не можете приступить к восстановлению незамедлительно - домашние негодуют, портят радостное существование своими жалобами и даже котики, чуя общую нервозность, стремятся нагадить вам в тапки.</p><p>Огорчать котиков - дело последнее, поэтому в этой статье я опишу, как вы можете внедрить автоматическое переключение с использования Pi-Hole на использование операторских (как, впрочем, и любых других) DNS при проблемах на Pi-Hole. </p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556024/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_17123" id="infopanel_post_556024">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 16: ↑16 и ↓0">+16</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556024" data-post-type="publish_ugc_ru,h_17123" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">99</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">9,1k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556024/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">13</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556018">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/egaxegax/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/377/221/2ca/3772212cae56cdecf113de497f75fddf.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">egaxegax</span>
</a>
<span class="post__time">5 мая 2021 в 21:21</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556018/">Карта метро Москвы с расчётом пути</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/javascript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'JavaScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">JavaScript</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/vector_graphics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Работа с векторной графикой'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Работа с векторной графикой</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/html5/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'HTML'); }" rel="nofollow" title="Вы не подписаны на этот хаб">HTML</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/canvas/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Canvas'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Canvas</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/423/4db/aee/4234dbaee2ee94f6cb5e44dc03b91c7c.png" style="object-position: 0% 0%">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>В своей предыдущей статье про интерактивную <a href="http://habrahabr.ru/post/268199" rel="noopener noreferrer nofollow">карту метро Москвы</a> я описывал процесс создания векторной карты на <em>svg</em>-движке, сравнивая с канвасным отображением. </p><p>Спустя время я решил вернуться к своей <a href="https://egaxegax.github.io/dbcartajs/svg/mosmetro.html" rel="noopener noreferrer nofollow">карте</a> и добавил в неё возможность вывода маршрута кратчайшего пути между выбранными станциями по алгоритму <a href="https://habr.com/ru/post/200252" rel="noopener noreferrer nofollow">BFS</a>, обхода графа в ширину.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556018/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_357,h_449,h_17103,h_17187" id="infopanel_post_556018">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑5 и ↓1">+4</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556018" data-post-type="publish_ugc_ru,h_357,h_449,h_17103,h_17187" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">19</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">6,1k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556018/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">14</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_555860">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/ph_piter/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/3be/b11/2b0/3beb112b076924a916b27c845d88dcfa.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">ph_piter</span>
</a>
<span class="post__time">5 мая 2021 в 21:16</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/company/piter/blog/555860/">Издательство Питер. Колонка редактора</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/piter/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Издательский дом «Питер»'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Издательский дом «Питер»</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/lib/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Профессиональная литература'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Профессиональная литература</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__text post__text-html post__text_v1">
<a href="https://habr.com/ru/company/piter/blog/555860/"><div style="text-align:center;"><img alt="image" src="https://habrastorage.org/webt/mi/sm/cq/mismcqetge7xg2rmwga6uqsr8su.png"/></div></a><br/>
Привет, Хаброжители! Предлагаем ознакомиться с краткими обзорами сданных в типографию новинок. <br/>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/piter/blog/555860/#habracut">Читать дальше →</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_piter,h_19309" id="infopanel_post_555860">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 7: ↑5 и ↓2">+3</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555860" data-post-type="publish_corp_ru,c_piter,h_19309" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">3k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/company/piter/blog/555860/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">7</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item">
<div class="promo-block promo-block_courses">
<h2 class="promo-block__header">
<a class="promo-block__title-link" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=block_name&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' } ga('send', 'event', 'tm_block', action, 'blockname'); }" rel="nofollow" target="_blank">
        Курсы
      </a>
</h2>
<div class="promo-block__content">
<ul class="content-list content-list_promo">
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=course&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses/265" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">
<img class="promo-item__title-image" height="20" src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/058/logo/medium_90c46342f487198001713f1faa9f8eee.png" width="20">
      Факультет Java-разработки
    </img></div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
            27 мая 2021
        </span>
<span class="promo-item__attrs-item">
            1 год
        </span>
<span class="promo-item__attrs-item promo-item__amount_rur">
            180 000 
        </span>
<span class="promo-item__attrs-item">
          GeekBrains
        </span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=course&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses/603" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">
<img class="promo-item__title-image" height="20" src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/023/logo/medium_003285e04cd9c6506d56e6d082755cc1.png" width="20">
      DevOps практики и инструменты
    </img></div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
            27 мая 2021
        </span>
<span class="promo-item__attrs-item promo-item__amount_rur">
            95 000 
        </span>
<span class="promo-item__attrs-item">
          OTUS
        </span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=course&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses/361" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">
<img class="promo-item__title-image" height="20" src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/023/logo/medium_003285e04cd9c6506d56e6d082755cc1.png" width="20">
      Разработчик Golang
    </img></div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
            27 мая 2021
        </span>
<span class="promo-item__attrs-item">
            5 месяцев
        </span>
<span class="promo-item__attrs-item promo-item__amount_rur">
            80 000 
        </span>
<span class="promo-item__attrs-item">
          OTUS
        </span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=course&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses/262" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">
<img class="promo-item__title-image" height="20" src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/058/logo/medium_90c46342f487198001713f1faa9f8eee.png" width="20">
      Факультет Python-разработки
    </img></div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
            27 мая 2021
        </span>
<span class="promo-item__attrs-item">
            16 месяцев
        </span>
<span class="promo-item__attrs-item promo-item__amount_rur">
            180 000 
        </span>
<span class="promo-item__attrs-item">
          GeekBrains
        </span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=course&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses/1239" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<div class="promo-item__title promo-item__title_hovered">
<img class="promo-item__title-image" height="20" src="https://habrastorage.org/getpro/moikrug/uploads/education_platform/000/000/023/logo/medium_003285e04cd9c6506d56e6d082755cc1.png" width="20">
      Роботизация процессов (RPA)
    </img></div>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
            27 мая 2021
        </span>
<span class="promo-item__attrs-item promo-item__amount_">
            Бесплатно
        </span>
<span class="promo-item__attrs-item">
          OTUS
        </span>
</div>
</div>
</a>
</li>
</ul>
</div>
<div class="promo-block__footer">
<a class="promo-block__footer-link promo-block__footer-link_selected" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=courses_all&amp;utm_campaign=courses_postlist" href="https://career.habr.com/courses" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'career_courses_post' } else {  var action = 'career_courses_feed' }  ga('send', 'event', 'tm_block', action, 'posts'); }" rel="nofollow" target="_blank">Больше курсов на Хабр Карьере</a>
</div>
</div>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_555916">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/gerasimovich/" title="Автор публикации">
<span class="default-image_mini default-image_green">
<svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
</span>
<span class="user-info__nickname user-info__nickname_small">gerasimovich</span>
</a>
<span class="post__time">5 мая 2021 в 21:05</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/company/it_people/blog/555916/">Три способа стать геймдизайнером, иконы игр и тренды GameDev. Интервью конференции DUMP</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/it_people/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании IT-People'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании IT-People</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/tech_events/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Конференции'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Конференции</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/game_design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Дизайн игр'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Дизайн игр</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/interviews/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Интервью'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Интервью</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/cfc/2af/348/cfc2af3480aa7491894a66d007e80ac6.jpg" style="object-position: 0% 0%"/>
</div>
<div class="post__text post__text-html post__text_v2">
<p>Когда играешь в особенно крутую игру, останавливаться не хочется, пока не пройдешь всё до конца. А ещё хочется создать свою игру! Знакомая история? Для участников DUMP тоже:) В этом году впервые на конференции будет представлена секция GameDev. </p><p>Мы решили узнать больше о разработке игр и пообщались с представителями индустрии из компании Targem Games — Евгением Бушуевым (Game Designer Crossout) и Алексеем Честных (Creative Director).</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/it_people/blog/555916/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_it_people,h_20754,h_20800,h_22020" id="infopanel_post_555916">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 1: ↑1 и ↓0">+1</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555916" data-post-type="publish_corp_ru,c_it_people,h_20754,h_20800,h_22020" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">9</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,3k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/company/it_people/blog/555916/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">4</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556004">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/danaumov/" title="Автор публикации">
<span class="default-image_mini default-image_green">
<svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
</span>
<span class="user-info__nickname user-info__nickname_small">danaumov</span>
</a>
<span class="post__time">5 мая 2021 в 19:59</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/company/rshb/blog/556004/">Вклад биотехнологий в решение проблем Агротеха</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/rshb/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Россельхозбанк'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Россельхозбанк</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/biotech/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Биотехнологии'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Биотехнологии</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/92e/1ce/86a/92e1ce86a9e293ad32d5a8f8994cda58.png" style="object-position: 0% 0%"/>
</div>
<div class="post__text post__text-html post__text_v2">
<p><strong>Проблемы аграриев взялись решать биотехнологи</strong></p><p>Благодаря биотехнологиям, всё больше процессов в агросфере выстраивается так, чтобы быть эффективными и прибыльными, не нанося вред природе. От специалистов-биотехнологов зависит, будем ли мы выращивать овощи и фрукты на городских мини-фермах и <a href="https://habr.com/ru/company/rshb/blog/546370/">будет ли мясо производиться в пробирке</a> из одной клетки или печататься на 3D-принтере и многое другое. </p><p>Существенную долю рынка мировых биотехнологий, - 51 %, составляют сельское хозяйство, пищевая промышленность и химпром. По <a href="https://rosng.ru/post/posle-koronavirusa-v-mire-nachnetsya-rost-biotehnologiy-ekspert">прогнозам экспертов</a>, до 2028 года рост рынка биотехнологий в год составит в среднем 15 %. </p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/rshb/blog/556004/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_rshb,h_21912" id="infopanel_post_556004">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 12: ↑9 и ↓3">+6</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556004" data-post-type="publish_corp_ru,c_rshb,h_21912" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">11</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">2,2k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/company/rshb/blog/556004/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_555914">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/honyaki/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/96e/81d/bc0/96e81dbc01247c6c855b1806b355efa3.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">honyaki</span>
</a>
<span class="post__time">5 мая 2021 в 19:45</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/company/skillfactory/blog/555914/">Как я посчитал миллионное число Фибоначчи</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/skillfactory/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании SkillFactory'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании SkillFactory</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/zadachki/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Занимательные задачки'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Занимательные задачки</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/maths/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Математика'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Математика</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/de4/f4e/871/de4f4e871d23e5f9d6715fc3d8ccec02.jpg" style="object-position: 0% 87.272727272727%">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Все мы понимаем, что рекурсивное вычисление чисел Фибоначчи крайне неэффективно. Многим людям наверняка хотелось проверить, где пределы (не)эффективности, но не доходили руки, не хватало времени. Специально к старту нового потока курса <a href="https://skillfactory.ru/python-fullstack-web-developer?utm_source=infopartners&amp;utm_medium=habr&amp;utm_campaign=habr_FPW&amp;utm_term=regular&amp;utm_content=050521">Fullstack-разработчик на Python</a> мы решили поделиться переводом статьи, автор которой шаг за шагом показывает возможности современного Python на примере разных подходов к вычислению чисел Фибоначчи. В статье вы найдёте проблемные значения n и сравнение производительности оптимального и неоптимального решений на графике.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/skillfactory/blog/555914/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_skillfactory,h_287,h_340,h_17812" id="infopanel_post_555914">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 29: ↑15 и ↓14">+1</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555914" data-post-type="publish_corp_ru,c_skillfactory,h_287,h_340,h_17812" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">35</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">5,7k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/company/skillfactory/blog/555914/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">34</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item">
<div class="promo-block promo-block_freelansim-tasks">
<h2 class="promo-block__header">
<a class="promo-block__title-link" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=block_name&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' }  ga('send', 'event', 'tm_block', action, 'blockname'); }" rel="nofollow" target="_blank">Заказы</a>
</h2>
<div class="promo-block__content">
<ul class="content-list content-list_promo">
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=task&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/tasks/367301" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<span class="promo-item__title promo-item__title_hovered">Дизайн сайта о лайф-коучинге и здоровом образе жизни</span>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
<span class="promo-item__amount_rur">800 </span>
<span class="promo-item__per">за час</span>
</span>
<span class="promo-item__attrs-item">2 отклика</span>
<span class="promo-item__attrs-item">11 просмотров</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=task&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/tasks/367299" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<span class="promo-item__title promo-item__title_hovered">Сверстать страницы личного кабинета</span>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
<span class="promo-item__amount_rur">5 000 </span>
<span class="promo-item__per">за проект</span>
</span>
<span class="promo-item__attrs-item">5 откликов</span>
<span class="promo-item__attrs-item">12 просмотров</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=task&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/tasks/367297" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<span class="promo-item__title promo-item__title_hovered">Такси</span>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
<span class="promo-item__amount_rur">350 000 </span>
<span class="promo-item__per">за проект</span>
</span>
<span class="promo-item__attrs-item">3 отклика</span>
<span class="promo-item__attrs-item">14 просмотров</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=task&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/tasks/367289" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<span class="promo-item__title promo-item__title_hovered">Разработать чат-бот для Microsoft Teams</span>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
<span class="promo-item__amount_rur">15 000 </span>
<span class="promo-item__per">за проект</span>
</span>
<span class="promo-item__attrs-item">0 откликов</span>
<span class="promo-item__attrs-item">10 просмотров</span>
</div>
</div>
</a>
</li>
<li class="content-list__item content-list__item_promo">
<a class="promo-item" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=task&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/tasks/367287" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' } ga('send', 'event', 'tm_block', action, 'post'); }">
<div class="promo-item__wrap">
<span class="promo-item__title promo-item__title_hovered">Оформить курсовую работу. Java + Spring</span>
<div class="promo-item__attrs">
<span class="promo-item__attrs-item">
<span class="promo-item__amount_rur">7 000 </span>
<span class="promo-item__per">за проект</span>
</span>
<span class="promo-item__attrs-item">1 отклик</span>
<span class="promo-item__attrs-item">11 просмотров</span>
</div>
</div>
</a>
</li>
</ul>
</div>
<div class="promo-block__footer">
<a class="promo-block__footer-link promo-block__footer-link_selected" data-utm="?utm_source=habr&amp;utm_medium=habr_block&amp;utm_content=tasks_all&amp;utm_campaign=tasks_postlist" href="http://freelance.habr.com/tasks/" onclick="if (typeof ga === 'function') { if (g_is_ugc_post) { var action = 'freelance_post' } else {  var action = 'freelance_feed' } ga('send', 'event', 'tm_block', action, 'posts'); }" rel="nofollow" target="_blank">Больше заказов на Хабр Фрилансе</a>
</div>
</div>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_556000">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">capissimo</span>
</a>
<span class="post__time">5 мая 2021 в 19:35</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/556000/">Python, исследование данных и выборы: часть 1</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/1c7/3ce/7ac/1c73ce7ac215107a7b21810d3ebfce74.png" style="object-position: % %">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Серия из 5 постов <strong>для</strong> <strong>начинающих</strong> представляет собой «ремикс» первой главы книги 2015 года под названием «Clojure для исследования данных» (Clojure for Data Science). Автор книги, Генри Гарнер, любезно дал согласие на использование материалов книги для данного ремикса с использованием языка Python.</p><p>Книга была написана как приглашение в так называемую «науку о данных», которая в последние годы получила сильный импульс к развитию в связи с потребностью в быстрой и своевременной обработке больших наборов данных локально и в распределенной среде.  </p><p>Три главы книги были адаптированы под язык Python в течение следующего года после издания книги, т.е. в 2016 году. Публикация ремикса книги в РФ не получилась по разным причинам, но одна из главных станет понятной в конце этой серии постов. В конце заключительного поста можно будет проголосовать за или против размещения следующей серии постов. А пока же…</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556000/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556000">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 5: ↑4 и ↓1">+3</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556000" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">74</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">4,4k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/556000/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">4</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_555998">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/Stedihabr/" title="Автор публикации">
<span class="default-image_mini default-image_pink">
<svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
</span>
<span class="user-info__nickname user-info__nickname_small">Stedihabr</span>
</a>
<span class="post__time">5 мая 2021 в 19:22</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/company/itsoft/blog/555998/">Украдено у Apple</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/itsoft/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании ITSOFT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании ITSOFT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/history/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'История IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">История IT</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/antikvariat/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Старое железо'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Старое железо</a>, 
        </li>
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it_bigraphy/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Биографии гиков'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Биографии гиков</a>
</li>
</ul>
<ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/e9c/b11/447/e9cb1144709e3b787d77bbe13e0164b1.png" style="object-position: 0% 0%"/>
</div>
<div class="post__text post__text-html post__text_v2">
<p>В 1980 году компания Franklin Computer выпустила клон Apple II под названием Franklin Ace, разработанный под «яблочное» ПО. Из Apple II скопировали практически все, включая программное обеспечение из ПЗУ и документацию, и продали клон по более низкой цене. Мы даже нашли место в мануале, где забыли поменять «Apple» на «Ace». В Apple пришли в ярость и подали на Franklin в суд. В конце концов мы победили и вынудили Franklin убрать Ace с рынка.  </p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/itsoft/blog/555998/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_itsoft,h_21906,h_21930,h_21938" id="infopanel_post_555998">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 35: ↑29 и ↓6">+23</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555998" data-post-type="publish_corp_ru,c_itsoft,h_21906,h_21930,h_21938" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">11</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">11k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/company/itsoft/blog/555998/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">9</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_555988">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/Hiro_Protagonist/" title="Автор публикации">
<span class="default-image_mini default-image_pink">
<svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
</span>
<span class="user-info__nickname user-info__nickname_small">Hiro_Protagonist</span>
</a>
<span class="post__time">5 мая 2021 в 18:47</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/555988/">Лингвистическая фантастика. Книги, в которых язык больше, чем просто средство для общения</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sci-fi/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Научная фантастика'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Научная фантастика</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/176/775/b2a/176775b2a73b083fdfb11703c730bbda.jpg" style="object-position: 0% 0%"/>
</div>
<div class="post__text post__text-html post__text_v2">
<p>Обычно когда речь идет про «научную фантастику», то наукой, которая лежит в основе сюжетов выступают физика, биология, может, компьютерные технологии. Что-то из области точных наук. Но некоторые фантасты не спешат идти проторенными путями, предпочитая удивлять читателя. Например, обращаясь к лингвистике и показывая миры или конфликты, в которых слово играет ключевую роль. </p><p>Очень приятно знакомиться с изобретательными способами показать, что речь — это инструмент, причем весьма функциональный и пластичный. На тему необычных языковых систем, вопросов взаимопонимания и того, как слово может влиять на человека (и не только) можно сказать не меньше интересных вещей, чем по поводу искусственного интеллекта или терраформирования Марса. Вот несколько тому примеров.</p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/555988/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21984" id="infopanel_post_555988">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 34: ↑32 и ↓2">+30</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555988" data-post-type="publish_ugc_ru,h_21984" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">135</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">14,7k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/555988/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">23</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
<li class="content-list__item content-list__item_post shortcuts_item" id="post_555934">
<article class="post post_preview" lang="ru">
<header class="post__meta">
<a class="post__user-info user-info" href="https://habr.com/ru/users/biolog_snork/" title="Автор публикации">
<img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/359/2e8/8a7/3592e88a7977d3df342bbcdff9e52244.jpg" width="24"/>
<span class="user-info__nickname user-info__nickname_small">biolog_snork</span>
</a>
<span class="post__time">5 мая 2021 в 18:43</span>
</header>
<h2 class="post__title">
<a class="post__title_link" href="https://habr.com/ru/post/555934/">Страшные волосатики, или посмертный кошмар кузнечика</a>
</h2>
<ul class="post__hubs inline-list">
<li class="inline-list__item inline-list__item_hub">
<a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/popular_science/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Научно-популярное'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Научно-популярное</a>
</li>
</ul>
<ul class="post__marks inline-list"></ul>
<div class="post__body post__body_crop">
<div class="post__body-cover post__body-cover_fit-cover">
<img src="https://habrastorage.org/getpro/habr/upload_files/8d6/48d/c7e/8d648dc7e3d596d8b2ae7138a7ac1fc7.jpg" style="object-position: 0% 0%">
</img></div>
<div class="post__text post__text-html post__text_v2">
<p>Волосатики — это тип, как правило, паразитоидных животных клады нематоид. Данные существа являются очень милыми свободно живущими червячками внешне похожими на нематод. Правда свободно живущими они являются только на взрослой стадии развития, потому-то их и называют паразитоидами. </p>
</div>
<a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/555934/#habracut">Читать далее</a>
</div>
<footer class="post__footer">
<ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21910" id="infopanel_post_555934">
<li class="post-stats__item">
<div class="post-stats__result">
<span class="post-stats__result-icon">
<svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
</span>
<span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 26: ↑23 и ↓3">+20</span>
</div>
</li>
<li class="post-stats__item post-stats__item_bookmark">
<button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555934" data-post-type="publish_ugc_ru,h_21910" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
<span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>
</button>
</li>
<li class="post-stats__item post-stats__item_views">
<div class="post-stats__views" title="Количество просмотров">
<svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">7,2k</span>
</div>
</li>
<li class="post-stats__item post-stats__item_comments">
<a class="post-stats__comments-link" href="https://habr.com/ru/post/555934/#comments" rel="nofollow">
<svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">10</span>
</a>
</li>
</ul>
</footer>
</article>
</li>
</ul>
<div class="page__footer">
<ul class="arrows-pagination">
<li class="arrows-pagination__item">
<a class="arrows-pagination__item-link arrows-pagination__item-link_prev" href="/ru/all/page49/" id="previous_page" rel="" title="На страницу назад (Alt + ←)">← <span>сюда</span></a>
</li>
<li class="arrows-pagination__item">
<span class="arrows-pagination__item-link">туда →</span>
</li>
</ul>
<ul class="toggle-menu toggle-menu_pagination" id="nav-pagess">
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_bordered" href="/ru/all/" rel="" title="Первая страница">
<span class="icon-svg icon-svg_arrow-first"><svg class="icon-svg" height="24" viewbox="0 0 28 24" width="28"><path d="M8.452 5.455l2.93 3.192c.89.969 1.335 1.361 2.225 1.909h-13.608v2.773h13.634c-.838.5-1.492 1.102-2.252 1.913l-2.93 3.192 2.276 1.964 7.588-8.452-7.588-8.452-2.276 1.961zM24.297 0h3.087v23.891h-3.087v-23.891z"></path></svg>
</span>
</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page43/">43</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page44/">44</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page45/">45</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page46/">46</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page47/">47</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page48/">48</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/ru/all/page49/">49</a>
</li>
<li class="toggle-menu__item toggle-menu__item_pagination">
<span class="toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_active">50</span>
</li>
</ul>
</div>
</div>
</div>
<div class="sidebar">
<div class="sidebar_right_ad">
<!-- /235032688/HH/HH01_ATF_Poster -->
<div class="dfp-slot dfp-slot_top is_visible">
<a class="dfp-slot__label" href="https://tmtm.ru/services/advertising/" target="_blank">Реклама</a>
<div class="dfp-slot__placeholder">
<span class="dfp-slot__placeholder-text">Баннер исчез, и под ним проявились пиктограммы от НЛО <a class="btn btn_large btn_blue" href="https://u.habr.com/msb21_ab" style="display:inline-flex!important;" target="_blank">Посмотреть</a></span>
</div>
<div class="dfp-slot__banner" id="div-gpt-hh-atf">
<script>
      window.display_dfp_slot('div-gpt-hh-atf');
    </script>
</div>
</div>
</div>
<div class="sidebar_right sidebar_content-area js-sidebar_right">
<div class="default-block default-block_sidebar" id="companies_rating">
<div class="default-block__header">
<h3 class="default-block__header-title">Лучшие компании</h3>
</div>
<div class="default-block__content companies-rating">
<ul class="companies-rating__list">
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/ruvds/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/f27/ea8/5bd/f27ea85bd62fbd985c308110885af7e0.png" width="32"/>
</a>
<a class="companies-rating__name" href="/company/ruvds/">RUVDS.com</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">4 025,63</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/selectel/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/66a/f7d/039/66af7d03979b6d18654293d8f1e72837.png" width="32"/>
</a>
<a class="companies-rating__name" href="/company/selectel/">Selectel</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">3 166,75</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/macloud/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/762/a3f/7f5/762a3f7f5d8dd06a124724495e436a14.png" width="32"/>
</a>
<a class="companies-rating__name" href="/company/macloud/">Маклауд</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">2 810,91</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/vdsina/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/349/b75/e68/349b75e680748f727261c7de1a4e1c5f.png" width="32"/>
</a>
<a class="companies-rating__name" href="/company/vdsina/">VDSina.ru</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">2 040,99</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/itsoft/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/f48/d46/029/f48d460297f1a9fe1a9e3e0a1e7aedc9.png" width="32"/>
</a>
<a class="companies-rating__name" href="/company/itsoft/">ITSOFT</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">723,26</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/timeweb/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/f16/9bf/2f9/f169bf2f9f64895ed94992d0d15e98fc.jpg" width="32"/>
</a>
<a class="companies-rating__name" href="/company/timeweb/">Timeweb</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">683,19</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/flipperdevices/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/595/777/b2c/595777b2c329a0b31b848c2a755e7df8.jpg" width="32"/>
</a>
<a class="companies-rating__name" href="/company/flipperdevices/">Flipper Devices Inc.</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">629,24</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/tuturu/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/d22/183/e95/d22183e95aa359a4bfa126050940009c.jpg" width="32"/>
</a>
<a class="companies-rating__name" href="/company/tuturu/">Туту.ру</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">603,49</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/otus/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/habr/company/968/422/761/968422761136a38a89fc391fd927f903.jpg" width="32"/>
</a>
<a class="companies-rating__name" href="/company/otus/">OTUS</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">549,48</span>
</div>
</li>
<li class="companies-rating__item">
<div class="companies-rating__body">
<a class="companies-rating__avatar" href="/company/lamptest/">
<img class="companies-rating__img" height="32" role="img" src="//habrastorage.org/getpro/geektimes/company/faa/8f3/29f/faa8f329f54ab8821c7f2d1459ec2bda.jpg" width="32"/>
</a>
<a class="companies-rating__name" href="/company/lamptest/">LampTest</a>
</div>
<div class="companies-rating__meta">
<span class="companies-rating__rating">537,02</span>
</div>
</li>
</ul>
</div>
<div class="default-block__footer">
<a class="default-block__footer-link" href="/companies/" rel="nofollow">Все компании</a>
</div>
</div>
<div class="default-block default-block_sidebar" id="most-reading">
<div class="default-block__header">
<h3 class="default-block__header-title">Читают сейчас</h3>
</div>
<div class="default-block__content default-block__content_most-read" id="broadcast_most-read">
<ul class="content-list content-list_most-read">
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://habr.com/ru/post/558858/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'post'); }">Как меня чуть не уволили из-за токсичного поведения и что было дальше</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter post-info__meta-counter_small">21,1k</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558858/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg>
<span class="post-info__meta-counter post-info__meta-counter_small">
                        101
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://habr.com/ru/company/vdsina/blog/558912/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'post'); }">Apple превращается в ещё одну Microsoft</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter post-info__meta-counter_small">4,8k</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/vdsina/blog/558912/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg>
<span class="post-info__meta-counter post-info__meta-counter_small">
                        8
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://habr.com/ru/post/558828/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'post'); }">Следует ли мне бросить видеоигры?</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter post-info__meta-counter_small">38,8k</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558828/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg>
<span class="post-info__meta-counter post-info__meta-counter_small">
                        322
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://habr.com/ru/company/vdsina/blog/558220/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'post'); }">Пиринговые мессенджеры — враг государства?</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter post-info__meta-counter_small">8,9k</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/vdsina/blog/558220/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg>
<span class="post-info__meta-counter post-info__meta-counter_small">
                        35
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://habr.com/ru/news/t/558888/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'post'); }">Google подала иск против Роскомнадзора</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter post-info__meta-counter_small">12,2k</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/news/t/558888/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg>
<span class="post-info__meta-counter post-info__meta-counter_small">
                        39
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://habr.com/ru/post/558864/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'post'); }">Недорогая видеостена на 8 мониторов (спойлер — NVidia)</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter post-info__meta-counter_small">22,6k</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558864/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg>
<span class="post-info__meta-counter post-info__meta-counter_small">
                        64
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title" href="https://u.habr.com/honormb15_chitayut" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'read_now,feed', 'https://u.habr.com/honormb15_chitayut'); }">Ноут для студента-программиста: обзор</a>
<div class="post-info__meta-label">
                    Мегапост
                  </div>
</li>
</ul>
</div>
</div>
</div>
</div>
</section>
<div class="overlay hidden" id="js-vote-result">
<div class="popup popup_reasons">
<div class="popup__head">
<span class="popup__head-title js-result-popup_title"></span>
<button class="btn btn_small btn_popup-close js-hide_result-reason" type="button">
<svg class="icon-svg" height="12" width="12">
<use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#close"></use>
</svg>
</button>
</div>
<div class="popup__body">
<div class="js-reasons-vote_result-empty">Пока никто не указал причину минусов</div>
<div class="js-reasons-vote_result-content">
<div class="reasons-vote__title">Причины минусов</div>
<div id="js-result-popup_list"></div>
</div>
</div>
</div>
</div>
</div>
</div>
<div class="layout__row layout__row_promo-blocks">
<div class="layout__cell">
<section class="column-wrapper column-wrapper_bottom column-wrapper_bordered">
<div class="content_left">
<div class="default-block default-block_content">
<div class="default-block__header default-block__header_large">
<h2 class="default-block__header-title default-block__header-title_large">Самое читаемое</h2>
</div>
<div class="default-block__content default-block__content_most-read" id="broadcast_tabs_posts">
<ul class="toggle-menu toggle-menu__most-read">
<li class="toggle-menu__item">
<a class="toggle-menu__item-link active" href="#broadcast_posts_today" rel="nofollow">Сутки</a>
</li>
<li class="toggle-menu__item">
<a class="toggle-menu__item-link" href="#broadcast_posts_week" rel="nofollow">Неделя</a>
</li>
<li class="toggle-menu__item">
<a class="toggle-menu__item-link" href="#broadcast_posts_month" rel="nofollow">Месяц</a>
</li>
</ul>
<div class="tabs__content tabs__content_reading" id="broadcast_posts_today">
<ul class="content-list content-list_most-read">
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/558828/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Следует ли мне бросить видеоигры?</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus41</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">38,8k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">91</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558828/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        322
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/558864/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Недорогая видеостена на 8 мониторов (спойлер — NVidia)</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus56</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">22,6k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">56</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558864/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        64
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/558858/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Как меня чуть не уволили из-за токсичного поведения и что было дальше</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus114</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">21,1k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">56</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558858/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        101
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/558866/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Спросите Итана: по какой фундаментальной причине E = mc²?</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus10</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">13,7k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">45</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/558866/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        26
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://u.habr.com/rt_chitayut" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'https://u.habr.com/rt_chitayut'); }">Ракеты и снаряды дата-инженеров</a>
<div class="post-info__meta-label">
                  Подборка
                </div>
</li>
</ul>
</div>
<div class="tabs__content tabs__content_reading" id="broadcast_posts_week">
<ul class="content-list content-list_most-read">
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/company/itsoft/blog/557504/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Банки ультимативно лезут к нам в ш̶т̶а̶н̶ы̶ личную жизнь</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus181</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">102k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">120</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/itsoft/blog/557504/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        398
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/company/itsoft/blog/558124/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Почему мир скоро может остаться без бананов</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus127</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">70,5k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">77</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/itsoft/blog/558124/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        251
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/company/ruvds/blog/556124/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Как Unix-way убивает десктопный Linux</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus202</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">59,4k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">183</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/ruvds/blog/556124/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        1613
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/company/dcmiran/blog/557708/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Ребята взломали машину для мороженого — и начали холодную войну с её производителем</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus74</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">58,9k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">50</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/dcmiran/blog/557708/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        222
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://u.habr.com/yprfs" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'https://u.habr.com/yprfs'); }">Работа для грустных: как выражение лица влияет на успех соискателя</a>
<div class="post-info__meta-label">
                  Турбо
                </div>
</li>
</ul>
</div>
<div class="tabs__content tabs__content_reading" id="broadcast_posts_month">
<ul class="content-list content-list_most-read">
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/553752/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Как рекламщики уничтожили электронную почту, и что сейчас они делают с мобильной связью</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus168</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">189k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">94</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/553752/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        752
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/554810/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Все английские времена в одной простой схеме</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus61</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">159k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">764</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/554810/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        124
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/company/vdsina/blog/555474/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Как я обогреваю свой дом при помощи майнинга криптовалют</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus50</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">112k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">124</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/company/vdsina/blog/555474/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        107
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://habr.com/ru/post/555884/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'post'); }">Что недоговаривают Тинькофф Инвестиции. Вытаскиваем все данные по портфелю через API в большую таблицу Excel</a>
<div class="post-info__meta">
<span class="post-info__meta-item" title="Рейтинг">
<svg class="post-info__meta-icon icon-svg_rating" height="13" width="11"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#arrow-bold"></use></svg><span class="post-info__meta-counter">&amp;plus148</span>
</span>
<span class="post-info__meta-item" title="Количество просмотров">
<svg class="post-info__meta-icon icon-svg_views" height="9" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-info__meta-counter">111k</span>
</span>
<span class="post-info__meta-item" title="Закладки">
<svg class="post-info__meta-icon icon-svg_bookmark-mini" height="13" width="8"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="post-info__meta-counter">489</span>
</span>
<a class="post-info__meta-item" href="https://habr.com/ru/post/555884/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'comment'); }" rel="nofollow" title="Комментарии">
<svg class="post-info__meta-icon icon-svg_comments" height="13" width="14"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-info__meta-counter">
                        104
                        
                      </span>
</a>
</div>
</li>
<li class="content-list__item content-list__item_devided post-info">
<a class="post-info__title post-info__title_large" href="https://u.habr.com/eduonline_chitayut" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block',  'most_read,feed' , 'https://u.habr.com/eduonline_chitayut'); }">Я бросила учёбу, падре! Как мы учимся онлайн</a>
<div class="post-info__meta-label">
                  Мегапост
                </div>
</li>
</ul>
</div>
</div>
</div>
</div>
<div class="sidebar">
<div class="sidebar_right">
<div class="content-list__item content-list__item_post shortcuts_item" id="effect-sidebar" style="display: none;">
<div class="default-block">
<div class="default-block__header">
<h2 class="default-block__header-title">Минуточку внимания</h2>
</div>
<div class="default-block__content">
<ul class="megapost-teasers" id="megapost-teasers-sidebar">
</ul>
</div>
</div>
</div>
</div>
</div>
</section>
</div>
</div>
<div class="layout__row layout__row_footer-links">
<div class="layout__cell">
<div class="footer-grid footer-grid_menu">
<div class="footer-grid__item footer-block">
<h3 class="footer-block__title">
      Ваш аккаунт
    </h3>
<div class="footer-block__content">
<ul class="footer-menu">
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/auth/login/">Войти</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/auth/register/">Регистрация</a>
</li>
</ul>
</div>
</div>
<div class="footer-grid__item footer-block">
<h3 class="footer-block__title">Разделы</h3>
<div class="footer-block__content">
<ul class="footer-menu">
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/posts/top/">Публикации</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/news/">Новости</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/hubs/">Хабы</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/companies/">Компании</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/users/">Пользователи</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/sandbox/">Песочница</a>
</li>
</ul>
</div>
</div>
<div class="footer-grid__item footer-block">
<h3 class="footer-block__title">Информация</h3>
<div class="footer-block__content">
<ul class="footer-menu">
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/docs/help/">Устройство сайта</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/docs/authors/">Для авторов</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/docs/companies/">Для компаний</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/docs/docs/">Документы</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://account.habr.com/info/agreement/?hl=ru_RU">Соглашение</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://account.habr.com/info/confidential/?hl=ru_RU">Конфиденциальность</a>
</li>
</ul>
</div>
</div>
<div class="footer-grid__item footer-block">
<h3 class="footer-block__title">Услуги</h3>
<div class="footer-block__content">
<ul class="footer-menu">
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://tmtm.ru/services/advertising/" target="_blank">Реклама</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://tmtm.ru/services/corpblog/" target="_blank">Тарифы</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://tmtm.ru/services/content/" target="_blank">Контент</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://tmtm.ru/workshops/" target="_blank">Семинары</a>
</li>
<li class="footer-menu__item">
<a class="footer-menu__item-link" href="https://habr.com/ru/megaprojects/" target="_blank">Мегапроекты</a>
</li>
</ul>
</div>
</div>
</div>
</div>
</div>
<div class="layout__row layout__row_footer">
<div class="layout__cell">
<script>
  $(document).ready(function () {
    window.voteReasonsList = JSON.parse('{"1":{"id":"1","title":"Низкий технический уровень материала","order":1},"2":{"id":"2","title":"Больше рекламы, чем пользы","order":2},"3":{"id":"3","title":"Не соответствует тематике Хабра","order":3},"4":{"id":"4","title":"В тексте много ошибок и опечаток","order":4},"5":{"id":"5","title":"Пост небрежно оформлен","order":5},"6":{"id":"6","title":"Личная неприязнь к автору или компании","order":6},"7":{"id":"7","title":"В статье нет новой для меня информации","order":7},"8":{"id":"8","title":"Ничего не понял после прочтения","order":8},"22":{"id":"22","title":"Не согласен с изложенным","order":9},"9":{"id":"9","title":"Другое","order":10}}');
  });
</script>
<script>

$(document).on('hljsUpdate', function () {
  if (typeof hljs === 'undefined') {
    initHighlightJS();
  } else {
    $('pre code').each(function (i, e) {
      hljs.highlightBlock(e, '    ');
    });
  }
})

function createScript(url) {
  var hljsScript = document.createElement("script");
  hljsScript.src = url;
  hljsScript.type = 'text/javascript';
  document.body.appendChild(hljsScript)

  return hljsScript;
}

function initHighlightJS() {
  if (typeof hljs !== 'undefined') {
    $('pre code').each(function (i, e) {
      hljs.highlightBlock(e, '    ');
    });
    return;
  };

  var hljsScript = createScript('https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/highlight.pack.js');

  hljsScript.onload = function() {
    var hljsLangs = createScript('https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/highlight.langs.js');
    hljsLangs.onload = function () {
      hljs.initHighlighting();
    }
  }
}


var codeElements = document.querySelectorAll('pre code');

if (codeElements.length) {
  initHighlightJS();
}

</script>
<script>

var mathElements = document.getElementsByTagName('math');

function mathJaxConfig() {
  MathJax.Hub.Config({
    showProcessingMessages: false,
    showMathMenu: true,
    tex2jax: {
      inlineMath: [['$inline$','$inline$']],
      displayMath: [['$$display$$','$$display$$']],
      processEscapes: true
    },
    MathMenu: {
      showRenderer: true,
      showContext:  true
    }
  });

  MathJax.Extension.Img2jax = {
    PreProcess: function (element) {
      var hasMath = false;
      var images = element.querySelectorAll('[data-tex]');
      for (var i = images.length - 1; i >= 0; i--) {
        var img = images[i];
        var tex = img.alt.replace(/(\r\n|\n|\r)/gm, " ");
        if (tex && tex[0] === '$'){
          var script = document.createElement("script"); script.type = "math/tex";
          hasMath = true;
          if (img.getAttribute('data-tex') == "display"){script.type += ";mode=display"}
          MathJax.HTML.setScript(script, tex.substring(1,tex.length-1));
          img.parentNode.replaceChild(script,img);
        }
      }
    }
  };

  MathJax.Hub.Register.PreProcessor(["PreProcess", MathJax.Extension.Img2jax]);
}

function mathjaxInit() {
 if (typeof MathJax === 'undefined') {
    var url = 'https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.1/MathJax.js?config=TeX-AMS_SVG-full&locale=ru';
    var mathScript = document.createElement("script");
    mathScript.src = url;
    mathScript.type = 'text/javascript';
    document.body.appendChild(mathScript)

    mathScript.onload = function() {
      mathJaxConfig();
    }
  } else {
    mathJaxConfig();
  }
}

if (mathElements.length) {
  mathjaxInit();
}

</script>
<div class="footer-grid footer">
<div class="footer-grid__item footer-grid__item_copyright">
<span class="footer__copyright">© 2006 – 2021 «<a class="footer__link" href="https://company.habr.com/">Habr</a>»</span>
</div>
<div class="footer-grid__item footer-grid__item_link footer-grid__item_lang">
<svg class="icon-svg icon-svg_lang-footer" height="16" width="16">
<use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#globus-v2"></use>
</svg>
<a class="footer__link js-show_lang_settings" href="#">Настройка языка</a>
</div>
<div class="footer-grid__item footer-grid__item_link">
<a class="footer__link" href="https://habr.com/ru/about/">О сайте</a>
</div>
<div class="footer-grid__item footer-grid__item_link">
<a class="footer__link" href="https://habr.com/ru/feedback/">Служба поддержки</a>
</div>
<div class="footer-grid__item footer-grid__item_link">
<a class="footer__link" href="https://m.habr.com/ru?mobile=yes">Мобильная версия</a>
</div>
<div class="footer-grid__item footer-grid__item_social">
<ul class="social-icons">
<li class="social-icons__item">
<a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_twitter" href="https://twitter.com/habr_com" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'twitter'); }" rel="nofollow noopener noreferrer" target="_blank">
<svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="
="social-icons__item-link social-icons__item-link_normal social-icons__item-link_youtube" href="https://www.youtube.com/channel/UCd_sTwKqVrweTt4oAKY5y4w" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'youtube'); }" rel="nofollow noopener noreferrer" target="_blank">
<svg aria-hidden="true" aria-labelledby="title" class="icon-svg" height="32" role="img" version="1.1" viewbox="0 0 32 32" width="32"><path d="M3.2 0h25.6c1.767 0 3.2 1.433 3.2 3.2v25.6c0 1.767-1.433 3.2-3.2 3.2h-25.6c-1.767 0-3.2-1.433-3.2-3.2v-25.6c0-1.767 1.433-3.2 3.2-3.2zm18.133 16l-10.667-5.333v10.667l10.667-5.333z"></path></svg>
</a>
</li>
<li class="social-icons__item">
<a class="social-icons__item-link social-icons__item-link_normal social-icons__item-link_zen" href="https://zen.yandex.ru/habr" onclick="if (typeof ga === 'function') { ga('send', 'event', 'footer', 'Social_icons', 'zen'); }" rel="nofollow noopener noreferrer" target="_blank">
<svg fill="none" height="30" viewbox="0 0 30 30" width="30" xmlns="http://www.w3.org/2000/svg">
<rect fill="#2C3036" height="30" rx="3" width="30"></rect>
<path clip-rule="evenodd" d="M26.25 15.1241V14.9998V14.8759C21.2684 14.7252 18.9904 14.6009 17.1735 12.8263C15.3994 11.0098 15.2747 8.73179 15.1243 3.75H15H14.8757C14.7253 8.73179 14.6006 11.0098 12.8264 12.8263C11.0095 14.6009 8.73151 14.7252 3.75 14.8759V14.9998V15.1241C8.73151 15.2748 11.0095 15.3991 12.8264 17.1733C14.6006 18.9903 14.7253 21.2682 14.8757 26.25H15H15.1243C15.2747 21.2682 15.3994 18.9903 17.1735 17.1733C18.9904 15.3991 21.2684 15.2748 26.25 15.1241Z" fill="white" fill-rule="evenodd"></path>
</svg>
</a>
</li>
</ul>
</div>
</div>
</div>
</div>
<a class="layout__elevator hidden" href="#" id="scroll_to_top" onclick="if (typeof ga === 'function') { ga('send', 'event', 'navigation_button', 'down'); }" title="Наверх">
<svg aria-hidden="true" class="icon-svg icon-svg_scroll-up" height="32" role="img" version="1.1" viewbox="0 0 32 32" width="32"><path d="M16 0C7.164 0 0 7.164 0 16s7.164 16 16 16 16-7.164 16-16S24.836 0 16 0zm8.412 19.523c-.517.512-1.355.512-1.872 0L16 13.516l-6.54 6.01c-.518.51-1.356.51-1.873 0-.516-.513-.517-1.343 0-1.855l7.476-7.326c.517-.512 1.356-.512 1.873 0l7.476 7.327c.516.513.516 1.342 0 1.854z"></path></svg>
</a>
</div>
<div class="overlay hidden" id="js-lang_settings">
<div class="popup">
<div class="popup__head popup__head_lang-settings">
<span class="popup__head-title js-popup_title" data-section="1">Настройка языка</span>
<button class="btn btn_small btn_popup-close js-hide_lang_settings" type="button">
<svg class="icon-svg" height="12" width="12">
<use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#close"></use>
</svg>
</button>
</div>
<div class="popup__body">
<form action="/json/settings/i18n/" class="form form_lang-settings" id="lang-settings-form" method="post">
<fieldset class="form__fieldset form__fieldset_thin" data-section="2">
<legend class="form__legend form__legend_lang-settings js-popup_hl_legend">Интерфейс</legend>
<div class="form-field form-field_lang-settings">
<span class="radio radio_custom">
<input checked="" class="radio__input js-hl_langs" id="hl_langs_ru" name="hl" type="radio" value="ru"/>
<label class="radio__label radio__label_another" for="hl_langs_ru">Русский</label>
</span>
</div>
<div class="form-field form-field_lang-settings">
<span class="radio radio_custom">
<input class="radio__input js-hl_langs" id="hl_langs_en" name="hl" type="radio" value="en"/>
<label class="radio__label radio__label_another" for="hl_langs_en">English</label>
</span>
</div>
</fieldset>
<fieldset class="form__fieldset form__fieldset_thin">
<legend class="form__legend form__legend_lang-settings js-popup_fl_legend" data-section="3">Язык публикаций</legend>
<div class="form-field form-field_lang-settings">
<span class="checkbox checkbox_custom">
<input checked="" class="checkbox__input js-fl_langs" id="fl_langs_ru" name="fl[]" type="checkbox" value="ru"/>
<label class="checkbox__label checkbox__label_another js-popup_feed_ru" for="fl_langs_ru">Русский</label>
</span>
</div>
<div class="form-field form-field_lang-settings">
<span class="checkbox checkbox_custom">
<input class="checkbox__input js-fl_langs" id="fl_langs_en" name="fl[]" type="checkbox" value="en"/>
<label class="checkbox__label checkbox__label_another js-popup_feed_en" for="fl_langs_en">Английский</label>
</span>
</div>
</fieldset>
<div class="form__footer form__footer_lang-settings">
<button class="btn btn_blue btn_huge btn_full-width js-popup_save_btn" type="submit">Сохранить настройки</button>
</div>
</form>
</div>
</div>
</div>
<script>
  function composeTeaser(t, blockType) {
    const listener = " onclick=\"if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'promo,"
      + blockType + "', '"+ t.linkUrl +"'); }\"";
    let teaser = '<li class="megapost-teasers__item teaser">'
    + '<a href="' + t.linkUrl + '" target="_blank" class="teaser__image" rel="nofollow';

    if (t.external) teaser += ' sponsored';

    teaser += '"';

    teaser += listener;

    teaser += '>'
    + '<img src="' + t.imageUrl + '" class="teaser__image-pic"/>'
    + '<div class="megapost-teasers__label">'
    + t.label;

    if (t.external) teaser += `<svg width="11" height="11" viewBox="0 0 11 11" fill="none" xmlns="http://www.w3.org/2000/svg">
<path fill-rule="evenodd" clip-rule="evenodd" d="M7.5 0C7.22386 0 7 0.223858 7 0.5C7 0.776142 7.22386 1 7.5 1H9.29289L5.14645 5.14645C4.95118 5.34171 4.95118 5.65829 5.14645 5.85355C5.34171 6.04882 5.65829 6.04882 5.85355 5.85355L10 1.70711V3.5C10 3.77614 10.2239 4 10.5 4C10.7761 4 11 3.77614 11 3.5V0.5C11 0.223858 10.7761 0 10.5 0H7.5ZM0.5 1C0.223858 1 0 1.22386 0 1.5V10.5C0 10.7761 0.223858 11 0.5 11H9.5C9.77614 11 10 10.7761 10 10.5V6C10 5.72386 9.77614 5.5 9.5 5.5C9.22386 5.5 9 5.72386 9 6V10H1V2H5C5.27614 2 5.5 1.77614 5.5 1.5C5.5 1.22386 5.27614 1 5 1H0.5Z" fill="#6667A2"/>
</svg>
`;

    teaser += '</div></a>'
    + '<a href="' + t.linkUrl + '" target="_blank" class="teaser__body" rel="nofollow';

    if (t.external) teaser += ' sponsored';

    teaser += '"';

    teaser += listener;

    teaser += '>'
    + '<h3 class="teaser__body-title">'
    + t.title
    + '</h3></a></li>';

    return teaser;
  }
</script>
<script type="text/javascript">
  // global vars
  var g_base_url = 'habr.com/ru';
  var g_base_fullurl = 'https://habr.com/ru/';
  var g_tmid_fullurl = 'https://account.habr.com/';
  var g_is_guest = false;
  var g_show_xpanel = false;
  var g_is_enableShortcuts = '1';
  var g_is_ugc_post = '';
  var g_is_company_post = '';
  var g_current_hl = 'ru';
  var g_current_fl = 'ru';

</script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/vendors.bundle.js"></script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/main.bundle.js"></script>
<script src="https://dr.habracdn.net/habr/oldassets/60a75345/javascripts/check-login.js"></script>
<!-- Yandex.Metrika counter -->
<script type="text/javascript">
(function(m,e,t,r,i,k,a){
  m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
  m[i].l=1*new Date();
  k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)
})(window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");

    ym(24049213, "init", {
      clickmap:true
      , trackLinks:true
      , accurateTrackBounce:true
    });
</script>
<noscript>
<div>
<img alt="" src="https://mc.yandex.ru/watch/24049213" style="position:absolute; left:-9999px;"/>
</div>
</noscript>
<!-- /Yandex.Metrika counter -->
<script type="text/javascript">
  function stripUrl(currentUrl, queryParam) {
   return currentUrl.replace(/\?([^#]*)/, function(_, search) {
      var result = search.split('&').map(function(param) {
        var regexp = new RegExp(`^${queryParam}`);
        if (regexp.test(param)) {
          return '';
        }
        return param;
      }).filter(Boolean).join('&');
      return result ? '?' + result : '';
    });
  }

  (function() {
    if (location.search.indexOf('cv') != -1 && history.replaceState) {
      var currentUrl = location.toString();
      var strippedUrl = stripUrl(currentUrl, 'cv');
      history.replaceState({}, '', strippedUrl);
    }
  })();

  function callGA(usesABP) {
    if (typeof window.adb1 === 'undefined') { window.adb1 = 'yes';}
    if (usesABP) { window.adb1 = 'aa'; }

    var user_type = 'guest';

    var page_type = "other";

    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
      m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');

        ga('create', 'UA-726094-1',  'auto');
        ga('create', 'UA-726094-24', 'auto', {'name': 'HGM', 'allowLinker': true});

    ga('HGM.require', 'linker');
    ga('HGM.linker:autoLink', ['toster.ru', 'habr.com', 'account.habr.com', 'm.habr.com']);

    ga('require', 'displayfeatures');
    ga('set', 'dimension1', user_type); // user type - guest/readonly/habrauser
    ga('set', 'dimension2', page_type);
    ga('set', 'dimension3', 'na');
    ga('set', 'dimension4', window.adb1);
    ga('set', 'dimension6', 'ru');
    


    (function() {
      var removeUtms = function(){
        var location = window.location;
        if (location.search.indexOf('utm_') != -1 && history.replaceState) {
          var currentUrl = location.toString();
          var strippedUrl = stripUrl(currentUrl, 'utm_');
          history.replaceState({}, '', strippedUrl);
        }
      };
      ga('require', 'GTM-559GVC8');
      ga('send', 'pageview', { 'hitCallback': removeUtms });
    })();

    ga('HGM.set', 'dimension1', user_type);
    ga('HGM.set', 'dimension2', "habrahabr");
    ga('HGM.set', 'dimension4', window.adb1);

    ga('HGM.send', 'pageview');
  }


  if (window.habr_blockers_checker) {
    window.habr_blockers_checker.detectWrapper(callGA);
  } else {
    callGA(false)
  }

</script>
<!-- Facebook Pixel Code -->
<img height="1" src="https://www.facebook.com/tr?id=317458588730613&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"
span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556050" data-post-type="publish_ugc_ru,h_21910,h_21968,h_22022" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">73</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">22,7k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556050/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">101</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/ArkadiyXIII/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/47c/a40/834/47ca40834e97604a4298612c8b345dae.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">ArkadiyXIII</span>
 </a>
 <span class="post__time">6 мая 2021 в 07:47</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556002/">Для чего нужно интеграционное тестирование?</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it_testing/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Тестирование IT-систем'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Тестирование IT-систем</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/refactoring/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Проектирование и рефакторинг'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Проектирование и рефакторинг</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/web_testing/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Тестирование веб-сервисов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Тестирование веб-сервисов</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__text post__text-html post__text_v2">
 <p>Эта статья является конспектом книги «<a href="https://www.litres.ru/vladimir-horikov/principy-unit-testirovaniya-pdf-epub-64083637/" rel="noopener noreferrer nofollow">Принципы юнит-тестирования</a>». Материал статьи посвящен интеграционным тестам.</p><p>Юнит-тесты прекрасно справляются с проверкой бизнес-логики, но проверять эту логику «в вакууме» недостаточно. Необходимо проверять, как разные ее части интегрируются друг с другом и внешними системами: базой данных, шиной сообщений и т. д.</p><p>В этой статье рассматривается роль интеграционных тестов, когда их следует использовать и когда лучше положиться на классические юнит-тесты. Также затронем эффективное написание интеграционных тестов.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556002/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_210,h_359,h_7504,h_19279" id="infopanel_post_556002">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 4: ↑3 и ↓1">+2</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556002" data-post-type="publish_ugc_ru,h_210,h_359,h_7504,h_19279" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">41</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">4,3k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556002/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">3</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">capissimo</span>
 </a>
 <span class="post__time">6 мая 2021 в 07:17</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556048/">Python, исследование данных и выборы: часть 5</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/1c2/952/165/1c29521658bfe85baf4f348a33f93f24.png" style="object-position: % %">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Заключительный пост №5<strong> для</strong> <strong>начинающих</strong> посвящен сопоставительной визуализации электоральных данных.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556048/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556048">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑2 и ↓1">+1</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556048" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">35</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">2,1k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556048/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">8</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">capissimo</span>
 </a>
 <span class="post__time">6 мая 2021 в 06:34</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556044/">Python, исследование данных и выборы: часть 4</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/848/ff2/331/848ff2331f6b0abf9367f56628da0abf.png" style="object-position: % %">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Пост №4 <strong>для</strong> <strong>начинающих</strong> посвящен техническим приемам визуализации данных.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556044/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556044">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter" title="Всего голосов 2: ↑1 и ↓1">0</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556044" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">25</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,2k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556044/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">capissimo</span>
 </a>
 <span class="post__time">6 мая 2021 в 06:01</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556042/">Python, исследование данных и выборы: часть 3</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/c90/bd9/7ef/c90bd97efe58d8c07d83a7265da0eed1.png" style="object-position: % %">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Пост №3 <strong>для</strong> <strong>начинающих</strong> посвящен генерированию распределений, их свойствам, а также графикам для их сопоставительного анализа.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556042/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556042">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter" title="Всего голосов 2: ↑1 и ↓1">0</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556042" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">28</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,5k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556042/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">2</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">capissimo</span>
 </a>
 <span class="post__time">6 мая 2021 в 05:02</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556040/">Python, исследование данных и выборы: часть 2</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/f08/8c0/f3b/f088c0f3b91e38dcaabb2b59639a3f50.png" style="object-position: % %">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Пост №2<strong> для</strong> <strong>начинающих</strong> посвящен описательным статистикам, группированию данных и нормальному распределению. Все эти сведения заложат основу для дальнейшего анализа электоральных данных.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556040/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556040">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов
a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/health/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Здоровье'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Здоровье</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/futurenow/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Будущее здесь'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Будущее здесь</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/webt/vp/ng/t_/vpngt_iecxrqwxfcyp3pti9cjzo.jpeg" style="object-position: 0% 0%">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>В последнее время в продуктовых магазинах (окей, лента и др) стали появляться <strong>"промышленные" лампы</strong>. Я специально не стал указывать бренд в заголовке, они отличаются только надписью на лампе, даже ценник примерно одинаковый.</p><p>Есть на 20Вт и более - но все их объединяет одно <s>их лучше не покупать</s>, они очень легкие и стоят разумных денег, до 600р.</p><p>Конечно же, нам обещают <s>300часов</s> 30 000часов работы, отсутствие пульсаций, а некоторые производители заявляют о промышленном применении данных ламп, но к этому мы еще вернемся.</p><p>Нам обещают: 40Вт, ЦТ 4000k, световой поток 3200лм (<a href="http://ecola.ru/catalogue60.html" rel="noopener noreferrer nofollow">http://ecola.ru/catalogue60.html</a>)</p><p>На практике: <strong><em>построена лампа на чипе bp2865g, имеет активную мощность ~36Вт, но PF(cosf) ~0,52</em></strong>, т.е. получаем потребление ~55Ва, <a href="https://habr.com/ru/company/lamptest/blog/535596/" rel="noopener noreferrer nofollow">сразу вспоминаем статью Lamptest </a>(при мощности ламп более 20Вт должен быть PF(cosf) ~0,9).</p><p>Немного снимков с тепловизора, лампа работает 7 минут, корпус разогрелся всего до 80 градусов.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556028/#habracut">Узнать что в них промышленного</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21996,h_22014" id="infopanel_post_556028">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 12: ↑8 и ↓4">+4</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556028" data-post-type="publish_ugc_ru,h_21996,h_22014" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">13</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">10,6k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556028/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">17</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/Furriest/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/927/130/b05/927130b056159f52821165e8bdce69d7.png" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">Furriest</span>
 </a>
 <span class="post__time">5 мая 2021 в 22:36</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556024/">Настраиваем отказоустойчивость Pi-Hole в связке с Mikrotik</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/network_technologies/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Сетевые технологии'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Сетевые технологии</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/a38/cc0/0a3/a38cc00a3b980ef2fcd235f8da23b48d.png" style="object-position: 0% 86.136363636364%">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>В <a href="https://habr.com/ru/post/468621/" rel="noopener noreferrer nofollow">прошлой статье</a> мы внедрили домашний сервер DoH с использованием Pi-Hole, чем не только пофильтровали большое количество рекламы, но и инкапсулировали наши DNS-запросы в HTTPS, что вывело их из поля фильтрации запросов оператором связи.</p><p>Всем замечательно это решение, но у него есть один нюанс. Если вдруг у нас закончились деньги на счету у оператора связи или по каким-то другим причинам пропал канал связи до внешнего мира, мы даже не сможем пополнить счет, чтобы восстановить сервис, потому что не будет работать DNS. Или, например, если наш Pi-Hole по каким-то причинам перестал работать -  вот вроде и вся сеть работает, и гугл пингуется, а пока не пропишешь другой DNS-сервер - не будет счастья. А если вы еще в этот момент заняты чем-то другим и не можете приступить к восстановлению незамедлительно - домашние негодуют, портят радостное существование своими жалобами и даже котики, чуя общую нервозность, стремятся нагадить вам в тапки.</p><p>Огорчать котиков - дело последнее, поэтому в этой статье я опишу, как вы можете внедрить автоматическое переключение с использования Pi-Hole на использование операторских (как, впрочем, и любых других) DNS при проблемах на Pi-Hole. </p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556024/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_17123" id="infopanel_post_556024">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 16: ↑16 и ↓0">+16</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556024" data-post-type="publish_ugc_ru,h_17123" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">99</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">9,1k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556024/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">13</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/egaxegax/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/377/221/2ca/3772212cae56cdecf113de497f75fddf.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">egaxegax</span>
 </a>
 <span class="post__time">5 мая 2021 в 21:21</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556018/">Карта метро Москвы с расчётом пути</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/javascript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'JavaScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">JavaScript</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/vector_graphics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Работа с векторной графикой'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Работа с векторной графикой</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/html5/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'HTML'); }" rel="nofollow" title="Вы не подписаны на этот хаб">HTML</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/canvas/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Canvas'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Canvas</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/423/4db/aee/4234dbaee2ee94f6cb5e44dc03b91c7c.png" style="object-position: 0% 0%">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>В своей предыдущей статье про интерактивную <a href="http://habrahabr.ru/post/268199" rel="noopener noreferrer nofollow">карту метро Москвы</a> я описывал процесс создания векторной карты на <em>svg</em>-движке, сравнивая с канвасным отображением. </p><p>Спустя время я решил вернуться к своей <a href="https://egaxegax.github.io/dbcartajs/svg/mosmetro.html" rel="noopener noreferrer nofollow">карте</a> и добавил в неё возможность вывода маршрута кратчайшего пути между выбранными станциями по алгоритму <a href="https://habr.com/ru/post/200252" rel="noopener noreferrer nofollow">BFS</a>, обхода графа в ширину.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556018/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_357,h_449,h_17103,h_17187" id="infopanel_post_556018">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑5 и ↓1">+4</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556018" data-post-type="publish_ugc_ru,h_357,h_449,h_17103,h_17187" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">19</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">6,1k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556018/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">14</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/ph_piter/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/3be/b11/2b0/3beb112b076924a916b27c845d88dcfa.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">ph_piter</span>
 </a>
 <span class="post__time">5 мая 2021 в 21:16</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/company/piter/blog/555860/">Издательство Питер. Колонка редактора</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/piter/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Издательский дом «Питер»'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Издательский дом «Питер»</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/lib/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Профессиональная литература'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Профессиональная литература</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__text post__text-html post__text_v1">
 <a href="https://habr.com/ru/company/piter/blog/555860/"><div style="text-align:center;"><img alt="image" src="https://habrastorage.org/webt/mi/sm/cq/mismcqetge7xg2rmwga6uqsr8su.png"/></div></a><br/>
 Привет, Хаброжители! Предлагаем ознакомиться с краткими обзорами сданных в типографию новинок. <br/>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/piter/blog/555860/#habracut">Читать дальше →</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_piter,h_19309" id="infopanel_post_555860">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 7: ↑5 и ↓2">+3</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555860" data-post-type="publish_corp_ru,c_piter,h_19309" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">3k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/company/piter/blog/555860/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">7</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/gerasimovich/" title="Автор публикации">
 <span class="default-image_mini default-image_green">
 <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
 </span>
 <span class="user-info__nickname user-info__nickname_small">gerasimovich</span>
 </a>
 <span class="post__time">5 мая 2021 в 21:05</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/company/it_people/blog/555916/">Три способа стать геймдизайнером, иконы игр и тренды GameDev. Интервью конференции DUMP</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/it_people/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании IT-People'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании IT-People</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/tech_events/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Конференции'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Конференции</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/game_design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Дизайн игр'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Дизайн игр</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/interviews/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Интервью'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Интервью</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/cfc/2af/348/cfc2af3480aa7491894a66d007e80ac6.jpg" style="object-position: 0% 0%"/>
 </div>
 <div class="post__text post__text-html post__text_v2">
 <p>Когда играешь в особенно крутую игру, останавливаться не хочется, пока не пройдешь всё до конца. А ещё хочется создать свою игру! Знакомая история? Для участников DUMP тоже:) В этом году впервые на конференции будет представлена секция GameDev. </p><p>Мы решили узнать больше о разработке игр и пообщались с представителями индустрии из компании Targem Games — Евгением Бушуевым (Game Designer Crossout) и Алексеем Честных (Creative Director).</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/it_people/blog/555916/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_it_people,h_20754,h_20800,h_22020" id="infopanel_post_555916">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 1: ↑1 и ↓0">+1</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555916" data-post-type="publish_corp_ru,c_it_people,h_20754,h_20800,h_22020" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">9</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,3k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/company/it_people/blog/555916/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">4</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/danaumov/" title="Автор публикации">
 <span class="default-image_mini default-image_green">
 <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
 </span>
 <span class="user-info__nickname user-info__nickname_small">danaumov</span>
 </a>
 <span class="post__time">5 мая 2021 в 19:59</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/company/rshb/blog/556004/">Вклад биотехнологий в решение проблем Агротеха</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/rshb/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Россельхозбанк'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Россельхозбанк</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/biotech/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Биотехнологии'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Биотехнологии</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/92e/1ce/86a/92e1ce86a9e293ad32d5a8f8994cda58.png" style="object-position: 0% 0%"/>
 </div>
 <div class="post__text post__text-html post__text_v2">
 <p><strong>Проблемы аграриев взялись решать биотехнологи</strong></p><p>Благодаря биотехнологиям, всё больше процессов в агросфере выстраивается так, чтобы быть эффективными и прибыльными, не нанося вред природе. От специалистов-биотехнологов зависит, будем ли мы выращивать овощи и фрукты на городских мини-фермах и <a href="https://habr.com/ru/company/rshb/blog/546370/">будет ли мясо производиться в пробирке</a> из одной клетки или печататься на 3D-принтере и многое другое. </p><p>Существенную долю рынка мировых биотехнологий, - 51 %, составляют сельское хозяйство, пищевая промышленность и химпром. По <a href="https://rosng.ru/post/posle-koronavirusa-v-mire-nachnetsya-rost-biotehnologiy-ekspert">прогнозам экспертов</a>, до 2028 года рост рынка биотехнологий в год составит в среднем 15 %. </p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/rshb/blog/556004/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_rshb,h_21912" id="infopanel_post_556004">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 12: ↑9 и ↓3">+6</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556004" data-post-type="publish_corp_ru,c_rshb,h_21912" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">11</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">2,2k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/company/rshb/blog/556004/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" id="post-stats-comments-count" title="Добавить комментарий">Комментировать</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/honyaki/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/96e/81d/bc0/96e81dbc01247c6c855b1806b355efa3.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">honyaki</span>
 </a>
 <span class="post__time">5 мая 2021 в 19:45</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/company/skillfactory/blog/555914/">Как я посчитал миллионное число Фибоначчи</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/skillfactory/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании SkillFactory'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании SkillFactory</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/zadachki/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Занимательные задачки'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Занимательные задачки</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/maths/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Математика'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Математика</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/de4/f4e/871/de4f4e871d23e5f9d6715fc3d8ccec02.jpg" style="object-position: 0% 87.272727272727%">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Все мы понимаем, что рекурсивное вычисление чисел Фибоначчи крайне неэффективно. Многим людям наверняка хотелось проверить, где пределы (не)эффективности, но не доходили руки, не хватало времени. Специально к старту нового потока курса <a href="https://skillfactory.ru/python-fullstack-web-developer?utm_source=infopartners&amp;utm_medium=habr&amp;utm_campaign=habr_FPW&amp;utm_term=regular&amp;utm_content=050521">Fullstack-разработчик на Python</a> мы решили поделиться переводом статьи, автор которой шаг за шагом показывает возможности современного Python на примере разных подходов к вычислению чисел Фибоначчи. В статье вы найдёте проблемные значения n и сравнение производительности оптимального и неоптимального решений на графике.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/skillfactory/blog/555914/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_skillfactory,h_287,h_340,h_17812" id="infopanel_post_555914">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 29: ↑15 и ↓14">+1</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555914" data-post-type="publish_corp_ru,c_skillfactory,h_287,h_340,h_17812" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">35</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">5,7k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/company/skillfactory/blog/555914/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">34</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/capissimo/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/42b/59f/84e/42b59f84e300138acabe4900f4254800.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">capissimo</span>
 </a>
 <span class="post__time">5 мая 2021 в 19:35</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/556000/">Python, исследование данных и выборы: часть 1</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/programming/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Программирование</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_mining/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Data Mining'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Data Mining</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/study/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Учебный процесс в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Учебный процесс в IT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/statistics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Статистика в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Статистика в IT</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Обучающий материал">Tutorial</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/1c7/3ce/7ac/1c73ce7ac215107a7b21810d3ebfce74.png" style="object-position: % %">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Серия из 5 постов <strong>для</strong> <strong>начинающих</strong> представляет собой «ремикс» первой главы книги 2015 года под названием «Clojure для исследования данных» (Clojure for Data Science). Автор книги, Генри Гарнер, любезно дал согласие на использование материалов книги для данного ремикса с использованием языка Python.</p><p>Книга была написана как приглашение в так называемую «науку о данных», которая в последние годы получила сильный импульс к развитию в связи с потребностью в быстрой и своевременной обработке больших наборов данных локально и в распределенной среде.  </p><p>Три главы книги были адаптированы под язык Python в течение следующего года после издания книги, т.е. в 2016 году. Публикация ремикса книги в РФ не получилась по разным причинам, но одна из главных станет понятной в конце этой серии постов. В конце заключительного поста можно будет проголосовать за или против размещения следующей серии постов. А пока же…</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/556000/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" id="infopanel_post_556000">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 5: ↑4 и ↓1">+3</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="556000" data-post-type="publish_ugc_ru,h_340,h_359,h_7152,h_20696,h_21890" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">74</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">4,4k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/556000/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">4</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/Stedihabr/" title="Автор публикации">
 <span class="default-image_mini default-image_pink">
 <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
 </span>
 <span class="user-info__nickname user-info__nickname_small">Stedihabr</span>
 </a>
 <span class="post__time">5 мая 2021 в 19:22</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/company/itsoft/blog/555998/">Украдено у Apple</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/itsoft/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании ITSOFT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании ITSOFT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/history/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'История IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">История IT</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/antikvariat/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Старое железо'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Старое железо</a>, 
         </li>
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it_bigraphy/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Биографии гиков'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Биографии гиков</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/e9c/b11/447/e9cb1144709e3b787d77bbe13e0164b1.png" style="object-position: 0% 0%"/>
 </div>
 <div class="post__text post__text-html post__text_v2">
 <p>В 1980 году компания Franklin Computer выпустила клон Apple II под названием Franklin Ace, разработанный под «яблочное» ПО. Из Apple II скопировали практически все, включая программное обеспечение из ПЗУ и документацию, и продали клон по более низкой цене. Мы даже нашли место в мануале, где забыли поменять «Apple» на «Ace». В Apple пришли в ярость и подали на Franklin в суд. В конце концов мы победили и вынудили Franklin убрать Ace с рынка.  </p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/itsoft/blog/555998/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_itsoft,h_21906,h_21930,h_21938" id="infopanel_post_555998">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов
a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/176/775/b2a/176775b2a73b083fdfb11703c730bbda.jpg" style="object-position: 0% 0%"/>
 </div>
 <div class="post__text post__text-html post__text_v2">
 <p>Обычно когда речь идет про «научную фантастику», то наукой, которая лежит в основе сюжетов выступают физика, биология, может, компьютерные технологии. Что-то из области точных наук. Но некоторые фантасты не спешат идти проторенными путями, предпочитая удивлять читателя. Например, обращаясь к лингвистике и показывая миры или конфликты, в которых слово играет ключевую роль. </p><p>Очень приятно знакомиться с изобретательными способами показать, что речь — это инструмент, причем весьма функциональный и пластичный. На тему необычных языковых систем, вопросов взаимопонимания и того, как слово может влиять на человека (и не только) можно сказать не меньше интересных вещей, чем по поводу искусственного интеллекта или терраформирования Марса. Вот несколько тому примеров.</p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/555988/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21984" id="infopanel_post_555988">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 34: ↑32 и ↓2">+30</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555988" data-post-type="publish_ugc_ru,h_21984" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">135</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">14,7k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/555988/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">23</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>,
 <article class="post post_preview" lang="ru">
 <header class="post__meta">
 <a class="post__user-info user-info" href="https://habr.com/ru/users/biolog_snork/" title="Автор публикации">
 <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/359/2e8/8a7/3592e88a7977d3df342bbcdff9e52244.jpg" width="24"/>
 <span class="user-info__nickname user-info__nickname_small">biolog_snork</span>
 </a>
 <span class="post__time">5 мая 2021 в 18:43</span>
 </header>
 <h2 class="post__title">
 <a class="post__title_link" href="https://habr.com/ru/post/555934/">Страшные волосатики, или посмертный кошмар кузнечика</a>
 </h2>
 <ul class="post__hubs inline-list">
 <li class="inline-list__item inline-list__item_hub">
 <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/popular_science/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Научно-популярное'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Научно-популярное</a>
 </li>
 </ul>
 <ul class="post__marks inline-list"></ul>
 <div class="post__body post__body_crop">
 <div class="post__body-cover post__body-cover_fit-cover">
 <img src="https://habrastorage.org/getpro/habr/upload_files/8d6/48d/c7e/8d648dc7e3d596d8b2ae7138a7ac1fc7.jpg" style="object-position: 0% 0%">
 </img></div>
 <div class="post__text post__text-html post__text_v2">
 <p>Волосатики — это тип, как правило, паразитоидных животных клады нематоид. Данные существа являются очень милыми свободно живущими червячками внешне похожими на нематод. Правда свободно живущими они являются только на взрослой стадии развития, потому-то их и называют паразитоидами. </p>
 </div>
 <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/555934/#habracut">Читать далее</a>
 </div>
 <footer class="post__footer">
 <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21910" id="infopanel_post_555934">
 <li class="post-stats__item">
 <div class="post-stats__result">
 <span class="post-stats__result-icon">
 <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#counter-rating"></use></svg>
 </span>
 <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 26: ↑23 и ↓3">+20</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_bookmark">
 <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="555934" data-post-type="publish_ugc_ru,h_21910" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
 <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>
 </button>
 </li>
 <li class="post-stats__item post-stats__item_views">
 <div class="post-stats__views" title="Количество просмотров">
 <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">7,2k</span>
 </div>
 </li>
 <li class="post-stats__item post-stats__item_comments">
 <a class="post-stats__comments-link" href="https://habr.com/ru/post/555934/#comments" rel="nofollow">
 <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/oldassets/60a75345/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" id="post-stats-comments-count" title="Читать комментарии">10</span>
 </a>
 </li>
 </ul>
 </footer>
 </article>]
In [11]:
# добрались до ссылок

list_link = []
for article in all_info:
    my_link = article.find('a', class_= 'post__title_link').get('href')
    list_link.append(my_link)
    
list_link
Out[11]:
['https://habr.com/ru/post/556056/',
 'https://habr.com/ru/post/556050/',
 'https://habr.com/ru/post/556002/',
 'https://habr.com/ru/post/556048/',
 'https://habr.com/ru/post/556044/',
 'https://habr.com/ru/post/556042/',
 'https://habr.com/ru/post/556040/',
 'https://habr.com/ru/company/southbridge/blog/544730/',
 'https://habr.com/ru/company/itsoft/blog/556038/',
 'https://habr.com/ru/post/556028/',
 'https://habr.com/ru/post/556024/',
 'https://habr.com/ru/post/556018/',
 'https://habr.com/ru/company/piter/blog/555860/',
 'https://habr.com/ru/company/it_people/blog/555916/',
 'https://habr.com/ru/company/rshb/blog/556004/',
 'https://habr.com/ru/company/skillfactory/blog/555914/',
 'https://habr.com/ru/post/556000/',
 'https://habr.com/ru/company/itsoft/blog/555998/',
 'https://habr.com/ru/post/555988/',
 'https://habr.com/ru/post/555934/']
In [12]:
# обернем наши действия в функцию , только одна страница

def all_links_1(URL):
    res = requests.get(URL)
    soup = BeautifulSoup(res.text, 'html.parser')
    all_info = soup.find_all('article', class_='post')
    list_link = []
    for article in all_info:
        my_link = article.find('a', class_= 'post__title_link').get('href')
        list_link.append(my_link)
    return list_link
In [13]:
# обернем наши действия в функцию , все страницы с постами

def all_links_2(URL):
    list_link = []
    res_1 = requests.get(URL)
    soup_1 = BeautifulSoup(res_1.text, 'html.parser')
    number_page = soup_1.find('a', class_='toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_bordered').get('href')
    for x in range(1,int(number_page[-3:-1])+1):
        url_links = f'https://habr.com/ru/all/page{x}'
        res_2 = requests.get(url_links)
        soup_2 = BeautifulSoup(res_2.text, 'html.parser')
        all_info = soup_2.find_all('article', class_='post')
        for article in all_info:
            my_link = article.find('a', class_= 'post__title_link').get('href')
            list_link.append(my_link)
    return list_link
In [14]:
all_links_1(URL)
Out[14]:
['https://habr.com/ru/company/agima/blog/558060/',
 'https://habr.com/ru/company/otus/blog/558958/',
 'https://habr.com/ru/post/558800/',
 'https://habr.com/ru/post/558954/',
 'https://habr.com/ru/post/558938/',
 'https://habr.com/ru/post/558556/',
 'https://habr.com/ru/company/vdsina/blog/558912/',
 'https://habr.com/ru/post/556148/',
 'https://habr.com/ru/company/ruvds/blog/554296/',
 'https://habr.com/ru/company/selectel/blog/555930/',
 'https://habr.com/ru/company/raiffeisenbank/blog/556128/',
 'https://habr.com/ru/post/556134/',
 'https://habr.com/ru/company/rosbank/blog/556122/',
 'https://habr.com/ru/company/macloud/blog/556092/',
 'https://habr.com/ru/post/556084/',
 'https://habr.com/ru/post/556112/',
 'https://habr.com/ru/company/redhatrussia/blog/555714/',
 'https://habr.com/ru/company/vdsina/blog/555994/',
 'https://habr.com/ru/post/556100/',
 'https://habr.com/ru/post/556090/',
 'https://habr.com/ru/company/vdsina/blog/555140/',
 'https://habr.com/ru/company/timeweb/blog/556080/',
 'https://habr.com/ru/company/ruvds/blog/555642/',
 'https://habr.com/ru/post/539038/',
 'https://habr.com/ru/company/selectel/blog/555926/',
 'https://habr.com/ru/post/556076/',
 'https://habr.com/ru/company/kaspersky/blog/556030/',
 'https://habr.com/ru/post/556054/',
 'https://habr.com/ru/company/2035_university/blog/556070/',
 'https://habr.com/ru/company/deutschetelekomitsolutions/blog/554384/',
 'https://habr.com/ru/company/htmlacademy/blog/554776/',
 'https://habr.com/ru/company/macloud/blog/556008/',
 'https://habr.com/ru/company/veeam/blog/555880/',
 'https://habr.com/ru/post/556062/',
 'https://habr.com/ru/company/productivity_inside/blog/556058/',
 'https://habr.com/ru/post/556056/',
 'https://habr.com/ru/post/556050/',
 'https://habr.com/ru/post/556002/',
 'https://habr.com/ru/post/556048/',
 'https://habr.com/ru/post/556044/',
 'https://habr.com/ru/post/556042/',
 'https://habr.com/ru/post/556040/',
 'https://habr.com/ru/company/southbridge/blog/544730/',
 'https://habr.com/ru/company/itsoft/blog/556038/',
 'https://habr.com/ru/post/556028/',
 'https://habr.com/ru/post/556024/',
 'https://habr.com/ru/post/556018/',
 'https://habr.com/ru/company/piter/blog/555860/',
 'https://habr.com/ru/company/it_people/blog/555916/',
 'https://habr.com/ru/company/rshb/blog/556004/',
 'https://habr.com/ru/company/skillfactory/blog/555914/',
 'https://habr.com/ru/post/556000/',
 'https://habr.com/ru/company/itsoft/blog/555998/',
 'https://habr.com/ru/post/555988/',
 'https://habr.com/ru/post/555934/']
Решение: итоговый датафрейм

In [28]:
# формируем итоговый дата-фрейм

our_table = pd.DataFrame()

for el in res_all_links:
    time.sleep(0.36)
    res_res = requests.get(el)
    res_soup = BeautifulSoup(res_res.text, 'html.parser')
    text_post = res_soup.find('article', class_='post') # в этой строке лежит HTML 
    for word in words:
        if word.lower() in text_post.text.lower():
            title_post = text_post.find('span', class_='post__title-text').text
            date_post = text_post.find('span', class_='post__time').text
            post_text = text_post.find('div', class_='post__text').text
            #link_post = text_post.find('div', class_='post__text').get('data-io-article-url')
            row = {'date': date_post, 'title': title_post, 'link': el, 'text': post_text}
            our_table = pd.concat([our_table, pd.DataFrame([row])]) # в пустой датафрейм добавляем каждую новую строку с данными
            break
        
our_table
Out[28]:
date	title	link	text
0	сегодня в 13:19	Как адаптировать языковые модели Kaldi? (со см...	https://habr.com/ru/company/cft/blog/558824/	\n\r\n«Как научить русскоязычную модель распоз...
0	сегодня в 12:39	Необычная концепция синтаксиса языка программи...	https://habr.com/ru/company/timeweb/blog/558738/	\n\r\nХочу представить на обсуждение читателей...
0	сегодня в 12:25	Как принимать платежи в Telegram | API Yoomone...	https://habr.com/ru/post/558924/	В данном посте мы научимся принимать платежи в...
0	сегодня в 11:59	Управление тестами в TestOps: храните информац...	https://habr.com/ru/post/558594/	Обеспечить представление данных из любой больш...
0	сегодня в 11:48	Как мы запустили документооборот в Telegram и ...	https://habr.com/ru/post/558918/	Разбираем аргументы «за» и «против». В конце т...
...	...	...	...	...
0	6 мая 2021 в 06:34	Python, исследование данных и выборы: часть 4	https://habr.com/ru/post/556044/	Пост №4 для начинающих посвящен техническим пр...
0	6 мая 2021 в 06:01	Python, исследование данных и выборы: часть 3	https://habr.com/ru/post/556042/	Пост №3 для начинающих посвящен генерированию ...
0	6 мая 2021 в 05:02	Python, исследование данных и выборы: часть 2	https://habr.com/ru/post/556040/	Пост №2 для начинающих посвящен описательным с...
0	5 мая 2021 в 19:45	Как я посчитал миллионное число Фибоначчи	https://habr.com/ru/company/skillfactory/blog/...	Все мы понимаем, что рекурсивное вычисление чи...
0	5 мая 2021 в 19:35	Python, исследование данных и выборы: часть 1	https://habr.com/ru/post/556000/	Серия из 5 постов для начинающих представляет ...
184 rows × 4 columns


Задание 2
Обязательная часть Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода: EMAIL = [xxx@x.ru, yyy@y.com]

В итоге должен формироваться датафрейм со столбцами: <дата утечки> - <источник утечки> - <описание утечки>

Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

Дополнительная часть (необязательная) Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте. Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get

GROUP = 'netology'
TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>

In [38]:
# main part

EMAIL = ['xxx@x.ru', 'yyy@y.com']
url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
headers = {'Vaar-Header-App-Build-Version': '1.0.0', 'Vaar-Header-App-Product': 'hackcheck-web-avast', 'Vaar-Header-App-Product-Name': 'hackcheck-web-avast', 'Vaar-Version': '0'}
adresses = {'emailAddresses': EMAIL}
adresses = {'emailAddresses': EMAIL}
res = requests.post(url, json=adresses, headers=headers)
df = pd.DataFrame(res.json()['breaches']).T.reset_index() 
df = df[['site', 'description', 'publishDate']]
In [39]:
df.head()
Out[39]:
site	description	publishDate
0	verifications.io	Big data e-mail verification platform verifica...	2019-03-28T00:00:00Z
1	vk.com	At some time in 2020, the Russian social netwo...	2020-05-21T00:00:00Z
2	www.dangdang.com	This is a list of email addresses only, and as...	2019-02-21T00:00:00Z
3	123rf.com	In March 2020, the stock image agency 123RF wa...	2020-11-19T00:00:00Z
4	azcentral.com	At an unconfirmed date, online Arizona newspap...	2020-01-03T00:00:00Z
